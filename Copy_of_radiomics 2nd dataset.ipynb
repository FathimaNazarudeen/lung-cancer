# %% [markdown]
# <a href="https://colab.research.google.com/github/FathimaNazarudeen/lung-cancer/blob/main/Copy_of_radiomics%202nd%20dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_csv("/content/thirddatasetdata2editednew.csv")

# %%
data['Label'].value_counts()
# Out:
# adeno       42
# squamous    35
# other       12
# Name: Label, dtype: int64

# %%
data.columns
# Out:
# Index(['imaging.radiomics.GLCM_autocorr', 'imaging.radiomics.GLCM_clusProm',
#        'imaging.radiomics.GLCM_clusShade', 'imaging.radiomics.GLCM_clusTend',
#        'imaging.radiomics.GLCM_contrast', 'imaging.radiomics.GLCM_correl1',
#        'imaging.radiomics.GLCM_diffEntro', 'imaging.radiomics.GLCM_dissimilar',
#        'imaging.radiomics.GLCM_energy', 'imaging.radiomics.GLCM_entrop2',
#        ...
#        'imaging.radiomics.Wavelet_LLL_stats_median',
#        'imaging.radiomics.Wavelet_LLL_stats_min',
#        'imaging.radiomics.Wavelet_LLL_stats_range',
#        'imaging.radiomics.Wavelet_LLL_stats_rms',
#        'imaging.radiomics.Wavelet_LLL_stats_skewness',
#        'imaging.radiomics.Wavelet_LLL_stats_std',
#        'imaging.radiomics.Wavelet_LLL_stats_totalenergy',
#        'imaging.radiomics.Wavelet_LLL_stats_uniformity',
#        'imaging.radiomics.Wavelet_LLL_stats_var', 'Label'],
#       dtype='object', length=651)

# %%
data_real = data.replace(np.inf, np.nan)

# %%
data_real.isnull().sum().sum()
# Out:
# 0

# %%
data_df = data_real.dropna(axis=0)

# %%
data_df.isnull().sum().sum()
# Out:
# 0

# %%
data_df
# Out:
#     imaging.radiomics.GLCM_autocorr  imaging.radiomics.GLCM_clusProm  \
# 0                        974.807775                     1.622693e+04
# 1                       1481.384832                     5.990974e+04
# 2                       3872.453374                     4.108418e+09
# 3                        695.041214                     4.149945e+04
# 4                        762.350839                     6.832887e+04
# ..                              ...                              ...
# 84                      1136.874226                     1.726526e+04
# 85                       690.874197                     4.733321e+04
# 86                       601.924490                     6.179012e+03
# 87                       601.924490                     6.179012e+03
# 88                       404.275573                     2.867433e+04
#
#     imaging.radiomics.GLCM_clusShade  imaging.radiomics.GLCM_clusTend  \
# 0                        -485.694214                        20.677451
# 1                       -1576.604188                        65.516719
# 2                      -40980.455560                      1374.305720
# 3                       -1315.773459                        87.294884
# 4                       -1381.277499                       148.188061
# ..                               ...                              ...
# 84                       -508.990915                        40.848166
# 85                      -1432.032909                       107.520123
# 86                       -210.953607                        20.484082
# 87                       -210.953607                        20.484082
# 88                       -707.032249                        93.849341
#
#     imaging.radiomics.GLCM_contrast  imaging.radiomics.GLCM_correl1  \
# 0                          2.199042                        0.821098
# 1                          9.254695                        0.754425
# 2                         29.367922                        0.960624
# 3                         10.902911                        0.775198
# 4                         22.457054                        0.736728
# ..                              ...                             ...
# 84                        12.219760                        0.537969
# 85                        12.172218                        0.792865
# 86                         2.231344                        0.800474
# 87                         2.231344                        0.800474
# 88                        22.308018                        0.618446
#
#     imaging.radiomics.GLCM_diffEntro  imaging.radiomics.GLCM_dissimilar  \
# 0                           1.080075                           0.734860
# 1                           1.686171                           1.722073
# 2                           2.416309                           3.878045
# 3                           1.851825                           2.009553
# 4                           2.297417                           3.411370
# ..                               ...                                ...
# 84                          2.017602                           2.541419
# 85                          1.992276                           2.357484
# 86                          1.212351                           0.864871
# 87                          1.212351                           0.864871
# 88                          2.266238                           3.473518
#
#     imaging.radiomics.GLCM_energy  imaging.radiomics.GLCM_entrop2  ...  \
# 0                        0.161738                        2.561361  ...
# 1                        0.047312                        4.066880  ...
# 2                        0.003364                        6.389297  ...
# 3                        0.034897                        4.583572  ...
# 4                        0.005689                        5.767177  ...
# ..                            ...                             ...  ...
# 84                       0.012917                        4.897015  ...
# 85                       0.019799                        4.922992  ...
# 86                       0.093544                        3.260115  ...
# 87                       0.093544                        3.260115  ...
# 88                       0.008502                        5.085398  ...
#
#     imaging.radiomics.Wavelet_LLL_stats_median  \
# 0                                  2908.156236
# 1                                  2895.820234
# 2                                  5252.020964
# 3                                  5886.237720
# 4                                  2577.676304
# ..                                         ...
# 84                                 2947.395894
# 85                                 5844.429702
# 86                                 2982.771351
# 87                                 2982.771351
# 88                                 2825.492940
#
#     imaging.radiomics.Wavelet_LLL_stats_min  \
# 0                                749.562721
# 1                                 77.734493
# 2                                768.520760
# 3                               4035.371922
# 4                                728.016080
# ..                                      ...
# 84                               899.333940
# 85                              3969.695656
# 86                              1308.938860
# 87                              1308.938860
# 88                              1492.839890
#
#     imaging.radiomics.Wavelet_LLL_stats_range  \
# 0                                 2737.841292
# 1                                 3450.898825
# 2                                 5846.377098
# 3                                 2586.389219
# 4                                 2955.870207
# ..                                        ...
# 84                                2488.809180
# 85                                2325.999258
# 86                                2335.651107
# 87                                2335.651107
# 88                                1983.158830
#
#     imaging.radiomics.Wavelet_LLL_stats_rms  \
# 0                               2866.720944
# 1                               2808.211801
# 2                               4919.140829
# 3                               5725.580599
# 4                               2540.403805
# ..                                      ...
# 84                              2872.653468
# 85                              5696.150168
# 86                              2959.605055
# 87                              2959.605055
# 88                              2777.899166
#
#     imaging.radiomics.Wavelet_LLL_stats_skewness  \
# 0                                      -4.684032
# 1                                      -2.685867
# 2                                      -0.778334
# 3                                      -1.472562
# 4                                      -0.571742
# ..                                           ...
# 84                                     -1.943993
# 85                                     -1.123228
# 86                                     -2.456362
# 87                                     -2.456362
# 88                                     -0.622212
#
#     imaging.radiomics.Wavelet_LLL_stats_std  \
# 0                                202.090410
# 1                                327.154770
# 2                               1349.678920
# 3                                397.225995
# 4                                474.197815
# ..                                      ...
# 84                               278.641225
# 85                               432.854997
# 86                               187.578235
# 87                               187.578235
# 88                               429.690726
#
#     imaging.radiomics.Wavelet_LLL_stats_totalenergy  \
# 0                                      4.920334e+08
# 1                                      6.100099e+08
# 2                                      2.104979e+08
# 3                                      9.263943e+08
# 4                                      3.166161e+07
# ..                                              ...
# 84                                     1.155299e+08
# 85                                     2.281936e+08
# 86                                     1.643343e+09
# 87                                     1.643343e+09
# 88                                     5.023587e+09
#
#     imaging.radiomics.Wavelet_LLL_stats_uniformity  \
# 0                                         0.341563
# 1                                         0.193098
# 2                                         0.026267
# 3                                         0.120999
# 4                                         0.045411
# ..                                             ...
# 84                                        0.099577
# 85                                        0.077416
# 86                                        0.253570
# 87                                        0.253570
# 88                                        0.049898
#
#     imaging.radiomics.Wavelet_LLL_stats_var     Label
# 0                              4.084053e+04  squamous
# 1                              1.070302e+05  squamous
# 2                              1.821633e+09  squamous
# 3                              1.577885e+05  squamous
# 4                              2.248636e+05  squamous
# ..                                      ...       ...
# 84                             7.764093e+04     other
# 85                             1.873634e+05     other
# 86                             3.518559e+04     other
# 87                             3.518559e+04     other
# 88                             1.846341e+05     other
#
# [89 rows x 651 columns]

# %%
data_X = data_df.drop(['Label'], axis = 1)

# %%
data_X.columns
# Out:
# Index(['imaging.radiomics.GLCM_autocorr', 'imaging.radiomics.GLCM_clusProm',
#        'imaging.radiomics.GLCM_clusShade', 'imaging.radiomics.GLCM_clusTend',
#        'imaging.radiomics.GLCM_contrast', 'imaging.radiomics.GLCM_correl1',
#        'imaging.radiomics.GLCM_diffEntro', 'imaging.radiomics.GLCM_dissimilar',
#        'imaging.radiomics.GLCM_energy', 'imaging.radiomics.GLCM_entrop2',
#        ...
#        'imaging.radiomics.Wavelet_LLL_stats_mean',
#        'imaging.radiomics.Wavelet_LLL_stats_median',
#        'imaging.radiomics.Wavelet_LLL_stats_min',
#        'imaging.radiomics.Wavelet_LLL_stats_range',
#        'imaging.radiomics.Wavelet_LLL_stats_rms',
#        'imaging.radiomics.Wavelet_LLL_stats_skewness',
#        'imaging.radiomics.Wavelet_LLL_stats_std',
#        'imaging.radiomics.Wavelet_LLL_stats_totalenergy',
#        'imaging.radiomics.Wavelet_LLL_stats_uniformity',
#        'imaging.radiomics.Wavelet_LLL_stats_var'],
#       dtype='object', length=650)

# %%
data_X.shape
# Out:
# (89, 650)

# %%
data_y = data_df['Label']

# %%
data_y.shape
# Out:
# (89,)

# %%
data_df.isnull().sum().sum()
# Out:
# 0

# %%
data_y.unique()
# Out:
# array(['squamous', 'adeno', 'other'], dtype=object)

# %%
data_X
# Out:
#     imaging.radiomics.GLCM_autocorr  imaging.radiomics.GLCM_clusProm  \
# 0                        974.807775                     1.622693e+04
# 1                       1481.384832                     5.990974e+04
# 2                       3872.453374                     4.108418e+09
# 3                        695.041214                     4.149945e+04
# 4                        762.350839                     6.832887e+04
# ..                              ...                              ...
# 84                      1136.874226                     1.726526e+04
# 85                       690.874197                     4.733321e+04
# 86                       601.924490                     6.179012e+03
# 87                       601.924490                     6.179012e+03
# 88                       404.275573                     2.867433e+04
#
#     imaging.radiomics.GLCM_clusShade  imaging.radiomics.GLCM_clusTend  \
# 0                        -485.694214                        20.677451
# 1                       -1576.604188                        65.516719
# 2                      -40980.455560                      1374.305720
# 3                       -1315.773459                        87.294884
# 4                       -1381.277499                       148.188061
# ..                               ...                              ...
# 84                       -508.990915                        40.848166
# 85                      -1432.032909                       107.520123
# 86                       -210.953607                        20.484082
# 87                       -210.953607                        20.484082
# 88                       -707.032249                        93.849341
#
#     imaging.radiomics.GLCM_contrast  imaging.radiomics.GLCM_correl1  \
# 0                          2.199042                        0.821098
# 1                          9.254695                        0.754425
# 2                         29.367922                        0.960624
# 3                         10.902911                        0.775198
# 4                         22.457054                        0.736728
# ..                              ...                             ...
# 84                        12.219760                        0.537969
# 85                        12.172218                        0.792865
# 86                         2.231344                        0.800474
# 87                         2.231344                        0.800474
# 88                        22.308018                        0.618446
#
#     imaging.radiomics.GLCM_diffEntro  imaging.radiomics.GLCM_dissimilar  \
# 0                           1.080075                           0.734860
# 1                           1.686171                           1.722073
# 2                           2.416309                           3.878045
# 3                           1.851825                           2.009553
# 4                           2.297417                           3.411370
# ..                               ...                                ...
# 84                          2.017602                           2.541419
# 85                          1.992276                           2.357484
# 86                          1.212351                           0.864871
# 87                          1.212351                           0.864871
# 88                          2.266238                           3.473518
#
#     imaging.radiomics.GLCM_energy  imaging.radiomics.GLCM_entrop2  ...  \
# 0                        0.161738                        2.561361  ...
# 1                        0.047312                        4.066880  ...
# 2                        0.003364                        6.389297  ...
# 3                        0.034897                        4.583572  ...
# 4                        0.005689                        5.767177  ...
# ..                            ...                             ...  ...
# 84                       0.012917                        4.897015  ...
# 85                       0.019799                        4.922992  ...
# 86                       0.093544                        3.260115  ...
# 87                       0.093544                        3.260115  ...
# 88                       0.008502                        5.085398  ...
#
#     imaging.radiomics.Wavelet_LLL_stats_mean  \
# 0                                2859.588978
# 1                                2789.090292
# 2                                4730.382935
# 3                                5711.785210
# 4                                2495.763162
# ..                                       ...
# 84                               2859.108700
# 85                               5679.682203
# 86                               2953.654799
# 87                               2953.654799
# 88                               2744.516947
#
#     imaging.radiomics.Wavelet_LLL_stats_median  \
# 0                                  2908.156236
# 1                                  2895.820234
# 2                                  5252.020964
# 3                                  5886.237720
# 4                                  2577.676304
# ..                                         ...
# 84                                 2947.395894
# 85                                 5844.429702
# 86                                 2982.771351
# 87                                 2982.771351
# 88                                 2825.492940
#
#     imaging.radiomics.Wavelet_LLL_stats_min  \
# 0                                749.562721
# 1                                 77.734493
# 2                                768.520760
# 3                               4035.371922
# 4                                728.016080
# ..                                      ...
# 84                               899.333940
# 85                              3969.695656
# 86                              1308.938860
# 87                              1308.938860
# 88                              1492.839890
#
#     imaging.radiomics.Wavelet_LLL_stats_range  \
# 0                                 2737.841292
# 1                                 3450.898825
# 2                                 5846.377098
# 3                                 2586.389219
# 4                                 2955.870207
# ..                                        ...
# 84                                2488.809180
# 85                                2325.999258
# 86                                2335.651107
# 87                                2335.651107
# 88                                1983.158830
#
#     imaging.radiomics.Wavelet_LLL_stats_rms  \
# 0                               2866.720944
# 1                               2808.211801
# 2                               4919.140829
# 3                               5725.580599
# 4                               2540.403805
# ..                                      ...
# 84                              2872.653468
# 85                              5696.150168
# 86                              2959.605055
# 87                              2959.605055
# 88                              2777.899166
#
#     imaging.radiomics.Wavelet_LLL_stats_skewness  \
# 0                                      -4.684032
# 1                                      -2.685867
# 2                                      -0.778334
# 3                                      -1.472562
# 4                                      -0.571742
# ..                                           ...
# 84                                     -1.943993
# 85                                     -1.123228
# 86                                     -2.456362
# 87                                     -2.456362
# 88                                     -0.622212
#
#     imaging.radiomics.Wavelet_LLL_stats_std  \
# 0                                202.090410
# 1                                327.154770
# 2                               1349.678920
# 3                                397.225995
# 4                                474.197815
# ..                                      ...
# 84                               278.641225
# 85                               432.854997
# 86                               187.578235
# 87                               187.578235
# 88                               429.690726
#
#     imaging.radiomics.Wavelet_LLL_stats_totalenergy  \
# 0                                      4.920334e+08
# 1                                      6.100099e+08
# 2                                      2.104979e+08
# 3                                      9.263943e+08
# 4                                      3.166161e+07
# ..                                              ...
# 84                                     1.155299e+08
# 85                                     2.281936e+08
# 86                                     1.643343e+09
# 87                                     1.643343e+09
# 88                                     5.023587e+09
#
#     imaging.radiomics.Wavelet_LLL_stats_uniformity  \
# 0                                         0.341563
# 1                                         0.193098
# 2                                         0.026267
# 3                                         0.120999
# 4                                         0.045411
# ..                                             ...
# 84                                        0.099577
# 85                                        0.077416
# 86                                        0.253570
# 87                                        0.253570
# 88                                        0.049898
#
#     imaging.radiomics.Wavelet_LLL_stats_var
# 0                              4.084053e+04
# 1                              1.070302e+05
# 2                              1.821633e+09
# 3                              1.577885e+05
# 4                              2.248636e+05
# ..                                      ...
# 84                             7.764093e+04
# 85                             1.873634e+05
# 86                             3.518559e+04
# 87                             3.518559e+04
# 88                             1.846341e+05
#
# [89 rows x 650 columns]

# %% [markdown]
# Label encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data_y_trans = le.fit_transform(data_y)

# %%
data_X
# Out:
#     imaging.radiomics.GLCM_autocorr  imaging.radiomics.GLCM_clusProm  \
# 0                        974.807775                     1.622693e+04
# 1                       1481.384832                     5.990974e+04
# 2                       3872.453374                     4.108418e+09
# 3                        695.041214                     4.149945e+04
# 4                        762.350839                     6.832887e+04
# ..                              ...                              ...
# 84                      1136.874226                     1.726526e+04
# 85                       690.874197                     4.733321e+04
# 86                       601.924490                     6.179012e+03
# 87                       601.924490                     6.179012e+03
# 88                       404.275573                     2.867433e+04
#
#     imaging.radiomics.GLCM_clusShade  imaging.radiomics.GLCM_clusTend  \
# 0                        -485.694214                        20.677451
# 1                       -1576.604188                        65.516719
# 2                      -40980.455560                      1374.305720
# 3                       -1315.773459                        87.294884
# 4                       -1381.277499                       148.188061
# ..                               ...                              ...
# 84                       -508.990915                        40.848166
# 85                      -1432.032909                       107.520123
# 86                       -210.953607                        20.484082
# 87                       -210.953607                        20.484082
# 88                       -707.032249                        93.849341
#
#     imaging.radiomics.GLCM_contrast  imaging.radiomics.GLCM_correl1  \
# 0                          2.199042                        0.821098
# 1                          9.254695                        0.754425
# 2                         29.367922                        0.960624
# 3                         10.902911                        0.775198
# 4                         22.457054                        0.736728
# ..                              ...                             ...
# 84                        12.219760                        0.537969
# 85                        12.172218                        0.792865
# 86                         2.231344                        0.800474
# 87                         2.231344                        0.800474
# 88                        22.308018                        0.618446
#
#     imaging.radiomics.GLCM_diffEntro  imaging.radiomics.GLCM_dissimilar  \
# 0                           1.080075                           0.734860
# 1                           1.686171                           1.722073
# 2                           2.416309                           3.878045
# 3                           1.851825                           2.009553
# 4                           2.297417                           3.411370
# ..                               ...                                ...
# 84                          2.017602                           2.541419
# 85                          1.992276                           2.357484
# 86                          1.212351                           0.864871
# 87                          1.212351                           0.864871
# 88                          2.266238                           3.473518
#
#     imaging.radiomics.GLCM_energy  imaging.radiomics.GLCM_entrop2  ...  \
# 0                        0.161738                        2.561361  ...
# 1                        0.047312                        4.066880  ...
# 2                        0.003364                        6.389297  ...
# 3                        0.034897                        4.583572  ...
# 4                        0.005689                        5.767177  ...
# ..                            ...                             ...  ...
# 84                       0.012917                        4.897015  ...
# 85                       0.019799                        4.922992  ...
# 86                       0.093544                        3.260115  ...
# 87                       0.093544                        3.260115  ...
# 88                       0.008502                        5.085398  ...
#
#     imaging.radiomics.Wavelet_LLL_stats_mean  \
# 0                                2859.588978
# 1                                2789.090292
# 2                                4730.382935
# 3                                5711.785210
# 4                                2495.763162
# ..                                       ...
# 84                               2859.108700
# 85                               5679.682203
# 86                               2953.654799
# 87                               2953.654799
# 88                               2744.516947
#
#     imaging.radiomics.Wavelet_LLL_stats_median  \
# 0                                  2908.156236
# 1                                  2895.820234
# 2                                  5252.020964
# 3                                  5886.237720
# 4                                  2577.676304
# ..                                         ...
# 84                                 2947.395894
# 85                                 5844.429702
# 86                                 2982.771351
# 87                                 2982.771351
# 88                                 2825.492940
#
#     imaging.radiomics.Wavelet_LLL_stats_min  \
# 0                                749.562721
# 1                                 77.734493
# 2                                768.520760
# 3                               4035.371922
# 4                                728.016080
# ..                                      ...
# 84                               899.333940
# 85                              3969.695656
# 86                              1308.938860
# 87                              1308.938860
# 88                              1492.839890
#
#     imaging.radiomics.Wavelet_LLL_stats_range  \
# 0                                 2737.841292
# 1                                 3450.898825
# 2                                 5846.377098
# 3                                 2586.389219
# 4                                 2955.870207
# ..                                        ...
# 84                                2488.809180
# 85                                2325.999258
# 86                                2335.651107
# 87                                2335.651107
# 88                                1983.158830
#
#     imaging.radiomics.Wavelet_LLL_stats_rms  \
# 0                               2866.720944
# 1                               2808.211801
# 2                               4919.140829
# 3                               5725.580599
# 4                               2540.403805
# ..                                      ...
# 84                              2872.653468
# 85                              5696.150168
# 86                              2959.605055
# 87                              2959.605055
# 88                              2777.899166
#
#     imaging.radiomics.Wavelet_LLL_stats_skewness  \
# 0                                      -4.684032
# 1                                      -2.685867
# 2                                      -0.778334
# 3                                      -1.472562
# 4                                      -0.571742
# ..                                           ...
# 84                                     -1.943993
# 85                                     -1.123228
# 86                                     -2.456362
# 87                                     -2.456362
# 88                                     -0.622212
#
#     imaging.radiomics.Wavelet_LLL_stats_std  \
# 0                                202.090410
# 1                                327.154770
# 2                               1349.678920
# 3                                397.225995
# 4                                474.197815
# ..                                      ...
# 84                               278.641225
# 85                               432.854997
# 86                               187.578235
# 87                               187.578235
# 88                               429.690726
#
#     imaging.radiomics.Wavelet_LLL_stats_totalenergy  \
# 0                                      4.920334e+08
# 1                                      6.100099e+08
# 2                                      2.104979e+08
# 3                                      9.263943e+08
# 4                                      3.166161e+07
# ..                                              ...
# 84                                     1.155299e+08
# 85                                     2.281936e+08
# 86                                     1.643343e+09
# 87                                     1.643343e+09
# 88                                     5.023587e+09
#
#     imaging.radiomics.Wavelet_LLL_stats_uniformity  \
# 0                                         0.341563
# 1                                         0.193098
# 2                                         0.026267
# 3                                         0.120999
# 4                                         0.045411
# ..                                             ...
# 84                                        0.099577
# 85                                        0.077416
# 86                                        0.253570
# 87                                        0.253570
# 88                                        0.049898
#
#     imaging.radiomics.Wavelet_LLL_stats_var
# 0                              4.084053e+04
# 1                              1.070302e+05
# 2                              1.821633e+09
# 3                              1.577885e+05
# 4                              2.248636e+05
# ..                                      ...
# 84                             7.764093e+04
# 85                             1.873634e+05
# 86                             3.518559e+04
# 87                             3.518559e+04
# 88                             1.846341e+05
#
# [89 rows x 650 columns]

# %%
df2 = pd.DataFrame(data_X)

# %%
df2.to_csv(r'my_data.csv', index=False)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test = train_test_split(data_X, data_y_trans, train_size = 0.7)

# %%
from sklearn.preprocessing import StandardScaler 
ss = StandardScaler()
X_train_std = ss.fit_transform(X_train)
X_test_std = ss.fit_transform(X_test)

# %% [markdown]
# FEATURE SELECTION

# %%
from sklearn.feature_selection import chi2 
from sklearn.feature_selection import SelectKBest 
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
                     criterion='gini', max_depth=None, max_features='auto',
                     max_leaf_nodes=None, max_samples=None,
                     min_impurity_decrease=0.0, 
                     min_samples_leaf=1, min_samples_split=2,
                     min_weight_fraction_leaf=0.0, n_estimators=100,
                     n_jobs=None, oob_score=False, random_state=42, verbose=0,
                     warm_start=False)

model.fit(data_X, data_y_trans)
# Out:
# ExtraTreesClassifier(random_state=42)

# %%
model.feature_importances_
# Out:
# array([1.62646199e-04, 5.20467836e-04, 8.11118706e-04, 0.00000000e+00,
#        9.79157452e-04, 1.20013551e-03, 1.27277105e-03, 0.00000000e+00,
#        1.00375940e-03, 4.46115288e-04, 0.00000000e+00, 0.00000000e+00,
#        2.33959688e-03, 1.34283183e-03, 1.74012322e-03, 2.14712483e-03,
#        2.97410192e-04, 1.43193775e-03, 1.08430799e-03, 6.37307555e-04,
#        3.40782512e-04, 0.00000000e+00, 4.55928584e-03, 2.09840754e-03,
#        1.65434419e-03, 9.80101770e-04, 1.12461831e-03, 1.62930204e-03,
#        2.28840151e-03, 2.28953095e-03, 7.64178966e-04, 1.10424395e-03,
#        2.06551620e-03, 7.43525480e-04, 2.94141948e-04, 0.00000000e+00,
#        1.24399285e-03, 8.99917683e-04, 3.59193476e-03, 1.65806182e-03,
#        3.90875158e-03, 0.00000000e+00, 0.00000000e+00, 1.11528822e-03,
#        6.97055138e-04, 8.42662211e-04, 1.39411028e-03, 1.08281005e-03,
#        1.62463637e-03, 2.90634221e-04, 6.11290020e-04, 0.00000000e+00,
#        1.71142564e-03, 6.67327786e-04, 1.04333699e-03, 6.37307555e-04,
#        1.54901142e-04, 3.18653777e-04, 4.72357364e-04, 1.51681768e-03,
#        8.79650726e-04, 4.01896304e-04, 1.65040126e-03, 0.00000000e+00,
#        1.55526534e-03, 3.34917284e-03, 8.94980131e-04, 3.17317487e-04,
#        3.86061307e-04, 7.39449135e-04, 0.00000000e+00, 1.07367473e-03,
#        0.00000000e+00, 1.48895744e-03, 2.56399302e-03, 1.72850983e-03,
#        0.00000000e+00, 0.00000000e+00, 8.85149381e-04, 3.48771633e-03,
#        2.69274576e-03, 0.00000000e+00, 1.09616899e-03, 2.84198686e-03,
#        3.32456206e-03, 1.90394946e-03, 4.30172104e-04, 1.45742922e-03,
#        3.13896081e-03, 1.26085527e-03, 2.94747919e-03, 1.88443300e-03,
#        1.07909545e-03, 1.03350042e-03, 6.94531861e-04, 4.07081706e-03,
#        5.06144510e-04, 1.26823738e-03, 6.27865961e-04, 1.20014711e-03,
#        1.89434761e-03, 1.22567183e-03, 6.40258053e-04, 2.92770144e-03,
#        4.74560771e-04, 0.00000000e+00, 3.13537006e-03, 1.63768729e-03,
#        1.16884513e-03, 5.57644110e-04, 8.26139423e-04, 0.00000000e+00,
#        1.85902517e-03, 0.00000000e+00, 9.92591822e-04, 3.18133346e-03,
#        2.78822055e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1
# imaging.radiomics.Wavelet_HLH_rlgl_longRunLowGrayLevEmpha      0.006191
# imaging.radiomics.LoG_sigma_4_5_mm_3D_stats_skewness           0.006030
# imaging.radiomics.Wavelet_HLH_glcm_correl1                     0.005996
# imaging.radiomics.Wavelet_LHH_rlgl_longRunLowGrayLevEmpha      0.005964
# imaging.radiomics.Wavelet_HHH_rlgl_highGrayLevelRunEmphasis    0.005815
# imaging.radiomics.Wavelet_LHH_rlgl_shortRunLowGrayLevEmpha     0.005487
# imaging.radiomics.Wavelet_HHL_stats_median                     0.005443
# imaging.radiomics.Stats_mean                                   0.005320
# dtype: float64

# %%
data_new_20features_X = data_X[['imaging.radiomics.Wavelet_LHH_rlgl_lowGrayLevelRunEmphasis',
'imaging.radiomics.Wavelet_HHH_glcm_autocorr',
'imaging.radiomics.Wavelet_HLH_rlgl_shortRunLowGrayLevEmpha',
'imaging.radiomics.LoG_sigma_3_mm_2D_stats_skewness',
'imaging.radiomics.Wavelet_HHL_rlgl_shortRunLowGrayLevEmpha',
'imaging.radiomics.Wavelet_HLL_glcm_autocorr',
'imaging.radiomics.Shape_spherDisprop',
'imaging.radiomics.Wavelet_LLL_stats_max',
'imaging.radiomics.Wavelet_HLL_glcm_sumVar',
'imaging.radiomics.Wavelet_HHL_glcm_sumSquares',
'imaging.radiomics.LoG_sigma_3_5_mm_2D_stats_skewness',
'imaging.radiomics.Shape_orig_maxDiameter3D_pdist',
'imaging.radiomics.Wavelet_HLH_rlgl_longRunLowGrayLevEmpha',
'imaging.radiomics.LoG_sigma_4_5_mm_3D_stats_skewness',
'imaging.radiomics.Wavelet_HLH_glcm_correl1',
'imaging.radiomics.Wavelet_LHH_rlgl_longRunLowGrayLevEmpha',
'imaging.radiomics.Wavelet_HHH_rlgl_highGrayLevelRunEmphasis',
'imaging.radiomics.Wavelet_LHH_rlgl_shortRunLowGrayLevEmpha',
'imaging.radiomics.Wavelet_HHL_stats_median',
'imaging.radiomics.Stats_mean']]

# %%
data_new_20features_X
# Out:
#     imaging.radiomics.Wavelet_LHH_rlgl_lowGrayLevelRunEmphasis  \
# 0                                            0.002676
# 1                                            0.001646
# 2                                            0.000857
# 3                                            0.002990
# 4                                            0.003023
# ..                                                ...
# 84                                           0.003274
# 85                                           0.005084
# 86                                           0.004617
# 87                                           0.004617
# 88                                           0.007489
#
#     imaging.radiomics.Wavelet_HHH_glcm_autocorr  \
# 0                                    461.564572
# 1                                    635.624496
# 2                                   1737.667222
# 3                                    314.578631
# 4                                    488.478638
# ..                                          ...
# 84                                   554.346205
# 85                                   269.683841
# 86                                   283.086114
# 87                                   283.086114
# 88                                   197.841330
#
#     imaging.radiomics.Wavelet_HLH_rlgl_shortRunLowGrayLevEmpha  \
# 0                                            0.002407
# 1                                            0.001372
# 2                                            0.000977
# 3                                            0.002628
# 4                                            0.002836
# ..                                                ...
# 84                                           0.002095
# 85                                           0.002753
# 86                                           0.003171
# 87                                           0.003171
# 88                                           0.008419
#
#     imaging.radiomics.LoG_sigma_3_mm_2D_stats_skewness  \
# 0                                            1.896589
# 1                                            1.824059
# 2                                           -0.439139
# 3                                            0.055921
# 4                                           -0.387496
# ..                                                ...
# 84                                          -0.058516
# 85                                          -0.251225
# 86                                           1.548916
# 87                                           1.548916
# 88                                          -0.360876
#
#     imaging.radiomics.Wavelet_HHL_rlgl_shortRunLowGrayLevEmpha  \
# 0                                            0.002891
# 1                                            0.001054
# 2                                            0.000789
# 3                                            0.001781
# 4                                            0.002882
# ..                                                ...
# 84                                           0.002292
# 85                                           0.003355
# 86                                           0.001875
# 87                                           0.001875
# 88                                           0.010121
#
#     imaging.radiomics.Wavelet_HLL_glcm_autocorr  \
# 0                                    348.202384
# 1                                    626.005997
# 2                                   1661.198979
# 3                                    356.950928
# 4                                    534.674421
# ..                                          ...
# 84                                   500.285340
# 85                                   288.447116
# 86                                   354.803776
# 87                                   354.803776
# 88                                   257.035618
#
#     imaging.radiomics.Shape_spherDisprop  \
# 0                               1.645513
# 1                               1.812829
# 2                               1.651870
# 3                               1.324282
# 4                               2.579936
# ..                                   ...
# 84                              1.664311
# 85                              1.372687
# 86                              1.485622
# 87                              1.485622
# 88                              1.190747
#
#     imaging.radiomics.Wavelet_LLL_stats_max  \
# 0                               3487.404013
# 1                               3528.633318
# 2                               6614.897858
# 3                               6621.761141
# 4                               3683.886287
# ..                                      ...
# 84                              3388.143119
# 85                              6295.694914
# 86                              3644.589967
# 87                              3644.589967
# 88                              3475.998719
#
#     imaging.radiomics.Wavelet_HLL_glcm_sumVar  \
# 0                                1.259422e+03
# 1                                2.265379e+03
# 2                                6.013715e+03
# 3                                1.218459e+06
# 4                                1.851761e+03
# ..                                        ...
# 84                               1.731943e+03
# 85                               9.567355e+02
# 86                               1.279928e+03
# 87                               1.279928e+03
# 88                               8.396646e+02
#
#     imaging.radiomics.Wavelet_HHL_glcm_sumSquares  \
# 0                                      295.517072
# 1                                      847.723396
# 2                                     2067.501686
# 3                                      500.936448
# 4                                      418.297726
# ..                                            ...
# 84                                     525.931892
# 85                                     310.925896
# 86                                     365.957059
# 87                                     365.957059
# 88                                     203.710571
#
#     imaging.radiomics.LoG_sigma_3_5_mm_2D_stats_skewness  \
# 0                                            1.669665
# 1                                            1.585641
# 2                                           -0.337244
# 3                                           -0.104680
# 4                                           -0.324424
# ..                                                ...
# 84                                          -0.326636
# 85                                          -0.442404
# 86                                           1.293033
# 87                                           1.293033
# 88                                          -0.367213
#
#     imaging.radiomics.Shape_orig_maxDiameter3D_pdist  \
# 0                                           7.905297
# 1                                           7.979188
# 2                                           4.571858
# 3                                           4.708313
# 4                                           3.882901
# ..                                               ...
# 84                                          4.165961
# 85                                          3.158176
# 86                                          8.825350
# 87                                          8.825350
# 88                                          1.288968
#
#     imaging.radiomics.Wavelet_HLH_rlgl_longRunLowGrayLevEmpha  \
# 0                                            0.071593
# 1                                            0.042268
# 2                                            0.028030
# 3                                            0.067419
# 4                                            0.057473
# ..                                                ...
# 84                                           0.051580
# 85                                           0.083235
# 86                                           0.101835
# 87                                           0.101835
# 88                                           0.092665
#
#     imaging.radiomics.LoG_sigma_4_5_mm_3D_stats_skewness  \
# 0                                            1.332256
# 1                                            0.782102
# 2                                            0.470369
# 3                                           -0.555988
# 4                                            0.161439
# ..                                                ...
# 84                                          -0.843733
# 85                                          -0.586735
# 86                                           0.447563
# 87                                           0.447563
# 88                                          -0.111031
#
#     imaging.radiomics.Wavelet_HLH_glcm_correl1  \
# 0                                     0.221458
# 1                                     0.072547
# 2                                     0.383424
# 3                                     0.273597
# 4                                     0.372920
# ..                                         ...
# 84                                   -0.009906
# 85                                    0.427821
# 86                                    0.217774
# 87                                    0.217774
# 88                                    0.428795
#
#     imaging.radiomics.Wavelet_LHH_rlgl_longRunLowGrayLevEmpha  \
# 0                                            0.062304
# 1                                            0.045900
# 2                                            0.027646
# 3                                            0.059308
# 4                                            0.055029
# ..                                                ...
# 84                                           0.057059
# 85                                           0.080181
# 86                                           0.088651
# 87                                           0.088651
# 88                                           0.070392
#
#     imaging.radiomics.Wavelet_HHH_rlgl_highGrayLevelRunEmphasis  \
# 0                                          467.183033
# 1                                          645.896126
# 2                                         1770.685469
# 3                                          323.444840
# 4                                          503.512245
# ..                                                ...
# 84                                         570.072004
# 85                                         276.792625
# 86                                         286.503305
# 87                                         286.503305
# 88                                         210.606101
#
#     imaging.radiomics.Wavelet_LHH_rlgl_shortRunLowGrayLevEmpha  \
# 0                                            0.002328
# 1                                            0.001493
# 2                                            0.000830
# 3                                            0.002782
# 4                                            0.002877
# ..                                                ...
# 84                                           0.003121
# 85                                           0.004581
# 86                                           0.003896
# 87                                           0.003896
# 88                                           0.007064
#
#     imaging.radiomics.Wavelet_HHL_stats_median  imaging.radiomics.Stats_mean
# 0                                     0.012467                   1011.353882
# 1                                     0.022672                    987.257263
# 2                                     0.178038                   1675.178467
# 3                                     0.017576                   2020.759644
# 4                                     0.409428                    888.529053
# ..                                         ...                           ...
# 84                                    0.080513                   1015.453186
# 85                                    0.053400                   2009.659424
# 86                                    0.002293                   1044.663696
# 87                                    0.002293                   1044.663696
# 88                                    0.301714                    975.198425
#
# [89 rows x 20 columns]

# %%
from sklearn.model_selection import train_test_split
X_train_20, X_test_20, y_train_20, y_test_20 = train_test_split(data_new_20features_X, data_y_trans, train_size = 0.8, random_state=26)

# %%
from sklearn.preprocessing import StandardScaler 
ss_20 = StandardScaler()
X_train_std_20 = ss_20.fit_transform(X_train_20)
X_test_std_20 = ss_20.fit_transform(X_test_20)

# %% [markdown]
# Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=56)

# %%
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
from sklearn.metrics import confusion_matrix

# %%
from sklearn.model_selection import cross_val_predict
y_pred = cross_val_predict(rf, data_new_20features_X, data_y_trans, cv=10)
conf_mat = confusion_matrix(data_y_trans, y_pred)

# %%
print(conf_mat)
# Out:
# [[41  0  1]
#  [ 0 12  0]
#  [ 1  0 34]]

# %%
print("Classification Report for Random Forest: \n", classification_report(data_y_trans,y_pred))
# Out:
# Classification Report for Random Forest:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        42
#            1       1.00      1.00      1.00        12
#            2       0.97      0.97      0.97        35
#
#     accuracy                           0.98        89
#    macro avg       0.98      0.98      0.98        89
# weighted avg       0.98      0.98      0.98        89

# %% [markdown]
# PSO

# %%
# !pip install optunity
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optunity in /usr/local/lib/python3.8/dist-packages (1.1.1)

# %%
data_new_20features_Xt = ss_20.fit_transform(data_new_20features_X)

# %%
import optunity
import optunity.metrics
from sklearn.model_selection import cross_val_score
data=data_new_20features_Xt
labels= data_y_trans.tolist()
# Define the hyperparameter configuration space
search = {
    'n_estimators': [10, 100],
    'max_features': [1, 64],
    'max_depth': [5,50],
    "min_samples_split":[2,11],
    "min_samples_leaf":[1,11],
    "criterion":[0,1]
         }
# Define the objective function
@optunity.cross_validated(x=data, y=labels, num_folds=3)
def performance(x_train, y_train, x_test, y_test,n_estimators=None, max_features=None,max_depth=None,min_samples_split=None,min_samples_leaf=None,criterion=None):
    # fit the model
    if criterion<0.5:
        cri='gini'
    else:
        cri='entropy'
    model = RandomForestClassifier(
                                   criterion=cri,
                                  )
    #predictions = model.predict(x_test)
    scores=np.mean(cross_val_score(model, data_new_20features_Xt,  data_y_trans, cv=10, n_jobs=-1,
                                    scoring="accuracy"))
    #return optunity.metrics.roc_auc(y_test, predictions, positive=True)
    return scores#optunity.metrics.accuracy(y_test, predictions)

optimal_configuration, info, _ = optunity.maximize(performance,
                                                  solver_name='particle swarm',
                                                  num_evals=20,
                                                   **search
                                                  )
print(optimal_configuration)
print("Accuracy:"+ str(info.optimum))
# Out:
# {'n_estimators': 62.294921875, 'max_features': 63.0771484375, 'max_depth': 31.8505859375, 'min_samples_split': 5.1904296875, 'min_samples_leaf': 6.986328125, 'criterion': 0.0478515625}
# Accuracy:0.9777777777777779

# %% [markdown]
# ROC Curve

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score

# %%
from sklearn.preprocessing import label_binarize
y_bin = label_binarize(data_y_trans, classes=[0, 1, 2,3])
from itertools import cycle
lw=2

# %%
import matplotlib.pyplot as plt

# %%
y_score = cross_val_predict(rf, data_new_20features_X, data_y_trans, cv=2 ,method='predict_proba')

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
colors = cycle(['blue', 'red', 'green','magenta'])
list_class = ['squamous','largecell','others','adeno']
for i, color in zip(range(3), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(list_class[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic for multi-class data')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# svm

# %%
from sklearn.svm import SVC

svm_rbf = SVC(gamma=4, C=1)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
y_pred = cross_val_predict(svm_rbf, data_new_20features_X, data_y_trans, cv=4)
conf_mat = confusion_matrix(data_y_trans, y_pred)

# %%
print("Classification Report for Random Forest: \n", classification_report(data_y_trans,y_pred))
# Out:
# Classification Report for Random Forest:
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        42
#            1       1.00      1.00      1.00        12
#            2       0.92      0.94      0.93        35
#
#     accuracy                           0.94        89
#    macro avg       0.96      0.96      0.96        89
# weighted avg       0.94      0.94      0.94        89

# %%
data=data_new_20features_Xt
labels=data_y_trans.tolist()

search = {
    'C': (0,50),
    'kernel':[0,4]
         }
@optunity.cross_validated(x=data, y=labels, num_folds=3)
def performance(x_train, y_train, x_test, y_test,C=None,kernel=None):
    # fit the model
    if kernel<1:
        ke='linear'
    elif kernel<2:
        ke='poly'
    elif kernel<3:
        ke='rbf'
    else:
        ke='sigmoid'
    model = SVC(C=float(C),
                kernel=ke
                                  )
    #predictions = model.predict(x_test)
    scores=np.mean(cross_val_score(model, data_new_20features_Xt,data_y_trans, cv=10, n_jobs=-1,
                                    scoring="accuracy"))
    #return optunity.metrics.roc_auc(y_test, predictions, positive=True)
    return scores#optunity.metrics.accuracy(y_test, predictions)

optimal_configuration, info, _ = optunity.maximize(performance,
                                                  solver_name='particle swarm',
                                                  num_evals=20,
                                                   **search
                                                  )
print(optimal_configuration)
print("Accuracy:"+ str(info.optimum))
# Out:
# {'C': 35.1806640625, 'kernel': 2.947265625}
# Accuracy:0.9777777777777779

# %% [markdown]
# knn

# %%
from sklearn.neighbors import KNeighborsClassifier,KNeighborsRegressor

# %%
clf2 = KNeighborsClassifier()
clf2.fit(data_new_20features_X, data_y_trans)
scores = cross_val_score(clf2, data_new_20features_X, data_y_trans, cv=10,scoring='accuracy')
print("Accuracy:"+ str(scores.mean()))
# Out:
# Accuracy:0.7749999999999999

# %% [markdown]
# knn PSO

# %%
import optunity
import optunity.metrics

data=data_new_20features_Xt
labels=data_y_trans.tolist()

search = {
    'n_neighbors': [1, 20],
         }
@optunity.cross_validated(x=data, y=labels, num_folds=3)
def performance(x_train, y_train, x_test, y_test,n_neighbors=None):
    # fit the model
    model = KNeighborsClassifier(n_neighbors=int(n_neighbors),
                                  )
    scores=np.mean(cross_val_score(model,data_new_20features_Xt,data_y_trans, cv=10, n_jobs=-1,
                                    scoring="accuracy"))
    return scores

optimal_configuration, info, _ = optunity.maximize(performance,
                                                  solver_name='particle swarm',
                                                  num_evals=10,
                                                   **search
                                                  )
print(optimal_configuration)
print("Accuracy:"+ str(info.optimum))
# Out:
# {'n_neighbors': 2.60498046875}
# Accuracy:0.9319444444444445

# %% [markdown]
# ROC Curve

# %%
y_score = cross_val_predict(clf2, data_new_20features_X, data_y_trans, cv=2 ,method='predict_proba')

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
colors = cycle(['blue', 'red', 'green','magenta'])
list_class = ['squamous','largecell','others','adeno']
for i, color in zip(range(3), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(list_class[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic for multi-class data')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# GradientBoosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gradient_boost = GradientBoostingClassifier(random_state=56)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
y_pred = cross_val_predict(gradient_boost, data_new_20features_X, data_y_trans, cv=10)
conf_mat = confusion_matrix(data_y_trans, y_pred)

# %%
print("Classification Report for GradientBoosting: \n", classification_report(data_y_trans,y_pred))
# Out:
# Classification Report for GradientBoosting:
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        42
#            1       0.80      1.00      0.89        12
#            2       0.97      0.91      0.94        35
#
#     accuracy                           0.93        89
#    macro avg       0.91      0.95      0.92        89
# weighted avg       0.94      0.93      0.93        89

# %% [markdown]
# GB PSO

# %%
data=data_new_20features_Xt
labels=data_y_trans.tolist()

search = {
    'C': (0,50),
    'kernel':[0,4]
         }
@optunity.cross_validated(x=data, y=labels, num_folds=3)
def performance(x_train, y_train, x_test, y_test,C=None,kernel=None):
    # fit the model
    
    model = GradientBoostingClassifier(random_state=56)
    #predictions = model.predict(x_test)
    scores=np.mean(cross_val_score(model, data_new_20features_Xt,data_y_trans, cv=10, n_jobs=-1,
                                    scoring="accuracy"))
    #return optunity.metrics.roc_auc(y_test, predictions, positive=True)
    return scores#optunity.metrics.accuracy(y_test, predictions)

optimal_configuration, info, _ = optunity.maximize(performance,
                                                  solver_name='particle swarm',
                                                  num_evals=20,
                                                   **search
                                                  )
print(optimal_configuration)
print("Accuracy:"+ str(info.optimum))
# Out:
# {'C': 22.6318359375, 'kernel': 0.591796875}
# Accuracy:0.9333333333333332

# %% [markdown]
# ROC

# %%
y_score = cross_val_predict(gradient_boost, data_new_20features_X, data_y_trans, cv=2 ,method='predict_proba')

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
colors = cycle(['blue', 'red', 'green','magenta'])
list_class = ['squamous','largecell','others','adeno']
for i, color in zip(range(3), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(list_class[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic for multi-class data')
plt.legend(loc="lower right")
plt.show()
