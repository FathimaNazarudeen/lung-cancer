# %% [markdown]
# <a href="https://colab.research.google.com/github/FathimaNazarudeen/lung-cancer/blob/main/log%2Bwavelet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_csv("/content/log+wavelet.csv")

# %%
data['Label'].value_counts()
# Out:
# 'squamous cell carcinoma'    83
# 'large cell'                 71
# others                       70
# adenocarcinoma               23
# Name: Label, dtype: int64

# %%
data.columns
# Out:
# Index(['log-sigma-1-0-mm-3D_firstorder_10Percentile',
#        'log-sigma-1-0-mm-3D_firstorder_90Percentile',
#        'log-sigma-1-0-mm-3D_firstorder_Energy',
#        'log-sigma-1-0-mm-3D_firstorder_Entropy',
#        'log-sigma-1-0-mm-3D_firstorder_InterquartileRange',
#        'log-sigma-1-0-mm-3D_firstorder_Kurtosis',
#        'log-sigma-1-0-mm-3D_firstorder_Maximum',
#        'log-sigma-1-0-mm-3D_firstorder_Mean',
#        'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation',
#        'log-sigma-1-0-mm-3D_firstorder_Median',
#        ...
#        'wavelet-LLL_gldm_LowGrayLevelEmphasis',
#        'wavelet-LLL_gldm_SmallDependenceEmphasis',
#        'wavelet-LLL_gldm_SmallDependenceHighGrayLevelEmphasis',
#        'wavelet-LLL_gldm_SmallDependenceLowGrayLevelEmphasis',
#        'wavelet-LLL_ngtdm_Busyness', 'wavelet-LLL_ngtdm_Coarseness',
#        'wavelet-LLL_ngtdm_Complexity', 'wavelet-LLL_ngtdm_Contrast',
#        'wavelet-LLL_ngtdm_Strength', 'Label'],
#       dtype='object', length=991)

# %%
data_real = data.replace(np.inf, np.nan)

# %%
data_real.isnull().sum().sum()
# Out:
# 0

# %%
data_df = data_real.dropna(axis=0)

# %%
data_df.isnull().sum().sum()
# Out:
# 0

# %%
data_df
# Out:
#      log-sigma-1-0-mm-3D_firstorder_10Percentile  \
# 0                                     -98.358093
# 1                                    -111.005576
# 2                                     -69.277760
# 3                                     -40.055520
# 4                                    -114.916722
# ..                                           ...
# 242                                   -32.333915
# 243                                   -45.553889
# 244                                   -38.180711
# 245                                   -29.717411
# 246                                   -29.717411
#
#      log-sigma-1-0-mm-3D_firstorder_90Percentile  \
# 0                                      66.171655
# 1                                      69.290557
# 2                                      21.564113
# 3                                      34.087923
# 4                                      61.713702
# ..                                           ...
# 242                                    22.054099
# 243                                    23.429811
# 244                                    28.584384
# 245                                    27.484397
# 246                                    27.484397
#
#      log-sigma-1-0-mm-3D_firstorder_Energy  \
# 0                             5.947318e+09
# 1                             2.151458e+09
# 2                             5.366198e+09
# 3                             1.782852e+09
# 4                             6.068749e+09
# ..                                     ...
# 242                           3.210097e+10
# 243                           1.652287e+09
# 244                           1.773794e+08
# 245                           9.495314e+08
# 246                           9.495314e+08
#
#      log-sigma-1-0-mm-3D_firstorder_Entropy  \
# 0                                  4.679830
# 1                                  4.793845
# 2                                  3.847705
# 3                                  3.708007
# 4                                  4.889442
# ..                                      ...
# 242                                3.369245
# 243                                3.593636
# 244                                3.508159
# 245                                3.342546
# 246                                3.342546
#
#      log-sigma-1-0-mm-3D_firstorder_InterquartileRange  \
# 0                                            59.053851
# 1                                            61.418368
# 2                                            33.577361
# 3                                            37.391896
# 4                                            69.082676
# ..                                                 ...
# 242                                          24.348059
# 243                                          33.160039
# 244                                          30.947919
# 245                                          26.520177
# 246                                          26.520177
#
#      log-sigma-1-0-mm-3D_firstorder_Kurtosis  \
# 0                                   6.661496
# 1                                   6.986314
# 2                                   7.320895
# 3                                  13.030340
# 4                                   6.349671
# ..                                       ...
# 242                                14.635831
# 243                                11.533548
# 244                                11.622763
# 245                                 7.789973
# 246                                 7.789973
#
#      log-sigma-1-0-mm-3D_firstorder_Maximum  \
# 0                                441.051544
# 1                                328.737396
# 2                                245.699371
# 3                                102.869247
# 4                                560.478882
# ..                                      ...
# 242                              243.547989
# 243                               80.350250
# 244                               71.404167
# 245                              104.165237
# 246                              104.165237
#
#      log-sigma-1-0-mm-3D_firstorder_Mean  \
# 0                              -6.952052
# 1                             -10.220715
# 2                             -13.011240
# 3                              -5.229649
# 4                             -13.823335
# ..                                   ...
# 242                            -5.985403
# 243                           -11.058552
# 244                           -13.890952
# 245                            -2.209538
# 246                            -2.209538
#
#      log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation  \
# 0                                            49.282723
# 1                                            55.934075
# 2                                            29.126174
# 3                                            25.811452
# 4                                            56.886949
# ..                                                 ...
# 242                                          20.983807
# 243                                          24.944843
# 244                                          27.254898
# 245                                          19.329296
# 246                                          19.329296
#
#      log-sigma-1-0-mm-3D_firstorder_Median  ...  \
# 0                                -0.191278  ...
# 1                                 0.297575  ...
# 2                                -6.232993  ...
# 3                                -1.417206  ...
# 4                                -8.866863  ...
# ..                                     ...  ...
# 242                              -1.562214  ...
# 243                              -4.237140  ...
# 244                              -7.273188  ...
# 245                              -2.596973  ...
# 246                              -2.596973  ...
#
#      wavelet-LLL_gldm_LowGrayLevelEmphasis  \
# 0                                 0.000175
# 1                                 0.000480
# 2                                 0.000204
# 3                                 0.000609
# 4                                 0.000179
# ..                                     ...
# 242                               0.000055
# 243                               0.000797
# 244                               0.005545
# 245                               0.001130
# 246                               0.001130
#
#      wavelet-LLL_gldm_SmallDependenceEmphasis  \
# 0                                    0.782714
# 1                                    0.809799
# 2                                    0.607683
# 3                                    0.672628
# 4                                    0.739990
# ..                                        ...
# 242                                  0.539262
# 243                                  0.635981
# 244                                  0.855006
# 245                                  0.715150
# 246                                  0.715150
#
#      wavelet-LLL_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                         188544.34720
# 1                                         185506.13380
# 2                                          51789.09974
# 3                                          16150.60173
# 4                                         152246.78220
# ..                                                 ...
# 242                                        30796.75751
# 243                                        11131.16552
# 244                                        21236.68132
# 245                                        10757.09395
# 246                                        10757.09395
#
#      wavelet-LLL_gldm_SmallDependenceLowGrayLevelEmphasis  \
# 0                                             0.000174
# 1                                             0.000478
# 2                                             0.000200
# 3                                             0.000595
# 4                                             0.000178
# ..                                                 ...
# 242                                           0.000047
# 243                                           0.000775
# 244                                           0.005537
# 245                                           0.001110
# 246                                           0.001110
#
#      wavelet-LLL_ngtdm_Busyness  wavelet-LLL_ngtdm_Coarseness  \
# 0                      0.001121                      0.001950
# 1                      0.000573                      0.006157
# 2                      0.003829                      0.001594
# 3                      0.008233                      0.005954
# 4                      0.001932                      0.001420
# ..                          ...                           ...
# 242                    0.018433                      0.000387
# 243                    0.007429                      0.006453
# 244                    0.003682                      0.030105
# 245                    0.007144                      0.010583
# 246                    0.007144                      0.010583
#
#      wavelet-LLL_ngtdm_Complexity  wavelet-LLL_ngtdm_Contrast  \
# 0                    5.241414e+06                    1.329551
# 1                    3.263341e+06                    8.577655
# 2                    1.033373e+06                    1.189275
# 3                    6.759171e+04                    0.596882
# 4                    3.371136e+06                    2.314521
# ..                            ...                         ...
# 242                  5.073418e+05                    0.115637
# 243                  8.507560e+04                    0.600453
# 244                  8.491850e+04                    4.490970
# 245                  5.701539e+04                    0.849220
# 246                  5.701539e+04                    0.849220
#
#      wavelet-LLL_ngtdm_Strength         Label
# 0                    576.487136  'large cell'
# 1                   1468.964920  'large cell'
# 2                    158.997655  'large cell'
# 3                     48.462226  'large cell'
# 4                    364.513624  'large cell'
# ..                          ...           ...
# 242                   33.076902        others
# 243                   51.726423        others
# 244                  194.650316        others
# 245                   56.233061        others
# 246                   56.233061        others
#
# [247 rows x 991 columns]

# %%
data_X = data_df.drop(['Label'], axis = 1)

# %%
data_X.columns
# Out:
# Index(['log-sigma-1-0-mm-3D_firstorder_10Percentile',
#        'log-sigma-1-0-mm-3D_firstorder_90Percentile',
#        'log-sigma-1-0-mm-3D_firstorder_Energy',
#        'log-sigma-1-0-mm-3D_firstorder_Entropy',
#        'log-sigma-1-0-mm-3D_firstorder_InterquartileRange',
#        'log-sigma-1-0-mm-3D_firstorder_Kurtosis',
#        'log-sigma-1-0-mm-3D_firstorder_Maximum',
#        'log-sigma-1-0-mm-3D_firstorder_Mean',
#        'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation',
#        'log-sigma-1-0-mm-3D_firstorder_Median',
#        ...
#        'wavelet-LLL_gldm_LargeDependenceLowGrayLevelEmphasis',
#        'wavelet-LLL_gldm_LowGrayLevelEmphasis',
#        'wavelet-LLL_gldm_SmallDependenceEmphasis',
#        'wavelet-LLL_gldm_SmallDependenceHighGrayLevelEmphasis',
#        'wavelet-LLL_gldm_SmallDependenceLowGrayLevelEmphasis',
#        'wavelet-LLL_ngtdm_Busyness', 'wavelet-LLL_ngtdm_Coarseness',
#        'wavelet-LLL_ngtdm_Complexity', 'wavelet-LLL_ngtdm_Contrast',
#        'wavelet-LLL_ngtdm_Strength'],
#       dtype='object', length=990)

# %%
data_X.shape
# Out:
# (247, 990)

# %%
data_y = data_df['Label']

# %%
data_y.shape
# Out:
# (247,)

# %%
data_df.isnull().sum().sum()
# Out:
# 0

# %%
data_y.unique()
# Out:
# array(["'large cell'", "'squamous cell carcinoma'", 'adenocarcinoma',
#        'others'], dtype=object)

# %%
data_X
# Out:
#      log-sigma-1-0-mm-3D_firstorder_10Percentile  \
# 0                                     -98.358093
# 1                                    -111.005576
# 2                                     -69.277760
# 3                                     -40.055520
# 4                                    -114.916722
# ..                                           ...
# 242                                   -32.333915
# 243                                   -45.553889
# 244                                   -38.180711
# 245                                   -29.717411
# 246                                   -29.717411
#
#      log-sigma-1-0-mm-3D_firstorder_90Percentile  \
# 0                                      66.171655
# 1                                      69.290557
# 2                                      21.564113
# 3                                      34.087923
# 4                                      61.713702
# ..                                           ...
# 242                                    22.054099
# 243                                    23.429811
# 244                                    28.584384
# 245                                    27.484397
# 246                                    27.484397
#
#      log-sigma-1-0-mm-3D_firstorder_Energy  \
# 0                             5.947318e+09
# 1                             2.151458e+09
# 2                             5.366198e+09
# 3                             1.782852e+09
# 4                             6.068749e+09
# ..                                     ...
# 242                           3.210097e+10
# 243                           1.652287e+09
# 244                           1.773794e+08
# 245                           9.495314e+08
# 246                           9.495314e+08
#
#      log-sigma-1-0-mm-3D_firstorder_Entropy  \
# 0                                  4.679830
# 1                                  4.793845
# 2                                  3.847705
# 3                                  3.708007
# 4                                  4.889442
# ..                                      ...
# 242                                3.369245
# 243                                3.593636
# 244                                3.508159
# 245                                3.342546
# 246                                3.342546
#
#      log-sigma-1-0-mm-3D_firstorder_InterquartileRange  \
# 0                                            59.053851
# 1                                            61.418368
# 2                                            33.577361
# 3                                            37.391896
# 4                                            69.082676
# ..                                                 ...
# 242                                          24.348059
# 243                                          33.160039
# 244                                          30.947919
# 245                                          26.520177
# 246                                          26.520177
#
#      log-sigma-1-0-mm-3D_firstorder_Kurtosis  \
# 0                                   6.661496
# 1                                   6.986314
# 2                                   7.320895
# 3                                  13.030340
# 4                                   6.349671
# ..                                       ...
# 242                                14.635831
# 243                                11.533548
# 244                                11.622763
# 245                                 7.789973
# 246                                 7.789973
#
#      log-sigma-1-0-mm-3D_firstorder_Maximum  \
# 0                                441.051544
# 1                                328.737396
# 2                                245.699371
# 3                                102.869247
# 4                                560.478882
# ..                                      ...
# 242                              243.547989
# 243                               80.350250
# 244                               71.404167
# 245                              104.165237
# 246                              104.165237
#
#      log-sigma-1-0-mm-3D_firstorder_Mean  \
# 0                              -6.952052
# 1                             -10.220715
# 2                             -13.011240
# 3                              -5.229649
# 4                             -13.823335
# ..                                   ...
# 242                            -5.985403
# 243                           -11.058552
# 244                           -13.890952
# 245                            -2.209538
# 246                            -2.209538
#
#      log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation  \
# 0                                            49.282723
# 1                                            55.934075
# 2                                            29.126174
# 3                                            25.811452
# 4                                            56.886949
# ..                                                 ...
# 242                                          20.983807
# 243                                          24.944843
# 244                                          27.254898
# 245                                          19.329296
# 246                                          19.329296
#
#      log-sigma-1-0-mm-3D_firstorder_Median  ...  \
# 0                                -0.191278  ...
# 1                                 0.297575  ...
# 2                                -6.232993  ...
# 3                                -1.417206  ...
# 4                                -8.866863  ...
# ..                                     ...  ...
# 242                              -1.562214  ...
# 243                              -4.237140  ...
# 244                              -7.273188  ...
# 245                              -2.596973  ...
# 246                              -2.596973  ...
#
#      wavelet-LLL_gldm_LargeDependenceLowGrayLevelEmphasis  \
# 0                                             0.000182
# 1                                             0.000492
# 2                                             0.000242
# 3                                             0.000702
# 4                                             0.000188
# ..                                                 ...
# 242                                           0.000135
# 243                                           0.000960
# 244                                           0.005574
# 245                                           0.001249
# 246                                           0.001249
#
#      wavelet-LLL_gldm_LowGrayLevelEmphasis  \
# 0                                 0.000175
# 1                                 0.000480
# 2                                 0.000204
# 3                                 0.000609
# 4                                 0.000179
# ..                                     ...
# 242                               0.000055
# 243                               0.000797
# 244                               0.005545
# 245                               0.001130
# 246                               0.001130
#
#      wavelet-LLL_gldm_SmallDependenceEmphasis  \
# 0                                    0.782714
# 1                                    0.809799
# 2                                    0.607683
# 3                                    0.672628
# 4                                    0.739990
# ..                                        ...
# 242                                  0.539262
# 243                                  0.635981
# 244                                  0.855006
# 245                                  0.715150
# 246                                  0.715150
#
#      wavelet-LLL_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                         188544.34720
# 1                                         185506.13380
# 2                                          51789.09974
# 3                                          16150.60173
# 4                                         152246.78220
# ..                                                 ...
# 242                                        30796.75751
# 243                                        11131.16552
# 244                                        21236.68132
# 245                                        10757.09395
# 246                                        10757.09395
#
#      wavelet-LLL_gldm_SmallDependenceLowGrayLevelEmphasis  \
# 0                                             0.000174
# 1                                             0.000478
# 2                                             0.000200
# 3                                             0.000595
# 4                                             0.000178
# ..                                                 ...
# 242                                           0.000047
# 243                                           0.000775
# 244                                           0.005537
# 245                                           0.001110
# 246                                           0.001110
#
#      wavelet-LLL_ngtdm_Busyness  wavelet-LLL_ngtdm_Coarseness  \
# 0                      0.001121                      0.001950
# 1                      0.000573                      0.006157
# 2                      0.003829                      0.001594
# 3                      0.008233                      0.005954
# 4                      0.001932                      0.001420
# ..                          ...                           ...
# 242                    0.018433                      0.000387
# 243                    0.007429                      0.006453
# 244                    0.003682                      0.030105
# 245                    0.007144                      0.010583
# 246                    0.007144                      0.010583
#
#      wavelet-LLL_ngtdm_Complexity  wavelet-LLL_ngtdm_Contrast  \
# 0                    5.241414e+06                    1.329551
# 1                    3.263341e+06                    8.577655
# 2                    1.033373e+06                    1.189275
# 3                    6.759171e+04                    0.596882
# 4                    3.371136e+06                    2.314521
# ..                            ...                         ...
# 242                  5.073418e+05                    0.115637
# 243                  8.507560e+04                    0.600453
# 244                  8.491850e+04                    4.490970
# 245                  5.701539e+04                    0.849220
# 246                  5.701539e+04                    0.849220
#
#      wavelet-LLL_ngtdm_Strength
# 0                    576.487136
# 1                   1468.964920
# 2                    158.997655
# 3                     48.462226
# 4                    364.513624
# ..                          ...
# 242                   33.076902
# 243                   51.726423
# 244                  194.650316
# 245                   56.233061
# 246                   56.233061
#
# [247 rows x 990 columns]

# %% [markdown]
# Label encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data_y_trans = le.fit_transform(data_y)

# %%
data_X
# Out:
#      log-sigma-1-0-mm-3D_firstorder_10Percentile  \
# 0                                     -98.358093
# 1                                    -111.005576
# 2                                     -69.277760
# 3                                     -40.055520
# 4                                    -114.916722
# ..                                           ...
# 242                                   -32.333915
# 243                                   -45.553889
# 244                                   -38.180711
# 245                                   -29.717411
# 246                                   -29.717411
#
#      log-sigma-1-0-mm-3D_firstorder_90Percentile  \
# 0                                      66.171655
# 1                                      69.290557
# 2                                      21.564113
# 3                                      34.087923
# 4                                      61.713702
# ..                                           ...
# 242                                    22.054099
# 243                                    23.429811
# 244                                    28.584384
# 245                                    27.484397
# 246                                    27.484397
#
#      log-sigma-1-0-mm-3D_firstorder_Energy  \
# 0                             5.947318e+09
# 1                             2.151458e+09
# 2                             5.366198e+09
# 3                             1.782852e+09
# 4                             6.068749e+09
# ..                                     ...
# 242                           3.210097e+10
# 243                           1.652287e+09
# 244                           1.773794e+08
# 245                           9.495314e+08
# 246                           9.495314e+08
#
#      log-sigma-1-0-mm-3D_firstorder_Entropy  \
# 0                                  4.679830
# 1                                  4.793845
# 2                                  3.847705
# 3                                  3.708007
# 4                                  4.889442
# ..                                      ...
# 242                                3.369245
# 243                                3.593636
# 244                                3.508159
# 245                                3.342546
# 246                                3.342546
#
#      log-sigma-1-0-mm-3D_firstorder_InterquartileRange  \
# 0                                            59.053851
# 1                                            61.418368
# 2                                            33.577361
# 3                                            37.391896
# 4                                            69.082676
# ..                                                 ...
# 242                                          24.348059
# 243                                          33.160039
# 244                                          30.947919
# 245                                          26.520177
# 246                                          26.520177
#
#      log-sigma-1-0-mm-3D_firstorder_Kurtosis  \
# 0                                   6.661496
# 1                                   6.986314
# 2                                   7.320895
# 3                                  13.030340
# 4                                   6.349671
# ..                                       ...
# 242                                14.635831
# 243                                11.533548
# 244                                11.622763
# 245                                 7.789973
# 246                                 7.789973
#
#      log-sigma-1-0-mm-3D_firstorder_Maximum  \
# 0                                441.051544
# 1                                328.737396
# 2                                245.699371
# 3                                102.869247
# 4                                560.478882
# ..                                      ...
# 242                              243.547989
# 243                               80.350250
# 244                               71.404167
# 245                              104.165237
# 246                              104.165237
#
#      log-sigma-1-0-mm-3D_firstorder_Mean  \
# 0                              -6.952052
# 1                             -10.220715
# 2                             -13.011240
# 3                              -5.229649
# 4                             -13.823335
# ..                                   ...
# 242                            -5.985403
# 243                           -11.058552
# 244                           -13.890952
# 245                            -2.209538
# 246                            -2.209538
#
#      log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation  \
# 0                                            49.282723
# 1                                            55.934075
# 2                                            29.126174
# 3                                            25.811452
# 4                                            56.886949
# ..                                                 ...
# 242                                          20.983807
# 243                                          24.944843
# 244                                          27.254898
# 245                                          19.329296
# 246                                          19.329296
#
#      log-sigma-1-0-mm-3D_firstorder_Median  ...  \
# 0                                -0.191278  ...
# 1                                 0.297575  ...
# 2                                -6.232993  ...
# 3                                -1.417206  ...
# 4                                -8.866863  ...
# ..                                     ...  ...
# 242                              -1.562214  ...
# 243                              -4.237140  ...
# 244                              -7.273188  ...
# 245                              -2.596973  ...
# 246                              -2.596973  ...
#
#      wavelet-LLL_gldm_LargeDependenceLowGrayLevelEmphasis  \
# 0                                             0.000182
# 1                                             0.000492
# 2                                             0.000242
# 3                                             0.000702
# 4                                             0.000188
# ..                                                 ...
# 242                                           0.000135
# 243                                           0.000960
# 244                                           0.005574
# 245                                           0.001249
# 246                                           0.001249
#
#      wavelet-LLL_gldm_LowGrayLevelEmphasis  \
# 0                                 0.000175
# 1                                 0.000480
# 2                                 0.000204
# 3                                 0.000609
# 4                                 0.000179
# ..                                     ...
# 242                               0.000055
# 243                               0.000797
# 244                               0.005545
# 245                               0.001130
# 246                               0.001130
#
#      wavelet-LLL_gldm_SmallDependenceEmphasis  \
# 0                                    0.782714
# 1                                    0.809799
# 2                                    0.607683
# 3                                    0.672628
# 4                                    0.739990
# ..                                        ...
# 242                                  0.539262
# 243                                  0.635981
# 244                                  0.855006
# 245                                  0.715150
# 246                                  0.715150
#
#      wavelet-LLL_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                         188544.34720
# 1                                         185506.13380
# 2                                          51789.09974
# 3                                          16150.60173
# 4                                         152246.78220
# ..                                                 ...
# 242                                        30796.75751
# 243                                        11131.16552
# 244                                        21236.68132
# 245                                        10757.09395
# 246                                        10757.09395
#
#      wavelet-LLL_gldm_SmallDependenceLowGrayLevelEmphasis  \
# 0                                             0.000174
# 1                                             0.000478
# 2                                             0.000200
# 3                                             0.000595
# 4                                             0.000178
# ..                                                 ...
# 242                                           0.000047
# 243                                           0.000775
# 244                                           0.005537
# 245                                           0.001110
# 246                                           0.001110
#
#      wavelet-LLL_ngtdm_Busyness  wavelet-LLL_ngtdm_Coarseness  \
# 0                      0.001121                      0.001950
# 1                      0.000573                      0.006157
# 2                      0.003829                      0.001594
# 3                      0.008233                      0.005954
# 4                      0.001932                      0.001420
# ..                          ...                           ...
# 242                    0.018433                      0.000387
# 243                    0.007429                      0.006453
# 244                    0.003682                      0.030105
# 245                    0.007144                      0.010583
# 246                    0.007144                      0.010583
#
#      wavelet-LLL_ngtdm_Complexity  wavelet-LLL_ngtdm_Contrast  \
# 0                    5.241414e+06                    1.329551
# 1                    3.263341e+06                    8.577655
# 2                    1.033373e+06                    1.189275
# 3                    6.759171e+04                    0.596882
# 4                    3.371136e+06                    2.314521
# ..                            ...                         ...
# 242                  5.073418e+05                    0.115637
# 243                  8.507560e+04                    0.600453
# 244                  8.491850e+04                    4.490970
# 245                  5.701539e+04                    0.849220
# 246                  5.701539e+04                    0.849220
#
#      wavelet-LLL_ngtdm_Strength
# 0                    576.487136
# 1                   1468.964920
# 2                    158.997655
# 3                     48.462226
# 4                    364.513624
# ..                          ...
# 242                   33.076902
# 243                   51.726423
# 244                  194.650316
# 245                   56.233061
# 246                   56.233061
#
# [247 rows x 990 columns]

# %%
df2 = pd.DataFrame(data_X)

# %%
df2.to_csv(r'my_data.csv', index=False)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test = train_test_split(data_X, data_y_trans, train_size = 0.7)

# %%
from sklearn.preprocessing import StandardScaler 
ss = StandardScaler()
X_train_std = ss.fit_transform(X_train)
X_test_std = ss.fit_transform(X_test)

# %% [markdown]
# FEATURE SELECTION

# %%
from sklearn.feature_selection import chi2 
from sklearn.feature_selection import SelectKBest 
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
                     criterion='gini', max_depth=None, max_features='auto',
                     max_leaf_nodes=None, max_samples=None,
                     min_impurity_decrease=0.0, 
                     min_samples_leaf=1, min_samples_split=2,
                     min_weight_fraction_leaf=0.0, n_estimators=100,
                     n_jobs=None, oob_score=False, random_state=42, verbose=0,
                     warm_start=False)

model.fit(data_X, data_y_trans)
# Out:
# ExtraTreesClassifier(random_state=42)

# %%
model.feature_importances_
# Out:
# array([6.66654785e-04, 6.27322620e-04, 9.24308960e-04, 1.14106328e-03,
#        3.84674201e-04, 2.45344396e-03, 1.03845885e-03, 2.70515129e-03,
#        1.02615490e-03, 9.74726690e-04, 1.30471993e-03, 1.18990582e-03,
#        1.44013528e-03, 1.47289855e-03, 1.22283775e-03, 7.96167818e-04,
#        1.61899850e-03, 9.16997967e-04, 5.84955183e-04, 1.96295440e-03,
#        1.12475638e-03, 5.23401417e-04, 8.91636121e-04, 9.81660624e-04,
#        2.11900337e-03, 9.97263750e-04, 7.09842567e-04, 4.53128467e-04,
#        5.77683226e-04, 1.25146354e-03, 3.66414411e-04, 1.04887700e-03,
#        3.54694366e-04, 1.21252961e-03, 1.47124857e-04, 7.44943090e-04,
#        1.05511134e-03, 8.66017390e-04, 9.25287344e-04, 1.40294285e-03,
#        9.74433809e-04, 7.04664885e-04, 7.77006225e-04, 7.21052746e-04,
#        1.10915707e-03, 6.66442299e-04, 1.37066332e-03, 2.19700312e-04,
#        8.99477660e-04, 5.48815400e-04, 7.16934168e-04, 2.13563878e-03,
#        1.18835994e-03, 5.49227641e-04, 1.22220841e-03, 5.41540261e-04,
#        1.63896496e-03, 5.51314024e-04, 9.85050066e-04, 9.21711637e-04,
#        1.60174024e-03, 1.49906455e-03, 9.69946011e-04, 4.10767625e-04,
#        4.01932444e-04, 1.07248452e-03, 6.19974064e-04, 9.56012858e-04,
#        4.00255059e-04, 6.26069303e-04, 1.78436414e-03, 8.61518846e-04,
#        1.03162863e-03, 8.49050376e-04, 6.45073662e-04, 2.11571505e-03,
#        1.36288310e-03, 5.05184662e-04, 1.02323211e-03, 1.94642319e-03,
#        6.84450626e-04, 4.39004709e-04, 1.13137569e-03, 0.00000000e+00,
#        7.32831351e-04, 5.10091911e-04, 7.64218686e-04, 7.31081977e-04,
#        5.77145272e-04, 1.14298320e-03, 6.14535946e-04, 9.29035885e-04,
#        6.45383738e-04, 9.29847033e-04, 7.83505155e-05, 6.65060020e-04,
#        6.22806052e-04, 7.31903126e-04, 7.21539276e-04, 5.61899630e-04,
#        5.89567933e-04, 1.44219866e-03])

# %%
feature_importance_std = pd.Series(model.feature_importances_, index=data_X.columns)
feature_importance_std.nlargest(20).plot(kind='bar', title='Standardised Dataset Feature Selection using ExtraTreesClassifier')

# %%
feature_importance_std.nlargest(20)
# Out:
# wavelet-HLL_glcm_Idmn                                  0.005226
# wavelet-HLL_glcm_Correlation                           0.005013
# wavelet-HLL_glszm_SizeZoneNonUniformityNormalized      0.004839
# wavelet-HLH_firstorder_Skewness                        0.004473
# wavelet-LLH_glszm_GrayLevelNonUniformity               0.003197
# wavelet-HLL_glcm_DifferenceVariance                    0.002887
# wavelet-HLL_firstorder_10Percentile                    0.002758
# log-sigma-1-0-mm-3D_firstorder_Mean                    0.002705
# log-sigma-1-0-mm-3D_glszm_HighGrayLevelZoneEmphasis    0.002639
# wavelet-HHL_glszm_HighGrayLevelZoneEmphasis            0.002579
# wavelet-HHH_firstorder_RootMeanSquared                 0.002555
# wavelet-HLH_glszm_SizeZoneNonUniformityNormalized      0.002533
# wavelet-HLL_firstorder_Maximum                         0.002520
# log-sigma-3-0-mm-3D_firstorder_InterquartileRange      0.002513
# wavelet-HLL_gldm_DependenceEntropy                     0.002502
# log-sigma-1-0-mm-3D_firstorder_Kurtosis                0.002453
# wavelet-LHL_glcm_ClusterShade                          0.002448
# wavelet-HLL_gldm_LowGrayLevelEmphasis                  0.002431
# wavelet-HHL_glszm_SmallAreaHighGrayLevelEmphasis       0.002396
# wavelet-HLL_glcm_DifferenceEntropy                     0.002381
# dtype: float64

# %%
data_new_20features_X = data_X[['wavelet-HLL_glcm_Idmn',
'wavelet-HLL_glcm_Correlation',
'wavelet-HLL_glszm_SizeZoneNonUniformityNormalized',
'wavelet-HLH_firstorder_Skewness',
'wavelet-LLH_glszm_GrayLevelNonUniformity',
'wavelet-HLL_glcm_DifferenceVariance',
'wavelet-HLL_firstorder_10Percentile',
'log-sigma-1-0-mm-3D_firstorder_Mean',
'log-sigma-1-0-mm-3D_glszm_HighGrayLevelZoneEmphasis',
'wavelet-HHL_glszm_HighGrayLevelZoneEmphasis',
'wavelet-HHH_firstorder_RootMeanSquared',
'wavelet-HLH_glszm_SizeZoneNonUniformityNormalized',
'wavelet-HLL_firstorder_Maximum',
'log-sigma-3-0-mm-3D_firstorder_InterquartileRange',
'wavelet-HLL_gldm_DependenceEntropy',
'log-sigma-1-0-mm-3D_firstorder_Kurtosis',
'wavelet-LHL_glcm_ClusterShade',
'wavelet-HLL_gldm_LowGrayLevelEmphasis',
'wavelet-HHL_glszm_SmallAreaHighGrayLevelEmphasis',
'wavelet-HLL_glcm_DifferenceEntropy']]

# %%
data_new_20features_X
# Out:
#      wavelet-HLL_glcm_Idmn  wavelet-HLL_glcm_Correlation  \
# 0                 0.991508                      0.111907
# 1                 0.987631                      0.186510
# 2                 0.992665                      0.228052
# 3                 0.994009                      0.182696
# 4                 0.992437                      0.172725
# ..                     ...                           ...
# 242               0.997897                      0.222189
# 243               0.988212                      0.242403
# 244               0.968710                      0.400221
# 245               0.993733                      0.371026
# 246               0.993733                      0.371026
#
#      wavelet-HLL_glszm_SizeZoneNonUniformityNormalized  \
# 0                                             0.642172
# 1                                             0.751013
# 2                                             0.590152
# 3                                             0.594932
# 4                                             0.675488
# ..                                                 ...
# 242                                           0.503431
# 243                                           0.522061
# 244                                           0.574756
# 245                                           0.526717
# 246                                           0.526717
#
#      wavelet-HLH_firstorder_Skewness  \
# 0                           0.252686
# 1                           0.546188
# 2                          -0.925250
# 3                           1.270809
# 4                          -0.198571
# ..                               ...
# 242                         1.530536
# 243                         1.370590
# 244                         0.579964
# 245                         3.147467
# 246                         3.147467
#
#      wavelet-LLH_glszm_GrayLevelNonUniformity  \
# 0                                   59.266235
# 1                                   35.799083
# 2                                   52.330247
# 3                                   36.963134
# 4                                   61.275099
# ..                                        ...
# 242                                377.034868
# 243                                 19.990148
# 244                                  4.717172
# 245                                 16.793765
# 246                                 16.793765
#
#      wavelet-HLL_glcm_DifferenceVariance  wavelet-HLL_firstorder_10Percentile  \
# 0                             587.651497                          -121.146713
# 1                            1794.187765                          -246.233463
# 2                             247.962922                           -95.728254
# 3                             170.436290                           -49.594727
# 4                            1009.465267                          -186.471365
# ..                                   ...                                  ...
# 242                           189.960458                           -47.492914
# 243                            55.281157                           -52.237895
# 244                            67.490218                           -79.366493
# 245                            55.987380                           -38.814238
# 246                            55.987380                           -38.814238
#
#      log-sigma-1-0-mm-3D_firstorder_Mean  \
# 0                              -6.952052
# 1                             -10.220715
# 2                             -13.011240
# 3                              -5.229649
# 4                             -13.823335
# ..                                   ...
# 242                            -5.985403
# 243                           -11.058552
# 244                           -13.890952
# 245                            -2.209538
# 246                            -2.209538
#
#      log-sigma-1-0-mm-3D_glszm_HighGrayLevelZoneEmphasis  \
# 0                                          2584.285137
# 1                                          2603.759821
# 2                                           595.028571
# 3                                          1001.603715
# 4                                          1390.796678
# ..                                                 ...
# 242                                        1013.200868
# 243                                         715.799505
# 244                                         497.606557
# 245                                         285.078603
# 246                                         285.078603
#
#      wavelet-HHL_glszm_HighGrayLevelZoneEmphasis  \
# 0                                   11144.006050
# 1                                    8793.775170
# 2                                    4196.363086
# 3                                    5901.982609
# 4                                   14759.642540
# ..                                           ...
# 242                                 11152.576870
# 243                                  3175.045135
# 244                                   836.029126
# 245                                  2699.710762
# 246                                  2699.710762
#
#      wavelet-HHH_firstorder_RootMeanSquared  \
# 0                               1000.404194
# 1                               1000.327659
# 2                               1000.100387
# 3                               1000.211471
# 4                               1000.626720
# ..                                      ...
# 242                             1000.080151
# 243                             1000.073671
# 244                              999.778374
# 245                              999.618213
# 246                              999.618213
#
#      wavelet-HLH_glszm_SizeZoneNonUniformityNormalized  \
# 0                                             0.562148
# 1                                             0.599479
# 2                                             0.518291
# 3                                             0.456795
# 4                                             0.564923
# ..                                                 ...
# 242                                           0.472647
# 243                                           0.548930
# 244                                           0.389648
# 245                                           0.534770
# 246                                           0.534770
#
#      wavelet-HLL_firstorder_Maximum  \
# 0                        774.164551
# 1                        982.078430
# 2                        511.219513
# 3                        442.672028
# 4                       1187.875732
# ..                              ...
# 242                      783.546021
# 243                      154.613281
# 244                      174.523468
# 245                      140.575989
# 246                      140.575989
#
#      log-sigma-3-0-mm-3D_firstorder_InterquartileRange  \
# 0                                           148.591108
# 1                                           116.065132
# 2                                           101.671436
# 3                                            79.019236
# 4                                           115.210442
# ..                                                 ...
# 242                                          62.731470
# 243                                         149.602139
# 244                                         104.983813
# 245                                          70.118759
# 246                                          70.118759
#
#      wavelet-HLL_gldm_DependenceEntropy  \
# 0                              7.745333
# 1                              7.880996
# 2                              7.384793
# 3                              6.641931
# 4                              7.783142
# ..                                  ...
# 242                            7.107402
# 243                            6.715105
# 244                            6.289500
# 245                            6.498121
# 246                            6.498121
#
#      log-sigma-1-0-mm-3D_firstorder_Kurtosis  wavelet-LHL_glcm_ClusterShade  \
# 0                                   6.661496                  -21720.947990
# 1                                   6.986314                  -99967.913090
# 2                                   7.320895                   -4492.809261
# 3                                  13.030340                  -74065.956220
# 4                                   6.349671                  -11122.503440
# ..                                       ...                            ...
# 242                                14.635831                  -26064.343870
# 243                                11.533548                 -206332.454100
# 244                                11.622763                     689.759498
# 245                                 7.789973                   10812.585440
# 246                                 7.789973                   10812.585440
#
#      wavelet-HLL_gldm_LowGrayLevelEmphasis  \
# 0                                 0.000233
# 1                                 0.000478
# 2                                 0.000285
# 3                                 0.000713
# 4                                 0.000196
# ..                                     ...
# 242                               0.000069
# 243                               0.000938
# 244                               0.006839
# 245                               0.002267
# 246                               0.002267
#
#      wavelet-HHL_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                         9267.195994
# 1                                         7693.458633
# 2                                         3249.378474
# 3                                         4840.629596
# 4                                        12476.179540
# ..                                                ...
# 242                                       8215.612218
# 243                                       2488.754793
# 244                                        638.743212
# 245                                       1951.995224
# 246                                       1951.995224
#
#      wavelet-HLL_glcm_DifferenceEntropy
# 0                              5.450264
# 1                              6.069575
# 2                              4.737171
# 3                              4.567658
# 4                              5.772762
# ..                                  ...
# 242                            4.320238
# 243                            4.353458
# 244                            4.411760
# 245                            3.940387
# 246                            3.940387
#
# [247 rows x 20 columns]

# %%
from sklearn.model_selection import train_test_split
X_train_20, X_test_20, y_train_20, y_test_20 = train_test_split(data_new_20features_X, data_y_trans, train_size = 0.8, random_state=94)

# %%
from sklearn.preprocessing import StandardScaler 
ss_20 = StandardScaler()
X_train_std_20 = ss_20.fit_transform(X_train_20)
X_test_std_20 = ss_20.fit_transform(X_test_20)

# %% [markdown]
# Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=56)
rf.fit(X_train_std_20, y_train_20)
# Out:
# RandomForestClassifier(random_state=56)

# %%
rf_y_pred = rf.predict(X_test_std_20)

# %%
from sklearn.metrics import accuracy_score

# %%
acc_score = accuracy_score(y_test_20, rf_y_pred)
print("Accuracy Score for Random_Forest: \n", acc_score*100)
# Out:
# Accuracy Score for Random_Forest:
#  86.0

# %%
from sklearn.metrics import classification_report 
from sklearn.metrics import confusion_matrix

# %%
print("Classification Report for Random Forest: \n", classification_report(y_test_20,rf_y_pred))
# Out:
# Classification Report for Random Forest:
#                precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85        17
#            1       1.00      0.83      0.91        18
#            2       1.00      0.80      0.89         5
#            3       0.67      1.00      0.80        10
#
#     accuracy                           0.86        50
#    macro avg       0.89      0.86      0.86        50
# weighted avg       0.89      0.86      0.86        50

# %%
rf_conf_mat = confusion_matrix(y_test_20, rf_y_pred)
print("Random Forest Confusion: \n", rf_conf_mat)
# Out:
# Random Forest Confusion:
#  [[14  0  0  3]
#  [ 1 15  0  2]
#  [ 1  0  4  0]
#  [ 0  0  0 10]]

# %% [markdown]
# ROC Curve

# %%
def RoC_Curve(classifier, X_val, y_val, title): 
        """ RoC Curve for Classifier 
        Parameters: 
        ------------
        classifier: Machine Learning Classifier to be Evaluated
        X_val: Validation Dataset
        y_val: Label/Target of Validation Dataset

        Attributes:
        Plots the Graph    
        
        Note: Some part of this Method code is taken 
            from Sklearn Website
        """

        lw = 2
        n_classes = 3
        y_test1 = to_categorical(y_val)
        pred_RFC_proba = classifier.predict_proba(X_val)
        y_score = pred_RFC_proba

        # Compute ROC curve and ROC area for each class
        fpr = dict()
        tpr = dict()
        roc_auc = dict()
        for i in range(n_classes):
            fpr[i], tpr[i], _ = roc_curve(y_test1[:, i], y_score[:, i])
            roc_auc[i] = auc(fpr[i], tpr[i])

        # Compute micro-average ROC curve and ROC area
        fpr["micro"], tpr["micro"], _ = roc_curve(y_test1.ravel(), y_score.ravel())
        roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

        # First aggregate all false positive rates
        all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

        # Then interpolate all ROC curves at this points
        mean_tpr = np.zeros_like(all_fpr)
        for i in range(n_classes):
            mean_tpr += interp(all_fpr, fpr[i], tpr[i])

        # Finally average it and compute AUC
        mean_tpr /= n_classes

        fpr["macro"] = all_fpr
        tpr["macro"] = mean_tpr
        roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

        # Plot all ROC curves
        plt.figure(figsize=(20,10))
        plt.plot(fpr["micro"], tpr["micro"],
                label='micro-average ROC curve (area = {0:0.2f})'
                    ''.format(roc_auc["micro"]),
                color='deeppink', linestyle=':', linewidth=4)

        plt.plot(fpr["macro"], tpr["macro"],
                label='macro-average ROC curve (area = {0:0.2f})'
                    ''.format(roc_auc["macro"]),
                color='navy', linestyle=':', linewidth=4)

        list_class = ['adeno','squamous','other']
        for i in range(n_classes):
            plt.plot(fpr[i], tpr[i], lw=lw,
                    label='ROC curve of class {0} (area = {1:0.2f})'
                    ''.format(list_class[i], roc_auc[i]))

        plt.plot([0, 1], [0, 1], 'k--', lw=lw)
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title(title) 
        plt.legend(loc="lower right")
        plt.show()

# %%
from keras.utils.np_utils import to_categorical
from sklearn.metrics import roc_curve, auc
from scipy import interp
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt

# %%
title = 'Receiver operating characteristic of Random Forest'
RoC_Curve(rf, X_test_std_20, y_test_20, title)
# Out:
# <ipython-input-9639-3fa2d96845d8>:40: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# %% [markdown]
# XGBoost

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gradient_boost = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1,
max_depth=3, random_state=0)
gradient_boost.fit(X_train_std_20, y_train_20)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
res_xg=gradient_boost.predict(X_test_std_20)

# %%
acc_score_xg = accuracy_score(y_test_20, res_xg)
print("Accuracy Score for GradientBoosting: \n", acc_score_xg*100)
# Out:
# Accuracy Score for GradientBoosting:
#  86.0
