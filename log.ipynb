# %% [markdown]
# <a href="https://colab.research.google.com/github/FathimaNazarudeen/lung-cancer/blob/main/log.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_csv("/content/log.csv")

# %%
data['Label'].value_counts()
# Out:
# 'squamous cell carcinoma'    83
# 'large cell'                 71
# others                       70
# adenocarcinoma               23
# Name: Label, dtype: int64

# %%
data.columns
# Out:
# Index(['log-sigma-1-0-mm-3D_firstorder_10Percentile',
#        'log-sigma-1-0-mm-3D_firstorder_90Percentile',
#        'log-sigma-1-0-mm-3D_firstorder_Energy',
#        'log-sigma-1-0-mm-3D_firstorder_Entropy',
#        'log-sigma-1-0-mm-3D_firstorder_InterquartileRange',
#        'log-sigma-1-0-mm-3D_firstorder_Kurtosis',
#        'log-sigma-1-0-mm-3D_firstorder_Maximum',
#        'log-sigma-1-0-mm-3D_firstorder_Mean',
#        'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation',
#        'log-sigma-1-0-mm-3D_firstorder_Median',
#        ...
#        'log-sigma-3-0-mm-3D_gldm_LowGrayLevelEmphasis',
#        'log-sigma-3-0-mm-3D_gldm_SmallDependenceEmphasis',
#        'log-sigma-3-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis',
#        'log-sigma-3-0-mm-3D_gldm_SmallDependenceLowGrayLevelEmphasis',
#        'log-sigma-3-0-mm-3D_ngtdm_Busyness',
#        'log-sigma-3-0-mm-3D_ngtdm_Coarseness',
#        'log-sigma-3-0-mm-3D_ngtdm_Complexity',
#        'log-sigma-3-0-mm-3D_ngtdm_Contrast',
#        'log-sigma-3-0-mm-3D_ngtdm_Strength', 'Label'],
#       dtype='object', length=271)

# %%
data_real = data.replace(np.inf, np.nan)

# %%
data_real.isnull().sum().sum()
# Out:
# 0

# %%
data_df = data_real.dropna(axis=0)

# %%
data_df.isnull().sum().sum()
# Out:
# 0

# %%
data_df
# Out:
#      log-sigma-1-0-mm-3D_firstorder_10Percentile  \
# 0                                     -98.358093
# 1                                    -111.005576
# 2                                     -69.277760
# 3                                     -40.055520
# 4                                    -114.916722
# ..                                           ...
# 242                                   -32.333915
# 243                                   -45.553889
# 244                                   -38.180711
# 245                                   -29.717411
# 246                                   -29.717411
#
#      log-sigma-1-0-mm-3D_firstorder_90Percentile  \
# 0                                      66.171655
# 1                                      69.290557
# 2                                      21.564113
# 3                                      34.087923
# 4                                      61.713702
# ..                                           ...
# 242                                    22.054099
# 243                                    23.429811
# 244                                    28.584384
# 245                                    27.484397
# 246                                    27.484397
#
#      log-sigma-1-0-mm-3D_firstorder_Energy  \
# 0                             5.947318e+09
# 1                             2.151458e+09
# 2                             5.366198e+09
# 3                             1.782852e+09
# 4                             6.068749e+09
# ..                                     ...
# 242                           3.210097e+10
# 243                           1.652287e+09
# 244                           1.773794e+08
# 245                           9.495314e+08
# 246                           9.495314e+08
#
#      log-sigma-1-0-mm-3D_firstorder_Entropy  \
# 0                                  4.679830
# 1                                  4.793845
# 2                                  3.847705
# 3                                  3.708007
# 4                                  4.889442
# ..                                      ...
# 242                                3.369245
# 243                                3.593636
# 244                                3.508159
# 245                                3.342546
# 246                                3.342546
#
#      log-sigma-1-0-mm-3D_firstorder_InterquartileRange  \
# 0                                            59.053851
# 1                                            61.418368
# 2                                            33.577361
# 3                                            37.391896
# 4                                            69.082676
# ..                                                 ...
# 242                                          24.348059
# 243                                          33.160039
# 244                                          30.947919
# 245                                          26.520177
# 246                                          26.520177
#
#      log-sigma-1-0-mm-3D_firstorder_Kurtosis  \
# 0                                   6.661496
# 1                                   6.986314
# 2                                   7.320895
# 3                                  13.030340
# 4                                   6.349671
# ..                                       ...
# 242                                14.635831
# 243                                11.533548
# 244                                11.622763
# 245                                 7.789973
# 246                                 7.789973
#
#      log-sigma-1-0-mm-3D_firstorder_Maximum  \
# 0                                441.051544
# 1                                328.737396
# 2                                245.699371
# 3                                102.869247
# 4                                560.478882
# ..                                      ...
# 242                              243.547989
# 243                               80.350250
# 244                               71.404167
# 245                              104.165237
# 246                              104.165237
#
#      log-sigma-1-0-mm-3D_firstorder_Mean  \
# 0                              -6.952052
# 1                             -10.220715
# 2                             -13.011240
# 3                              -5.229649
# 4                             -13.823335
# ..                                   ...
# 242                            -5.985403
# 243                           -11.058552
# 244                           -13.890952
# 245                            -2.209538
# 246                            -2.209538
#
#      log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation  \
# 0                                            49.282723
# 1                                            55.934075
# 2                                            29.126174
# 3                                            25.811452
# 4                                            56.886949
# ..                                                 ...
# 242                                          20.983807
# 243                                          24.944843
# 244                                          27.254898
# 245                                          19.329296
# 246                                          19.329296
#
#      log-sigma-1-0-mm-3D_firstorder_Median  ...  \
# 0                                -0.191278  ...
# 1                                 0.297575  ...
# 2                                -6.232993  ...
# 3                                -1.417206  ...
# 4                                -8.866863  ...
# ..                                     ...  ...
# 242                              -1.562214  ...
# 243                              -4.237140  ...
# 244                              -7.273188  ...
# 245                              -2.596973  ...
# 246                              -2.596973  ...
#
#      log-sigma-3-0-mm-3D_gldm_LowGrayLevelEmphasis  \
# 0                                         0.001765
# 1                                         0.000902
# 2                                         0.001998
# 3                                         0.004308
# 4                                         0.001260
# ..                                             ...
# 242                                       0.001170
# 243                                       0.003544
# 244                                       0.017139
# 245                                       0.003587
# 246                                       0.003587
#
#      log-sigma-3-0-mm-3D_gldm_SmallDependenceEmphasis  \
# 0                                            0.370667
# 1                                            0.357667
# 2                                            0.251514
# 3                                            0.231473
# 4                                            0.349570
# ..                                                ...
# 242                                          0.157893
# 243                                          0.279485
# 244                                          0.383158
# 245                                          0.208701
# 246                                          0.208701
#
#      log-sigma-3-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                           487.629352
# 1                                          1047.619053
# 2                                           248.918861
# 3                                           134.824489
# 4                                           552.458032
# ..                                                 ...
# 242                                         160.494121
# 243                                         164.288447
# 244                                         123.911514
# 245                                         129.780672
# 246                                         129.780672
#
#      log-sigma-3-0-mm-3D_gldm_SmallDependenceLowGrayLevelEmphasis  \
# 0                                             0.000762
# 1                                             0.000648
# 2                                             0.000679
# 3                                             0.001294
# 4                                             0.000613
# ..                                                 ...
# 242                                           0.000265
# 243                                           0.001896
# 244                                           0.009912
# 245                                           0.001880
# 246                                           0.001880
#
#      log-sigma-3-0-mm-3D_ngtdm_Busyness  log-sigma-3-0-mm-3D_ngtdm_Coarseness  \
# 0                              0.144805                              0.002671
# 1                              0.025551                              0.006234
# 2                              0.155728                              0.002805
# 3                              0.069851                              0.009397
# 4                              0.095826                              0.002587
# ..                                  ...                                   ...
# 242                            0.548607                              0.000557
# 243                            0.076818                              0.010919
# 244                            0.038624                              0.059153
# 245                            0.060836                              0.015259
# 246                            0.060836                              0.015259
#
#      log-sigma-3-0-mm-3D_ngtdm_Complexity  log-sigma-3-0-mm-3D_ngtdm_Contrast  \
# 0                             4149.015711                            0.136159
# 1                             8132.626677                            0.084016
# 2                             2821.611332                            0.080914
# 3                              965.235995                            0.079924
# 4                             7833.104283                            0.085867
# ..                                    ...                                 ...
# 242                           2390.278232                            0.027154
# 243                           1198.041902                            0.173265
# 244                            721.107863                            0.288703
# 245                            777.194979                            0.080927
# 246                            777.194979                            0.080927
#
#      log-sigma-3-0-mm-3D_ngtdm_Strength         Label
# 0                              3.679598  'large cell'
# 1                             21.822374  'large cell'
# 2                              3.581366  'large cell'
# 3                              7.691174  'large cell'
# 4                              6.501620  'large cell'
# ..                                  ...           ...
# 242                            1.317583        others
# 243                            7.173603        others
# 244                           18.428371        others
# 245                            9.812313        others
# 246                            9.812313        others
#
# [247 rows x 271 columns]

# %%
data_X = data_df.drop(['Label'], axis = 1)

# %%
data_X.columns
# Out:
# Index(['log-sigma-1-0-mm-3D_firstorder_10Percentile',
#        'log-sigma-1-0-mm-3D_firstorder_90Percentile',
#        'log-sigma-1-0-mm-3D_firstorder_Energy',
#        'log-sigma-1-0-mm-3D_firstorder_Entropy',
#        'log-sigma-1-0-mm-3D_firstorder_InterquartileRange',
#        'log-sigma-1-0-mm-3D_firstorder_Kurtosis',
#        'log-sigma-1-0-mm-3D_firstorder_Maximum',
#        'log-sigma-1-0-mm-3D_firstorder_Mean',
#        'log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation',
#        'log-sigma-1-0-mm-3D_firstorder_Median',
#        ...
#        'log-sigma-3-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis',
#        'log-sigma-3-0-mm-3D_gldm_LowGrayLevelEmphasis',
#        'log-sigma-3-0-mm-3D_gldm_SmallDependenceEmphasis',
#        'log-sigma-3-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis',
#        'log-sigma-3-0-mm-3D_gldm_SmallDependenceLowGrayLevelEmphasis',
#        'log-sigma-3-0-mm-3D_ngtdm_Busyness',
#        'log-sigma-3-0-mm-3D_ngtdm_Coarseness',
#        'log-sigma-3-0-mm-3D_ngtdm_Complexity',
#        'log-sigma-3-0-mm-3D_ngtdm_Contrast',
#        'log-sigma-3-0-mm-3D_ngtdm_Strength'],
#       dtype='object', length=270)

# %%
data_X.shape
# Out:
# (247, 270)

# %%
data_y = data_df['Label']

# %%
data_y.shape
# Out:
# (247,)

# %%
data_df.isnull().sum().sum()
# Out:
# 0

# %%
data_y.unique()
# Out:
# array(["'large cell'", "'squamous cell carcinoma'", 'adenocarcinoma',
#        'others'], dtype=object)

# %%
data_X
# Out:
#      log-sigma-1-0-mm-3D_firstorder_10Percentile  \
# 0                                     -98.358093
# 1                                    -111.005576
# 2                                     -69.277760
# 3                                     -40.055520
# 4                                    -114.916722
# ..                                           ...
# 242                                   -32.333915
# 243                                   -45.553889
# 244                                   -38.180711
# 245                                   -29.717411
# 246                                   -29.717411
#
#      log-sigma-1-0-mm-3D_firstorder_90Percentile  \
# 0                                      66.171655
# 1                                      69.290557
# 2                                      21.564113
# 3                                      34.087923
# 4                                      61.713702
# ..                                           ...
# 242                                    22.054099
# 243                                    23.429811
# 244                                    28.584384
# 245                                    27.484397
# 246                                    27.484397
#
#      log-sigma-1-0-mm-3D_firstorder_Energy  \
# 0                             5.947318e+09
# 1                             2.151458e+09
# 2                             5.366198e+09
# 3                             1.782852e+09
# 4                             6.068749e+09
# ..                                     ...
# 242                           3.210097e+10
# 243                           1.652287e+09
# 244                           1.773794e+08
# 245                           9.495314e+08
# 246                           9.495314e+08
#
#      log-sigma-1-0-mm-3D_firstorder_Entropy  \
# 0                                  4.679830
# 1                                  4.793845
# 2                                  3.847705
# 3                                  3.708007
# 4                                  4.889442
# ..                                      ...
# 242                                3.369245
# 243                                3.593636
# 244                                3.508159
# 245                                3.342546
# 246                                3.342546
#
#      log-sigma-1-0-mm-3D_firstorder_InterquartileRange  \
# 0                                            59.053851
# 1                                            61.418368
# 2                                            33.577361
# 3                                            37.391896
# 4                                            69.082676
# ..                                                 ...
# 242                                          24.348059
# 243                                          33.160039
# 244                                          30.947919
# 245                                          26.520177
# 246                                          26.520177
#
#      log-sigma-1-0-mm-3D_firstorder_Kurtosis  \
# 0                                   6.661496
# 1                                   6.986314
# 2                                   7.320895
# 3                                  13.030340
# 4                                   6.349671
# ..                                       ...
# 242                                14.635831
# 243                                11.533548
# 244                                11.622763
# 245                                 7.789973
# 246                                 7.789973
#
#      log-sigma-1-0-mm-3D_firstorder_Maximum  \
# 0                                441.051544
# 1                                328.737396
# 2                                245.699371
# 3                                102.869247
# 4                                560.478882
# ..                                      ...
# 242                              243.547989
# 243                               80.350250
# 244                               71.404167
# 245                              104.165237
# 246                              104.165237
#
#      log-sigma-1-0-mm-3D_firstorder_Mean  \
# 0                              -6.952052
# 1                             -10.220715
# 2                             -13.011240
# 3                              -5.229649
# 4                             -13.823335
# ..                                   ...
# 242                            -5.985403
# 243                           -11.058552
# 244                           -13.890952
# 245                            -2.209538
# 246                            -2.209538
#
#      log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation  \
# 0                                            49.282723
# 1                                            55.934075
# 2                                            29.126174
# 3                                            25.811452
# 4                                            56.886949
# ..                                                 ...
# 242                                          20.983807
# 243                                          24.944843
# 244                                          27.254898
# 245                                          19.329296
# 246                                          19.329296
#
#      log-sigma-1-0-mm-3D_firstorder_Median  ...  \
# 0                                -0.191278  ...
# 1                                 0.297575  ...
# 2                                -6.232993  ...
# 3                                -1.417206  ...
# 4                                -8.866863  ...
# ..                                     ...  ...
# 242                              -1.562214  ...
# 243                              -4.237140  ...
# 244                              -7.273188  ...
# 245                              -2.596973  ...
# 246                              -2.596973  ...
#
#      log-sigma-3-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis  \
# 0                                             0.011625
# 1                                             0.005178
# 2                                             0.046034
# 3                                             0.054809
# 4                                             0.018770
# ..                                                 ...
# 242                                           0.062420
# 243                                           0.032742
# 244                                           0.087701
# 245                                           0.036964
# 246                                           0.036964
#
#      log-sigma-3-0-mm-3D_gldm_LowGrayLevelEmphasis  \
# 0                                         0.001765
# 1                                         0.000902
# 2                                         0.001998
# 3                                         0.004308
# 4                                         0.001260
# ..                                             ...
# 242                                       0.001170
# 243                                       0.003544
# 244                                       0.017139
# 245                                       0.003587
# 246                                       0.003587
#
#      log-sigma-3-0-mm-3D_gldm_SmallDependenceEmphasis  \
# 0                                            0.370667
# 1                                            0.357667
# 2                                            0.251514
# 3                                            0.231473
# 4                                            0.349570
# ..                                                ...
# 242                                          0.157893
# 243                                          0.279485
# 244                                          0.383158
# 245                                          0.208701
# 246                                          0.208701
#
#      log-sigma-3-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                           487.629352
# 1                                          1047.619053
# 2                                           248.918861
# 3                                           134.824489
# 4                                           552.458032
# ..                                                 ...
# 242                                         160.494121
# 243                                         164.288447
# 244                                         123.911514
# 245                                         129.780672
# 246                                         129.780672
#
#      log-sigma-3-0-mm-3D_gldm_SmallDependenceLowGrayLevelEmphasis  \
# 0                                             0.000762
# 1                                             0.000648
# 2                                             0.000679
# 3                                             0.001294
# 4                                             0.000613
# ..                                                 ...
# 242                                           0.000265
# 243                                           0.001896
# 244                                           0.009912
# 245                                           0.001880
# 246                                           0.001880
#
#      log-sigma-3-0-mm-3D_ngtdm_Busyness  log-sigma-3-0-mm-3D_ngtdm_Coarseness  \
# 0                              0.144805                              0.002671
# 1                              0.025551                              0.006234
# 2                              0.155728                              0.002805
# 3                              0.069851                              0.009397
# 4                              0.095826                              0.002587
# ..                                  ...                                   ...
# 242                            0.548607                              0.000557
# 243                            0.076818                              0.010919
# 244                            0.038624                              0.059153
# 245                            0.060836                              0.015259
# 246                            0.060836                              0.015259
#
#      log-sigma-3-0-mm-3D_ngtdm_Complexity  log-sigma-3-0-mm-3D_ngtdm_Contrast  \
# 0                             4149.015711                            0.136159
# 1                             8132.626677                            0.084016
# 2                             2821.611332                            0.080914
# 3                              965.235995                            0.079924
# 4                             7833.104283                            0.085867
# ..                                    ...                                 ...
# 242                           2390.278232                            0.027154
# 243                           1198.041902                            0.173265
# 244                            721.107863                            0.288703
# 245                            777.194979                            0.080927
# 246                            777.194979                            0.080927
#
#      log-sigma-3-0-mm-3D_ngtdm_Strength
# 0                              3.679598
# 1                             21.822374
# 2                              3.581366
# 3                              7.691174
# 4                              6.501620
# ..                                  ...
# 242                            1.317583
# 243                            7.173603
# 244                           18.428371
# 245                            9.812313
# 246                            9.812313
#
# [247 rows x 270 columns]

# %% [markdown]
# Label encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data_y_trans = le.fit_transform(data_y)

# %%
data_X
# Out:
#      log-sigma-1-0-mm-3D_firstorder_10Percentile  \
# 0                                     -98.358093
# 1                                    -111.005576
# 2                                     -69.277760
# 3                                     -40.055520
# 4                                    -114.916722
# ..                                           ...
# 242                                   -32.333915
# 243                                   -45.553889
# 244                                   -38.180711
# 245                                   -29.717411
# 246                                   -29.717411
#
#      log-sigma-1-0-mm-3D_firstorder_90Percentile  \
# 0                                      66.171655
# 1                                      69.290557
# 2                                      21.564113
# 3                                      34.087923
# 4                                      61.713702
# ..                                           ...
# 242                                    22.054099
# 243                                    23.429811
# 244                                    28.584384
# 245                                    27.484397
# 246                                    27.484397
#
#      log-sigma-1-0-mm-3D_firstorder_Energy  \
# 0                             5.947318e+09
# 1                             2.151458e+09
# 2                             5.366198e+09
# 3                             1.782852e+09
# 4                             6.068749e+09
# ..                                     ...
# 242                           3.210097e+10
# 243                           1.652287e+09
# 244                           1.773794e+08
# 245                           9.495314e+08
# 246                           9.495314e+08
#
#      log-sigma-1-0-mm-3D_firstorder_Entropy  \
# 0                                  4.679830
# 1                                  4.793845
# 2                                  3.847705
# 3                                  3.708007
# 4                                  4.889442
# ..                                      ...
# 242                                3.369245
# 243                                3.593636
# 244                                3.508159
# 245                                3.342546
# 246                                3.342546
#
#      log-sigma-1-0-mm-3D_firstorder_InterquartileRange  \
# 0                                            59.053851
# 1                                            61.418368
# 2                                            33.577361
# 3                                            37.391896
# 4                                            69.082676
# ..                                                 ...
# 242                                          24.348059
# 243                                          33.160039
# 244                                          30.947919
# 245                                          26.520177
# 246                                          26.520177
#
#      log-sigma-1-0-mm-3D_firstorder_Kurtosis  \
# 0                                   6.661496
# 1                                   6.986314
# 2                                   7.320895
# 3                                  13.030340
# 4                                   6.349671
# ..                                       ...
# 242                                14.635831
# 243                                11.533548
# 244                                11.622763
# 245                                 7.789973
# 246                                 7.789973
#
#      log-sigma-1-0-mm-3D_firstorder_Maximum  \
# 0                                441.051544
# 1                                328.737396
# 2                                245.699371
# 3                                102.869247
# 4                                560.478882
# ..                                      ...
# 242                              243.547989
# 243                               80.350250
# 244                               71.404167
# 245                              104.165237
# 246                              104.165237
#
#      log-sigma-1-0-mm-3D_firstorder_Mean  \
# 0                              -6.952052
# 1                             -10.220715
# 2                             -13.011240
# 3                              -5.229649
# 4                             -13.823335
# ..                                   ...
# 242                            -5.985403
# 243                           -11.058552
# 244                           -13.890952
# 245                            -2.209538
# 246                            -2.209538
#
#      log-sigma-1-0-mm-3D_firstorder_MeanAbsoluteDeviation  \
# 0                                            49.282723
# 1                                            55.934075
# 2                                            29.126174
# 3                                            25.811452
# 4                                            56.886949
# ..                                                 ...
# 242                                          20.983807
# 243                                          24.944843
# 244                                          27.254898
# 245                                          19.329296
# 246                                          19.329296
#
#      log-sigma-1-0-mm-3D_firstorder_Median  ...  \
# 0                                -0.191278  ...
# 1                                 0.297575  ...
# 2                                -6.232993  ...
# 3                                -1.417206  ...
# 4                                -8.866863  ...
# ..                                     ...  ...
# 242                              -1.562214  ...
# 243                              -4.237140  ...
# 244                              -7.273188  ...
# 245                              -2.596973  ...
# 246                              -2.596973  ...
#
#      log-sigma-3-0-mm-3D_gldm_LargeDependenceLowGrayLevelEmphasis  \
# 0                                             0.011625
# 1                                             0.005178
# 2                                             0.046034
# 3                                             0.054809
# 4                                             0.018770
# ..                                                 ...
# 242                                           0.062420
# 243                                           0.032742
# 244                                           0.087701
# 245                                           0.036964
# 246                                           0.036964
#
#      log-sigma-3-0-mm-3D_gldm_LowGrayLevelEmphasis  \
# 0                                         0.001765
# 1                                         0.000902
# 2                                         0.001998
# 3                                         0.004308
# 4                                         0.001260
# ..                                             ...
# 242                                       0.001170
# 243                                       0.003544
# 244                                       0.017139
# 245                                       0.003587
# 246                                       0.003587
#
#      log-sigma-3-0-mm-3D_gldm_SmallDependenceEmphasis  \
# 0                                            0.370667
# 1                                            0.357667
# 2                                            0.251514
# 3                                            0.231473
# 4                                            0.349570
# ..                                                ...
# 242                                          0.157893
# 243                                          0.279485
# 244                                          0.383158
# 245                                          0.208701
# 246                                          0.208701
#
#      log-sigma-3-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                           487.629352
# 1                                          1047.619053
# 2                                           248.918861
# 3                                           134.824489
# 4                                           552.458032
# ..                                                 ...
# 242                                         160.494121
# 243                                         164.288447
# 244                                         123.911514
# 245                                         129.780672
# 246                                         129.780672
#
#      log-sigma-3-0-mm-3D_gldm_SmallDependenceLowGrayLevelEmphasis  \
# 0                                             0.000762
# 1                                             0.000648
# 2                                             0.000679
# 3                                             0.001294
# 4                                             0.000613
# ..                                                 ...
# 242                                           0.000265
# 243                                           0.001896
# 244                                           0.009912
# 245                                           0.001880
# 246                                           0.001880
#
#      log-sigma-3-0-mm-3D_ngtdm_Busyness  log-sigma-3-0-mm-3D_ngtdm_Coarseness  \
# 0                              0.144805                              0.002671
# 1                              0.025551                              0.006234
# 2                              0.155728                              0.002805
# 3                              0.069851                              0.009397
# 4                              0.095826                              0.002587
# ..                                  ...                                   ...
# 242                            0.548607                              0.000557
# 243                            0.076818                              0.010919
# 244                            0.038624                              0.059153
# 245                            0.060836                              0.015259
# 246                            0.060836                              0.015259
#
#      log-sigma-3-0-mm-3D_ngtdm_Complexity  log-sigma-3-0-mm-3D_ngtdm_Contrast  \
# 0                             4149.015711                            0.136159
# 1                             8132.626677                            0.084016
# 2                             2821.611332                            0.080914
# 3                              965.235995                            0.079924
# 4                             7833.104283                            0.085867
# ..                                    ...                                 ...
# 242                           2390.278232                            0.027154
# 243                           1198.041902                            0.173265
# 244                            721.107863                            0.288703
# 245                            777.194979                            0.080927
# 246                            777.194979                            0.080927
#
#      log-sigma-3-0-mm-3D_ngtdm_Strength
# 0                              3.679598
# 1                             21.822374
# 2                              3.581366
# 3                              7.691174
# 4                              6.501620
# ..                                  ...
# 242                            1.317583
# 243                            7.173603
# 244                           18.428371
# 245                            9.812313
# 246                            9.812313
#
# [247 rows x 270 columns]

# %%
df2 = pd.DataFrame(data_X)

# %%
df2.to_csv(r'my_data.csv', index=False)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test = train_test_split(data_X, data_y_trans, train_size = 0.7)

# %%
from sklearn.preprocessing import StandardScaler 
ss = StandardScaler()
X_train_std = ss.fit_transform(X_train)
X_test_std = ss.fit_transform(X_test)

# %% [markdown]
# FEATURE SELECTION

# %%
from sklearn.feature_selection import chi2 
from sklearn.feature_selection import SelectKBest 
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
                     criterion='gini', max_depth=None, max_features='auto',
                     max_leaf_nodes=None, max_samples=None,
                     min_impurity_decrease=0.0, 
                     min_samples_leaf=1, min_samples_split=2,
                     min_weight_fraction_leaf=0.0, n_estimators=100,
                     n_jobs=None, oob_score=False, random_state=42, verbose=0,
                     warm_start=False)

model.fit(data_X, data_y_trans)
# Out:
# ExtraTreesClassifier(random_state=42)

# %%
model.feature_importances_
# Out:
# array([0.00534586, 0.00414486, 0.00335208, 0.00343764, 0.00322224,
#        0.00735209, 0.00329546, 0.00434736, 0.00397055, 0.00471431,
#        0.00433271, 0.00784441, 0.00411561, 0.00594972, 0.0058641 ,
#        0.0044566 , 0.00346188, 0.00169338, 0.0048543 , 0.00477973,
#        0.00748859, 0.00197696, 0.00195728, 0.00389686, 0.00333596,
#        0.00195314, 0.00279301, 0.00543466, 0.00343719, 0.0020759 ,
#        0.00266826, 0.0029896 , 0.00293641, 0.00435481, 0.00231877,
#        0.00434109, 0.00302544, 0.00342743, 0.00316818, 0.0043963 ,
#        0.0035355 , 0.0037102 , 0.00349125, 0.00241074, 0.00297625,
#        0.00272074, 0.00324727, 0.00352849, 0.00376421, 0.00351759,
#        0.00350246, 0.00540607, 0.00331858, 0.00185521, 0.00261372,
#        0.00666118, 0.0061047 , 0.00465823, 0.00345756, 0.00364803,
#        0.0041931 , 0.00291657, 0.00276181, 0.00374416, 0.0053622 ,
#        0.0047515 , 0.00429416, 0.00303093, 0.003955  , 0.00323756,
#        0.0044857 , 0.00461065, 0.00347444, 0.00412759, 0.00166228,
#        0.0070503 , 0.00296512, 0.0057352 , 0.0036015 , 0.00344429,
#        0.00399696, 0.00412073, 0.00386171, 0.00413579, 0.00263179,
#        0.00444812, 0.00424869, 0.00248307, 0.00425494, 0.00352584,
#        0.00355412, 0.00380999, 0.00356628, 0.00444332, 0.00278122,
#        0.00422751, 0.00447224, 0.00287364, 0.00357583, 0.0038247 ,
#        0.00288295, 0.00502764, 0.00395379, 0.00408901, 0.00364461,
#        0.00298415, 0.00284517, 0.00363161, 0.00470805, 0.00289404,
#        0.00330811, 0.00320549, 0.00234992, 0.00331747, 0.00299396,
#        0.00341014, 0.0037721 , 0.00328079, 0.00313265, 0.00377055,
#        0.005074  , 0.00281783, 0.00369135, 0.00315636, 0.00402383,
#        0.0017913 , 0.0023983 , 0.00315554, 0.00342943, 0.00600091,
#        0.00208718, 0.00344797, 0.00473593, 0.00226557, 0.00434784,
#        0.00336948, 0.0026322 , 0.00561186, 0.00285736, 0.00343461,
#        0.00192702, 0.00248679, 0.00435317, 0.00345869, 0.00373362,
#        0.00872068, 0.00273629, 0.00339608, 0.00363223, 0.00336065,
#        0.0038611 , 0.00272797, 0.00368742, 0.00455223, 0.00270006,
#        0.00532282, 0.00370605, 0.00453512, 0.00373201, 0.00213645,
#        0.00248677, 0.00523307, 0.00436456, 0.00299729, 0.00418192,
#        0.00280134, 0.00444413, 0.00312835, 0.00443898, 0.0039647 ,
#        0.00357921, 0.00420515, 0.00177632, 0.0060613 , 0.00375661,
#        0.00486111, 0.00377532, 0.00225887, 0.00544873, 0.00260291,
#        0.00370147, 0.00353914, 0.00290443, 0.00371941, 0.00404552,
#        0.00521286, 0.00396634, 0.00291767, 0.00503901, 0.00362089,
#        0.00198036, 0.0046526 , 0.00185851, 0.00429634, 0.00332034,
#        0.00342816, 0.0027339 , 0.00296334, 0.00286456, 0.0043501 ,
#        0.00377185, 0.00324697, 0.00210972, 0.00402751, 0.00378834,
#        0.00285171, 0.00271876, 0.00426971, 0.00225259, 0.00392838,
#        0.00657508, 0.00320854, 0.0052298 , 0.00285891, 0.00384048,
#        0.00388637, 0.00325097, 0.0037652 , 0.00296343, 0.00450381,
#        0.00323912, 0.00405922, 0.00322055, 0.00186174, 0.0050644 ,
#        0.00293064, 0.00402803, 0.00361707, 0.00442423, 0.00243944,
#        0.00278648, 0.00405398, 0.00231243, 0.00360151, 0.00437728,
#        0.00483591, 0.00191113, 0.00522585, 0.00365876, 0.00508408,
#        0.00430754, 0.00447467, 0.0031263 , 0.00371727, 0.00394862,
#        0.00536303, 0.00320808, 0.00386542, 0.00443738, 0.00326189,
#        0.0019014 , 0.00244874, 0.00387457, 0.00349463, 0.00266839,
#        0.00337118, 0.00191324, 0.00286407, 0.00176408, 0.0049463 ,
#        0.00302762, 0.0031361 , 0.00194273, 0.00457676, 0.00385666,
#        0.00560221, 0.00261778, 0.00534948, 0.00309494, 0.0034006 ])

# %%
feature_importance_std = pd.Series(model.feature_importances_, index=data_X.columns)
feature_importance_std.nlargest(20).plot(kind='bar', title='Standardised Dataset Feature Selection using ExtraTreesClassifier')

# %%
feature_importance_std.nlargest(20)
# Out:
# log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformity                 0.008721
# log-sigma-1-0-mm-3D_firstorder_Range                             0.007844
# log-sigma-1-0-mm-3D_glcm_ClusterShade                            0.007489
# log-sigma-1-0-mm-3D_firstorder_Kurtosis                          0.007352
# log-sigma-1-0-mm-3D_gldm_GrayLevelNonUniformity                  0.007050
# log-sigma-1-0-mm-3D_glszm_GrayLevelNonUniformity                 0.006661
# log-sigma-3-0-mm-3D_glcm_Imc2                                    0.006575
# log-sigma-1-0-mm-3D_glszm_GrayLevelNonUniformityNormalized       0.006105
# log-sigma-2-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis    0.006061
# log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformity                 0.006001
# log-sigma-1-0-mm-3D_firstorder_RootMeanSquared                   0.005950
# log-sigma-1-0-mm-3D_firstorder_Skewness                          0.005864
# log-sigma-1-0-mm-3D_gldm_HighGrayLevelEmphasis                   0.005735
# log-sigma-2-0-mm-3D_glrlm_RunEntropy                             0.005612
# log-sigma-3-0-mm-3D_ngtdm_Busyness                               0.005602
# log-sigma-2-0-mm-3D_ngtdm_Contrast                               0.005449
# log-sigma-1-0-mm-3D_glcm_JointEnergy                             0.005435
# log-sigma-1-0-mm-3D_glrlm_RunVariance                            0.005406
# log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis                      0.005363
# log-sigma-1-0-mm-3D_glszm_SizeZoneNonUniformityNormalized        0.005362
# dtype: float64

# %%
data_new_20features_X = data_X[['log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_Range', 'log-sigma-1-0-mm-3D_glcm_ClusterShade', 'log-sigma-1-0-mm-3D_firstorder_Kurtosis', 'log-sigma-1-0-mm-3D_gldm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_glszm_GrayLevelNonUniformity', 'log-sigma-3-0-mm-3D_glcm_Imc2', 'log-sigma-1-0-mm-3D_glszm_GrayLevelNonUniformityNormalized', 'log-sigma-2-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformity', 'log-sigma-1-0-mm-3D_firstorder_RootMeanSquared', 'log-sigma-1-0-mm-3D_firstorder_Skewness', 'log-sigma-1-0-mm-3D_gldm_HighGrayLevelEmphasis', 'log-sigma-2-0-mm-3D_glrlm_RunEntropy', 'log-sigma-3-0-mm-3D_ngtdm_Busyness', 'log-sigma-2-0-mm-3D_ngtdm_Contrast', 'log-sigma-1-0-mm-3D_glcm_JointEnergy', 'log-sigma-1-0-mm-3D_glrlm_RunVariance', 'log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis', 'log-sigma-1-0-mm-3D_glszm_SizeZoneNonUniformityNormalized']]

# %%
data_new_20features_X
# Out:
#      log-sigma-2-0-mm-3D_glszm_GrayLevelNonUniformity  \
# 0                                           68.792708
# 1                                           29.131048
# 2                                           50.389531
# 3                                           18.679634
# 4                                           59.270791
# ..                                                ...
# 242                                        179.463396
# 243                                         16.681529
# 244                                          3.486486
# 245                                         11.558559
# 246                                         11.558559
#
#      log-sigma-1-0-mm-3D_firstorder_Range  \
# 0                              949.676941
# 1                              838.579864
# 2                              486.600967
# 3                              413.468674
# 4                              924.450714
# ..                                    ...
# 242                            564.503647
# 243                            363.548859
# 244                            295.968636
# 245                            259.566711
# 246                            259.566711
#
#      log-sigma-1-0-mm-3D_glcm_ClusterShade  \
# 0                              -570.809165
# 1                             -2721.374606
# 2                              -168.649093
# 3                              -289.306340
# 4                               269.355961
# ..                                     ...
# 242                            -288.533610
# 243                            -324.433789
# 244                            -770.927810
# 245                             -38.394322
# 246                             -38.394322
#
#      log-sigma-1-0-mm-3D_firstorder_Kurtosis  \
# 0                                   6.661496
# 1                                   6.986314
# 2                                   7.320895
# 3                                  13.030340
# 4                                   6.349671
# ..                                       ...
# 242                                14.635831
# 243                                11.533548
# 244                                11.622763
# 245                                 7.789973
# 246                                 7.789973
#
#      log-sigma-1-0-mm-3D_gldm_GrayLevelNonUniformity  \
# 0                                         348.309885
# 1                                         119.275229
# 2                                         575.598763
# 3                                         174.993330
# 4                                         304.079903
# ..                                               ...
# 242                                      4569.225407
# 243                                       186.106106
# 244                                        20.879121
# 245                                       122.183631
# 246                                       122.183631
#
#      log-sigma-1-0-mm-3D_glszm_GrayLevelNonUniformity  \
# 0                                           74.848142
# 1                                           38.046429
# 2                                           62.634286
# 3                                           42.436533
# 4                                           89.982724
# ..                                                ...
# 242                                        360.566319
# 243                                         25.188119
# 244                                          4.475410
# 245                                         16.991266
# 246                                         16.991266
#
#      log-sigma-3-0-mm-3D_glcm_Imc2  \
# 0                         0.903676
# 1                         0.963817
# 2                         0.935471
# 3                         0.955818
# 4                         0.914868
# ..                             ...
# 242                       0.940899
# 243                       0.958585
# 244                       0.989074
# 245                       0.939828
# 246                       0.939828
#
#      log-sigma-1-0-mm-3D_glszm_GrayLevelNonUniformityNormalized  \
# 0                                             0.030229
# 1                                             0.033970
# 2                                             0.044739
# 3                                             0.065691
# 4                                             0.029895
# ..                                                 ...
# 242                                           0.062598
# 243                                           0.062347
# 244                                           0.073367
# 245                                           0.074198
# 246                                           0.074198
#
#      log-sigma-2-0-mm-3D_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                           564.197301
# 1                                           984.931867
# 2                                           141.215803
# 3                                           227.685648
# 4                                           728.466056
# ..                                                 ...
# 242                                         124.727795
# 243                                         113.012488
# 244                                         106.894448
# 245                                         128.189875
# 246                                         128.189875
#
#      log-sigma-2-0-mm-3D_glrlm_GrayLevelNonUniformity  \
# 0                                          189.461498
# 1                                           82.625648
# 2                                          262.424754
# 3                                          144.131325
# 4                                          224.282718
# ..                                                ...
# 242                                       2179.402133
# 243                                         85.011584
# 244                                          8.884845
# 245                                         59.327570
# 246                                         59.327570
#
#      log-sigma-1-0-mm-3D_firstorder_RootMeanSquared  \
# 0                                        995.683159
# 1                                        993.432086
# 2                                        987.940945
# 3                                        995.501971
# 4                                        989.757802
# ..                                              ...
# 242                                      994.638080
# 243                                      989.658007
# 244                                      987.224346
# 245                                      998.178521
# 246                                      998.178521
#
#      log-sigma-1-0-mm-3D_firstorder_Skewness  \
# 0                                  -0.370839
# 1                                  -1.152248
# 2                                  -0.359027
# 3                                  -2.151546
# 4                                   0.302852
# ..                                       ...
# 242                                -1.999120
# 243                                -2.285986
# 244                                -2.589063
# 245                                -0.593056
# 246                                -0.593056
#
#      log-sigma-1-0-mm-3D_gldm_HighGrayLevelEmphasis  \
# 0                                       2633.519587
# 1                                       2621.119266
# 2                                        604.668607
# 3                                       1038.337410
# 4                                       1375.097175
# ..                                              ...
# 242                                     1095.004130
# 243                                      820.921162
# 244                                      512.494505
# 245                                      272.547744
# 246                                      272.547744
#
#      log-sigma-2-0-mm-3D_glrlm_RunEntropy  log-sigma-3-0-mm-3D_ngtdm_Busyness  \
# 0                                5.515441                            0.144805
# 1                                5.471503                            0.025551
# 2                                5.284852                            0.155728
# 3                                4.575431                            0.069851
# 4                                5.609005                            0.095826
# ..                                    ...                                 ...
# 242                              5.079065                            0.548607
# 243                              5.078001                            0.076818
# 244                              4.699625                            0.038624
# 245                              4.697823                            0.060836
# 246                              4.697823                            0.060836
#
#      log-sigma-2-0-mm-3D_ngtdm_Contrast  log-sigma-1-0-mm-3D_glcm_JointEnergy  \
# 0                              0.126967                              0.006368
# 1                              0.110736                              0.005523
# 2                              0.076783                              0.018287
# 3                              0.060300                              0.011260
# 4                              0.107094                              0.003754
# ..                                  ...                                   ...
# 242                            0.020544                              0.026492
# 243                            0.163884                              0.016112
# 244                            0.198881                              0.022468
# 245                            0.061450                              0.021604
# 246                            0.061450                              0.021604
#
#      log-sigma-1-0-mm-3D_glrlm_RunVariance  \
# 0                                 0.127635
# 1                                 0.084601
# 2                                 0.216328
# 3                                 0.090588
# 4                                 0.066033
# ..                                     ...
# 242                               0.250916
# 243                               0.151855
# 244                               0.142588
# 245                               0.173146
# 246                               0.173146
#
#      log-sigma-3-0-mm-3D_glszm_SmallAreaEmphasis  \
# 0                                       0.683104
# 1                                       0.686450
# 2                                       0.663421
# 3                                       0.636094
# 4                                       0.725298
# ..                                           ...
# 242                                     0.603906
# 243                                     0.648430
# 244                                     0.590853
# 245                                     0.544318
# 246                                     0.544318
#
#      log-sigma-1-0-mm-3D_glszm_SizeZoneNonUniformityNormalized
# 0                                             0.531908
# 1                                             0.558629
# 2                                             0.507263
# 3                                             0.426746
# 4                                             0.535056
# ..                                                 ...
# 242                                           0.461731
# 243                                           0.478384
# 244                                           0.429723
# 245                                           0.433039
# 246                                           0.433039
#
# [247 rows x 20 columns]

# %%
from sklearn.model_selection import train_test_split
X_train_20, X_test_20, y_train_20, y_test_20 = train_test_split(data_new_20features_X, data_y_trans, train_size = 0.8, random_state=22)

# %%
from sklearn.preprocessing import StandardScaler 
ss_20 = StandardScaler()
X_train_std_20 = ss_20.fit_transform(X_train_20)
X_test_std_20 = ss_20.fit_transform(X_test_20)

# %% [markdown]
# Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=56)
rf.fit(X_train_std_20, y_train_20)
# Out:
# RandomForestClassifier(random_state=56)

# %%
rf_y_pred = rf.predict(X_test_std_20)

# %%
from sklearn.metrics import accuracy_score

# %%
acc_score = accuracy_score(y_test_20, rf_y_pred)
print("Accuracy Score for Random_Forest: \n", acc_score*100)
# Out:
# Accuracy Score for Random_Forest:
#  86.0

# %%
from sklearn.metrics import classification_report 
from sklearn.metrics import confusion_matrix

# %%
print("Classification Report for Random Forest: \n", classification_report(y_test_20,rf_y_pred))
# Out:
# Classification Report for Random Forest:
#                precision    recall  f1-score   support
#
#            0       0.76      0.93      0.84        14
#            1       0.84      0.94      0.89        17
#            2       1.00      1.00      1.00         5
#            3       1.00      0.64      0.78        14
#
#     accuracy                           0.86        50
#    macro avg       0.90      0.88      0.88        50
# weighted avg       0.88      0.86      0.86        50

# %%
rf_conf_mat = confusion_matrix(y_test_20, rf_y_pred)
print("Random Forest Confusion: \n", rf_conf_mat)
# Out:
# Random Forest Confusion:
#  [[13  1  0  0]
#  [ 1 16  0  0]
#  [ 0  0  5  0]
#  [ 3  2  0  9]]

# %% [markdown]
# ROC Curve

# %%
def RoC_Curve(classifier, X_val, y_val, title): 
        """ RoC Curve for Classifier 
        Parameters: 
        ------------
        classifier: Machine Learning Classifier to be Evaluated
        X_val: Validation Dataset
        y_val: Label/Target of Validation Dataset

        Attributes:
        Plots the Graph    
        
        Note: Some part of this Method code is taken 
            from Sklearn Website
        """

        lw = 2
        n_classes = 3
        y_test1 = to_categorical(y_val)
        pred_RFC_proba = classifier.predict_proba(X_val)
        y_score = pred_RFC_proba

        # Compute ROC curve and ROC area for each class
        fpr = dict()
        tpr = dict()
        roc_auc = dict()
        for i in range(n_classes):
            fpr[i], tpr[i], _ = roc_curve(y_test1[:, i], y_score[:, i])
            roc_auc[i] = auc(fpr[i], tpr[i])

        # Compute micro-average ROC curve and ROC area
        fpr["micro"], tpr["micro"], _ = roc_curve(y_test1.ravel(), y_score.ravel())
        roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

        # First aggregate all false positive rates
        all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

        # Then interpolate all ROC curves at this points
        mean_tpr = np.zeros_like(all_fpr)
        for i in range(n_classes):
            mean_tpr += interp(all_fpr, fpr[i], tpr[i])

        # Finally average it and compute AUC
        mean_tpr /= n_classes

        fpr["macro"] = all_fpr
        tpr["macro"] = mean_tpr
        roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

        # Plot all ROC curves
        plt.figure(figsize=(20,10))
        plt.plot(fpr["micro"], tpr["micro"],
                label='micro-average ROC curve (area = {0:0.2f})'
                    ''.format(roc_auc["micro"]),
                color='deeppink', linestyle=':', linewidth=4)

        plt.plot(fpr["macro"], tpr["macro"],
                label='macro-average ROC curve (area = {0:0.2f})'
                    ''.format(roc_auc["macro"]),
                color='navy', linestyle=':', linewidth=4)

        list_class = ['adeno','squamous','other']
        for i in range(n_classes):
            plt.plot(fpr[i], tpr[i], lw=lw,
                    label='ROC curve of class {0} (area = {1:0.2f})'
                    ''.format(list_class[i], roc_auc[i]))

        plt.plot([0, 1], [0, 1], 'k--', lw=lw)
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title(title) 
        plt.legend(loc="lower right")
        plt.show()

# %%
from keras.utils.np_utils import to_categorical
from sklearn.metrics import roc_curve, auc
from scipy import interp
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt

# %%
title = 'Receiver operating characteristic of Random Forest'
RoC_Curve(rf, X_test_std_20, y_test_20, title)
# Out:
# <ipython-input-5350-3fa2d96845d8>:40: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# %% [markdown]
# XGBoost

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gradient_boost = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1,
max_depth=3, random_state=0)
gradient_boost.fit(X_train_std_20, y_train_20)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
res_xg=gradient_boost.predict(X_test_std_20)

# %%
acc_score_xg = accuracy_score(y_test_20, res_xg)
print("Accuracy Score for GradientBoosting: \n", acc_score_xg*100)
# Out:
# Accuracy Score for GradientBoosting:
#  76.0
