# %% [markdown]
# <a href="https://colab.research.google.com/github/FathimaNazarudeen/lung-cancer/blob/main/2nd%20dataset%20old.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_csv("/content/thirddatasetdata2 (1).csv")

# %%
data['Label'].value_counts()
# Out:
# adeno       42
# squamous    35
# other       12
# Name: Label, dtype: int64

# %%
data.columns
# Out:
# Index(['imaging.radiomics.GLCM_autocorr', 'imaging.radiomics.GLCM_clusProm',
#        'imaging.radiomics.GLCM_clusShade', 'imaging.radiomics.GLCM_clusTend',
#        'imaging.radiomics.GLCM_contrast', 'imaging.radiomics.GLCM_correl1',
#        'imaging.radiomics.GLCM_diffEntro', 'imaging.radiomics.GLCM_dissimilar',
#        'imaging.radiomics.GLCM_energy', 'imaging.radiomics.GLCM_entrop2',
#        ...
#        'imaging.radiomics.Wavelet_LLL_stats_median',
#        'imaging.radiomics.Wavelet_LLL_stats_min',
#        'imaging.radiomics.Wavelet_LLL_stats_range',
#        'imaging.radiomics.Wavelet_LLL_stats_rms',
#        'imaging.radiomics.Wavelet_LLL_stats_skewness',
#        'imaging.radiomics.Wavelet_LLL_stats_std',
#        'imaging.radiomics.Wavelet_LLL_stats_totalenergy',
#        'imaging.radiomics.Wavelet_LLL_stats_uniformity',
#        'imaging.radiomics.Wavelet_LLL_stats_var', 'Label'],
#       dtype='object', length=651)

# %%
data_real = data.replace(np.inf, np.nan)

# %%
data_real.isnull().sum().sum()
# Out:
# 0

# %%
data_df = data_real.dropna(axis=0)

# %%
data_df.isnull().sum().sum()
# Out:
# 0

# %%
data_df
# Out:
#     imaging.radiomics.GLCM_autocorr  imaging.radiomics.GLCM_clusProm  \
# 0                       1015.604377                     1.728441e+06
# 1                        921.867862                     6.464357e+04
# 2                        632.293653                     2.927069e+04
# 3                        768.887796                     1.016742e+04
# 4                        131.834572                     3.611580e+01
# ..                              ...                              ...
# 84                       603.054548                     3.314669e+05
# 85                      1726.367922                     4.040858e+04
# 86                       473.814975                     2.669862e+04
# 87                       404.275573                     2.867433e+04
# 88                       681.259465                     6.136644e+04
#
#     imaging.radiomics.GLCM_clusShade  imaging.radiomics.GLCM_clusTend  \
# 0                      -16203.786420                       995.351478
# 1                       -1855.872326                       111.303433
# 2                       -1068.132061                        84.292617
# 3                        -348.622125                        29.055416
# 4                          -2.013109                         2.503468
# ..                               ...                              ...
# 84                       1834.022542                       488.061895
# 85                       -874.026124                        31.988221
# 86                       -868.125572                        98.751127
# 87                       -707.032249                        93.849341
# 88                      -1530.954192                       134.468888
#
#     imaging.radiomics.GLCM_contrast  imaging.radiomics.GLCM_correl1  \
# 0                         22.221434                        0.957409
# 1                         24.812007                        0.630987
# 2                          7.278293                        0.839872
# 3                          6.021883                        0.658310
# 4                          1.033765                        0.411724
# ..                              ...                             ...
# 84                         9.442247                        0.967033
# 85                         7.225593                        0.632259
# 86                         5.111226                        0.902248
# 87                        22.308018                        0.618446
# 88                        21.364108                        0.725157
#
#     imaging.radiomics.GLCM_diffEntro  imaging.radiomics.GLCM_dissimilar  \
# 0                           2.037688                           3.085783
# 1                           2.203000                           3.070020
# 2                           1.714220                           1.639064
# 3                           1.641467                           1.628996
# 4                           1.005289                           0.695758
# ..                               ...                                ...
# 84                          1.807970                           1.934324
# 85                          1.551758                           1.450927
# 86                          1.633828                           1.522530
# 87                          2.266238                           3.473518
# 88                          2.253468                           3.234712
#
#     imaging.radiomics.GLCM_energy  imaging.radiomics.GLCM_entrop2  ...  \
# 0                        0.017533                        5.265293  ...
# 1                        0.026890                        4.855617  ...
# 2                        0.054382                        4.266069  ...
# 3                        0.029925                        4.174316  ...
# 4                        0.118367                        2.520816  ...
# ..                            ...                             ...  ...
# 84                       0.024847                        4.915511  ...
# 85                       0.053324                        3.714601  ...
# 86                       0.027358                        4.591139  ...
# 87                       0.008502                        5.085398  ...
# 88                       0.007381                        5.659427  ...
#
#     imaging.radiomics.Wavelet_LLL_stats_median  \
# 0                                  1415.663637
# 1                                  2761.175191
# 2                                  2860.668702
# 3                                  2931.331097
# 4                                  3033.154546
# ..                                         ...
# 84                                 4460.909095
# 85                                 5894.908307
# 86                                 2636.621869
# 87                                 2825.492940
# 88                                 2771.040671
#
#     imaging.radiomics.Wavelet_LLL_stats_min  \
# 0                               -363.889654
# 1                                627.327497
# 2                               1064.846734
# 3                               1090.306774
# 4                               2305.169603
# ..                                      ...
# 84                              3251.188474
# 85                              3004.315216
# 86                              1108.310171
# 87                              1492.839890
# 88                               988.253227
#
#     imaging.radiomics.Wavelet_LLL_stats_range  \
# 0                                 3646.793034
# 1                                 2591.028927
# 2                                 2858.450410
# 3                                 4341.408441
# 4                                 1481.835287
# ..                                        ...
# 84                                2664.350676
# 85                                3444.537968
# 86                                2736.174517
# 87                                1983.158830
# 88                                2592.351205
#
#     imaging.radiomics.Wavelet_LLL_stats_rms  \
# 0                               1928.917633
# 1                               2583.771232
# 2                               2695.236066
# 3                               2900.917177
# 4                               3025.285718
# ..                                      ...
# 84                              4833.234698
# 85                              5846.312571
# 86                              2525.870412
# 87                              2777.899166
# 88                              2666.177912
#
#     imaging.radiomics.Wavelet_LLL_stats_skewness  \
# 0                                       0.031798
# 1                                      -1.232774
# 2                                      -1.243821
# 3                                      -2.325833
# 4                                      -1.020618
# ..                                           ...
# 84                                      0.147291
# 85                                     -4.068370
# 86                                     -0.821885
# 87                                     -0.622212
# 88                                     -0.904100
#
#     imaging.radiomics.Wavelet_LLL_stats_std  \
# 0                               1304.624058
# 1                                497.655023
# 2                                359.149777
# 3                                218.932372
# 4                                 69.813296
# ..                                      ...
# 84                               792.489235
# 85                               267.867124
# 86                               373.004255
# 87                               429.690726
# 88                               465.168673
#
#     imaging.radiomics.Wavelet_LLL_stats_totalenergy  \
# 0                                      2.093502e+08
# 1                                      2.372606e+07
# 2                                      3.164909e+08
# 3                                      7.121297e+08
# 4                                      1.908266e+08
# ..                                              ...
# 84                                     2.985662e+08
# 85                                     4.396834e+08
# 86                                     3.136865e+08
# 87                                     5.023587e+09
# 88                                     8.361023e+07
#
#     imaging.radiomics.Wavelet_LLL_stats_uniformity  \
# 0                                         0.047220
# 1                                         0.091541
# 2                                         0.144030
# 3                                         0.240815
# 4                                         0.360381
# ..                                             ...
# 84                                        0.091199
# 85                                        0.189860
# 86                                        0.095700
# 87                                        0.049898
# 88                                        0.056554
#
#     imaging.radiomics.Wavelet_LLL_stats_var     Label
# 0                              1.702044e+09  squamous
# 1                              2.476605e+08  squamous
# 2                              1.289886e+05     adeno
# 3                              4.793138e+04  squamous
# 4                              4.873896e+03     adeno
# ..                                      ...       ...
# 84                             6.280392e+05  squamous
# 85                             7.175280e+04  squamous
# 86                             1.391322e+05  squamous
# 87                             1.846341e+05     other
# 88                             2.163819e+05     adeno
#
# [89 rows x 651 columns]

# %%
data_X = data_df.drop(['Label'], axis = 1)

# %%
data_X.columns
# Out:
# Index(['imaging.radiomics.GLCM_autocorr', 'imaging.radiomics.GLCM_clusProm',
#        'imaging.radiomics.GLCM_clusShade', 'imaging.radiomics.GLCM_clusTend',
#        'imaging.radiomics.GLCM_contrast', 'imaging.radiomics.GLCM_correl1',
#        'imaging.radiomics.GLCM_diffEntro', 'imaging.radiomics.GLCM_dissimilar',
#        'imaging.radiomics.GLCM_energy', 'imaging.radiomics.GLCM_entrop2',
#        ...
#        'imaging.radiomics.Wavelet_LLL_stats_mean',
#        'imaging.radiomics.Wavelet_LLL_stats_median',
#        'imaging.radiomics.Wavelet_LLL_stats_min',
#        'imaging.radiomics.Wavelet_LLL_stats_range',
#        'imaging.radiomics.Wavelet_LLL_stats_rms',
#        'imaging.radiomics.Wavelet_LLL_stats_skewness',
#        'imaging.radiomics.Wavelet_LLL_stats_std',
#        'imaging.radiomics.Wavelet_LLL_stats_totalenergy',
#        'imaging.radiomics.Wavelet_LLL_stats_uniformity',
#        'imaging.radiomics.Wavelet_LLL_stats_var'],
#       dtype='object', length=650)

# %%
data_X.shape
# Out:
# (89, 650)

# %%
data_y = data_df['Label']

# %%
data_y.shape
# Out:
# (89,)

# %%
data_df.isnull().sum().sum()
# Out:
# 0

# %%
data_y.unique()
# Out:
# array(['squamous', 'adeno', 'other'], dtype=object)

# %%
data_X
# Out:
#     imaging.radiomics.GLCM_autocorr  imaging.radiomics.GLCM_clusProm  \
# 0                       1015.604377                     1.728441e+06
# 1                        921.867862                     6.464357e+04
# 2                        632.293653                     2.927069e+04
# 3                        768.887796                     1.016742e+04
# 4                        131.834572                     3.611580e+01
# ..                              ...                              ...
# 84                       603.054548                     3.314669e+05
# 85                      1726.367922                     4.040858e+04
# 86                       473.814975                     2.669862e+04
# 87                       404.275573                     2.867433e+04
# 88                       681.259465                     6.136644e+04
#
#     imaging.radiomics.GLCM_clusShade  imaging.radiomics.GLCM_clusTend  \
# 0                      -16203.786420                       995.351478
# 1                       -1855.872326                       111.303433
# 2                       -1068.132061                        84.292617
# 3                        -348.622125                        29.055416
# 4                          -2.013109                         2.503468
# ..                               ...                              ...
# 84                       1834.022542                       488.061895
# 85                       -874.026124                        31.988221
# 86                       -868.125572                        98.751127
# 87                       -707.032249                        93.849341
# 88                      -1530.954192                       134.468888
#
#     imaging.radiomics.GLCM_contrast  imaging.radiomics.GLCM_correl1  \
# 0                         22.221434                        0.957409
# 1                         24.812007                        0.630987
# 2                          7.278293                        0.839872
# 3                          6.021883                        0.658310
# 4                          1.033765                        0.411724
# ..                              ...                             ...
# 84                         9.442247                        0.967033
# 85                         7.225593                        0.632259
# 86                         5.111226                        0.902248
# 87                        22.308018                        0.618446
# 88                        21.364108                        0.725157
#
#     imaging.radiomics.GLCM_diffEntro  imaging.radiomics.GLCM_dissimilar  \
# 0                           2.037688                           3.085783
# 1                           2.203000                           3.070020
# 2                           1.714220                           1.639064
# 3                           1.641467                           1.628996
# 4                           1.005289                           0.695758
# ..                               ...                                ...
# 84                          1.807970                           1.934324
# 85                          1.551758                           1.450927
# 86                          1.633828                           1.522530
# 87                          2.266238                           3.473518
# 88                          2.253468                           3.234712
#
#     imaging.radiomics.GLCM_energy  imaging.radiomics.GLCM_entrop2  ...  \
# 0                        0.017533                        5.265293  ...
# 1                        0.026890                        4.855617  ...
# 2                        0.054382                        4.266069  ...
# 3                        0.029925                        4.174316  ...
# 4                        0.118367                        2.520816  ...
# ..                            ...                             ...  ...
# 84                       0.024847                        4.915511  ...
# 85                       0.053324                        3.714601  ...
# 86                       0.027358                        4.591139  ...
# 87                       0.008502                        5.085398  ...
# 88                       0.007381                        5.659427  ...
#
#     imaging.radiomics.Wavelet_LLL_stats_mean  \
# 0                                1420.812989
# 1                                2535.405873
# 2                                2671.200451
# 3                                2892.644059
# 4                                3024.480123
# ..                                       ...
# 84                               4767.826297
# 85                               5840.173239
# 86                               2498.177734
# 87                               2744.516947
# 88                               2625.288776
#
#     imaging.radiomics.Wavelet_LLL_stats_median  \
# 0                                  1415.663637
# 1                                  2761.175191
# 2                                  2860.668702
# 3                                  2931.331097
# 4                                  3033.154546
# ..                                         ...
# 84                                 4460.909095
# 85                                 5894.908307
# 86                                 2636.621869
# 87                                 2825.492940
# 88                                 2771.040671
#
#     imaging.radiomics.Wavelet_LLL_stats_min  \
# 0                               -363.889654
# 1                                627.327497
# 2                               1064.846734
# 3                               1090.306774
# 4                               2305.169603
# ..                                      ...
# 84                              3251.188474
# 85                              3004.315216
# 86                              1108.310171
# 87                              1492.839890
# 88                               988.253227
#
#     imaging.radiomics.Wavelet_LLL_stats_range  \
# 0                                 3646.793034
# 1                                 2591.028927
# 2                                 2858.450410
# 3                                 4341.408441
# 4                                 1481.835287
# ..                                        ...
# 84                                2664.350676
# 85                                3444.537968
# 86                                2736.174517
# 87                                1983.158830
# 88                                2592.351205
#
#     imaging.radiomics.Wavelet_LLL_stats_rms  \
# 0                               1928.917633
# 1                               2583.771232
# 2                               2695.236066
# 3                               2900.917177
# 4                               3025.285718
# ..                                      ...
# 84                              4833.234698
# 85                              5846.312571
# 86                              2525.870412
# 87                              2777.899166
# 88                              2666.177912
#
#     imaging.radiomics.Wavelet_LLL_stats_skewness  \
# 0                                       0.031798
# 1                                      -1.232774
# 2                                      -1.243821
# 3                                      -2.325833
# 4                                      -1.020618
# ..                                           ...
# 84                                      0.147291
# 85                                     -4.068370
# 86                                     -0.821885
# 87                                     -0.622212
# 88                                     -0.904100
#
#     imaging.radiomics.Wavelet_LLL_stats_std  \
# 0                               1304.624058
# 1                                497.655023
# 2                                359.149777
# 3                                218.932372
# 4                                 69.813296
# ..                                      ...
# 84                               792.489235
# 85                               267.867124
# 86                               373.004255
# 87                               429.690726
# 88                               465.168673
#
#     imaging.radiomics.Wavelet_LLL_stats_totalenergy  \
# 0                                      2.093502e+08
# 1                                      2.372606e+07
# 2                                      3.164909e+08
# 3                                      7.121297e+08
# 4                                      1.908266e+08
# ..                                              ...
# 84                                     2.985662e+08
# 85                                     4.396834e+08
# 86                                     3.136865e+08
# 87                                     5.023587e+09
# 88                                     8.361023e+07
#
#     imaging.radiomics.Wavelet_LLL_stats_uniformity  \
# 0                                         0.047220
# 1                                         0.091541
# 2                                         0.144030
# 3                                         0.240815
# 4                                         0.360381
# ..                                             ...
# 84                                        0.091199
# 85                                        0.189860
# 86                                        0.095700
# 87                                        0.049898
# 88                                        0.056554
#
#     imaging.radiomics.Wavelet_LLL_stats_var
# 0                              1.702044e+09
# 1                              2.476605e+08
# 2                              1.289886e+05
# 3                              4.793138e+04
# 4                              4.873896e+03
# ..                                      ...
# 84                             6.280392e+05
# 85                             7.175280e+04
# 86                             1.391322e+05
# 87                             1.846341e+05
# 88                             2.163819e+05
#
# [89 rows x 650 columns]

# %% [markdown]
# Label encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data_y_trans = le.fit_transform(data_y)

# %%
data_X
# Out:
#     imaging.radiomics.GLCM_autocorr  imaging.radiomics.GLCM_clusProm  \
# 0                       1015.604377                     1.728441e+06
# 1                        921.867862                     6.464357e+04
# 2                        632.293653                     2.927069e+04
# 3                        768.887796                     1.016742e+04
# 4                        131.834572                     3.611580e+01
# ..                              ...                              ...
# 84                       603.054548                     3.314669e+05
# 85                      1726.367922                     4.040858e+04
# 86                       473.814975                     2.669862e+04
# 87                       404.275573                     2.867433e+04
# 88                       681.259465                     6.136644e+04
#
#     imaging.radiomics.GLCM_clusShade  imaging.radiomics.GLCM_clusTend  \
# 0                      -16203.786420                       995.351478
# 1                       -1855.872326                       111.303433
# 2                       -1068.132061                        84.292617
# 3                        -348.622125                        29.055416
# 4                          -2.013109                         2.503468
# ..                               ...                              ...
# 84                       1834.022542                       488.061895
# 85                       -874.026124                        31.988221
# 86                       -868.125572                        98.751127
# 87                       -707.032249                        93.849341
# 88                      -1530.954192                       134.468888
#
#     imaging.radiomics.GLCM_contrast  imaging.radiomics.GLCM_correl1  \
# 0                         22.221434                        0.957409
# 1                         24.812007                        0.630987
# 2                          7.278293                        0.839872
# 3                          6.021883                        0.658310
# 4                          1.033765                        0.411724
# ..                              ...                             ...
# 84                         9.442247                        0.967033
# 85                         7.225593                        0.632259
# 86                         5.111226                        0.902248
# 87                        22.308018                        0.618446
# 88                        21.364108                        0.725157
#
#     imaging.radiomics.GLCM_diffEntro  imaging.radiomics.GLCM_dissimilar  \
# 0                           2.037688                           3.085783
# 1                           2.203000                           3.070020
# 2                           1.714220                           1.639064
# 3                           1.641467                           1.628996
# 4                           1.005289                           0.695758
# ..                               ...                                ...
# 84                          1.807970                           1.934324
# 85                          1.551758                           1.450927
# 86                          1.633828                           1.522530
# 87                          2.266238                           3.473518
# 88                          2.253468                           3.234712
#
#     imaging.radiomics.GLCM_energy  imaging.radiomics.GLCM_entrop2  ...  \
# 0                        0.017533                        5.265293  ...
# 1                        0.026890                        4.855617  ...
# 2                        0.054382                        4.266069  ...
# 3                        0.029925                        4.174316  ...
# 4                        0.118367                        2.520816  ...
# ..                            ...                             ...  ...
# 84                       0.024847                        4.915511  ...
# 85                       0.053324                        3.714601  ...
# 86                       0.027358                        4.591139  ...
# 87                       0.008502                        5.085398  ...
# 88                       0.007381                        5.659427  ...
#
#     imaging.radiomics.Wavelet_LLL_stats_mean  \
# 0                                1420.812989
# 1                                2535.405873
# 2                                2671.200451
# 3                                2892.644059
# 4                                3024.480123
# ..                                       ...
# 84                               4767.826297
# 85                               5840.173239
# 86                               2498.177734
# 87                               2744.516947
# 88                               2625.288776
#
#     imaging.radiomics.Wavelet_LLL_stats_median  \
# 0                                  1415.663637
# 1                                  2761.175191
# 2                                  2860.668702
# 3                                  2931.331097
# 4                                  3033.154546
# ..                                         ...
# 84                                 4460.909095
# 85                                 5894.908307
# 86                                 2636.621869
# 87                                 2825.492940
# 88                                 2771.040671
#
#     imaging.radiomics.Wavelet_LLL_stats_min  \
# 0                               -363.889654
# 1                                627.327497
# 2                               1064.846734
# 3                               1090.306774
# 4                               2305.169603
# ..                                      ...
# 84                              3251.188474
# 85                              3004.315216
# 86                              1108.310171
# 87                              1492.839890
# 88                               988.253227
#
#     imaging.radiomics.Wavelet_LLL_stats_range  \
# 0                                 3646.793034
# 1                                 2591.028927
# 2                                 2858.450410
# 3                                 4341.408441
# 4                                 1481.835287
# ..                                        ...
# 84                                2664.350676
# 85                                3444.537968
# 86                                2736.174517
# 87                                1983.158830
# 88                                2592.351205
#
#     imaging.radiomics.Wavelet_LLL_stats_rms  \
# 0                               1928.917633
# 1                               2583.771232
# 2                               2695.236066
# 3                               2900.917177
# 4                               3025.285718
# ..                                      ...
# 84                              4833.234698
# 85                              5846.312571
# 86                              2525.870412
# 87                              2777.899166
# 88                              2666.177912
#
#     imaging.radiomics.Wavelet_LLL_stats_skewness  \
# 0                                       0.031798
# 1                                      -1.232774
# 2                                      -1.243821
# 3                                      -2.325833
# 4                                      -1.020618
# ..                                           ...
# 84                                      0.147291
# 85                                     -4.068370
# 86                                     -0.821885
# 87                                     -0.622212
# 88                                     -0.904100
#
#     imaging.radiomics.Wavelet_LLL_stats_std  \
# 0                               1304.624058
# 1                                497.655023
# 2                                359.149777
# 3                                218.932372
# 4                                 69.813296
# ..                                      ...
# 84                               792.489235
# 85                               267.867124
# 86                               373.004255
# 87                               429.690726
# 88                               465.168673
#
#     imaging.radiomics.Wavelet_LLL_stats_totalenergy  \
# 0                                      2.093502e+08
# 1                                      2.372606e+07
# 2                                      3.164909e+08
# 3                                      7.121297e+08
# 4                                      1.908266e+08
# ..                                              ...
# 84                                     2.985662e+08
# 85                                     4.396834e+08
# 86                                     3.136865e+08
# 87                                     5.023587e+09
# 88                                     8.361023e+07
#
#     imaging.radiomics.Wavelet_LLL_stats_uniformity  \
# 0                
# imaging.radiomics.Wavelet_LHH_glcm_correl1                    0.003928
# imaging.radiomics.Shape_orig_maxDiameter3D_pdist              0.003894
# imaging.radiomics.LoG_sigma_3_mm_2D_stats_skewness            0.003884
# imaging.radiomics.Wavelet_HLH_glcm_correl1                    0.003868
# imaging.radiomics.Wavelet_HHL_rlgl_shortRunLowGrayLevEmpha    0.003834
# dtype: float64

# %%
data_new_20features_X = data_X[['imaging.radiomics.Shape_sphericity',
'imaging.radiomics.Shape_compactness2',
'imaging.radiomics.Stats_min',
'imaging.radiomics.Wavelet_HHH_glcm_clusShade',
'imaging.radiomics.Shape_orig_spherDisprop',
'imaging.radiomics.Wavelet_LHL_stats_kurtosis',
'imaging.radiomics.GLSZM_highIntensityLarteAreaEmp',
'imaging.radiomics.LoG_sigma_4_5_mm_2D_stats_skewness',
'imaging.radiomics.Wavelet_LHL_glcm_homogeneity1',
'imaging.radiomics.Wavelet_HHL_stats_kurtosis',
'imaging.radiomics.Wavelet_LHL_glcm_correl1',
'imaging.radiomics.Shape_orig_compactness2',
'imaging.radiomics.Shape_maxDiameter2Dy',
'imaging.radiomics.LoG_sigma_5_mm_2D_stats_skewness',
'imaging.radiomics.Shape_orig_maxDiameter2Dz',
'imaging.radiomics.Wavelet_LHH_glcm_correl1',
'imaging.radiomics.Shape_orig_maxDiameter3D_pdist',
'imaging.radiomics.LoG_sigma_3_mm_2D_stats_skewness',
'imaging.radiomics.Wavelet_HLH_glcm_correl1',
'imaging.radiomics.Wavelet_HHL_rlgl_shortRunLowGrayLevEmpha']]

# %%
data_new_20features_X
# Out:
#     imaging.radiomics.Shape_sphericity  imaging.radiomics.Shape_compactness2  \
# 0                             0.583940                              0.199115
# 1                             0.681389                              0.316363
# 2                             0.754555                              0.429609
# 3                             0.676058                              0.308995
# 4                             0.403271                              0.065583
# ..                                 ...                                   ...
# 84                            0.619567                              0.237830
# 85                            0.535142                              0.153252
# 86                            0.697786                              0.339756
# 87                            0.839809                              0.592300
# 88                            0.646992                              0.270830
#
#     imaging.radiomics.Stats_min  imaging.radiomics.Wavelet_HHH_glcm_clusShade  \
# 0                   -128.921326                                     -0.863219
# 1                    212.710602                                    -38.921032
# 2                    361.168671                                      0.767457
# 3                    370.879425                                      2.856808
# 4                    821.966858                                      0.384893
# ..                          ...                                           ...
# 84                  1154.799683                                     -6.624924
# 85                  1065.498657                                    -12.476435
# 86                   395.864105                                      2.077206
# 87                   531.244934                                     -4.671561
# 88                   334.440613                                     -3.883241
#
#     imaging.radiomics.Shape_orig_spherDisprop  \
# 0                                    1.701854
# 1                                    1.366801
# 2                                    1.317834
# 3                                    1.479943
# 4                                    2.467313
# ..                                        ...
# 84                                   1.602454
# 85                                   1.955343
# 86                                   1.328542
# 87                                   1.196983
# 88                                   1.566814
#
#     imaging.radiomics.Wavelet_LHL_stats_kurtosis  \
# 0                                      16.418530
# 1                                       7.163341
# 2                                       8.772360
# 3                                      42.023809
# 4                                      12.793155
# ..                                           ...
# 84                                     10.774038
# 85                                     17.248399
# 86                                      5.893239
# 87                                      4.457320
# 88                                      5.812689
#
#     imaging.radiomics.GLSZM_highIntensityLarteAreaEmp  \
# 0                                        7.490583e+07
# 1                                        6.437977e+05
# 2                                        4.368889e+09
# 3                                        5.932381e+09
# 4                                        7.631637e+08
# ..                                                ...
# 84                                       2.466864e+08
# 85                                       2.316146e+08
# 86                                       2.688024e+09
# 87                                       2.275388e+07
# 88                                       1.145273e+07
#
#     imaging.radiomics.LoG_sigma_4_5_mm_2D_stats_skewness  \
# 0                                            1.006432
# 1                                           -0.169763
# 2                                            0.319306
# 3                                            0.713365
# 4                                            0.010129
# ..                                                ...
# 84                                          -0.268134
# 85                                           0.190830
# 86                                           0.187629
# 87                                          -0.349178
# 88                                          -0.013539
#
#     imaging.radiomics.Wavelet_LHL_glcm_homogeneity1  \
# 0                                          0.680020
# 1                                          0.523651
# 2                                          0.582285
# 3                                          0.779460
# 4                                          0.719789
# ..                                              ...
# 84                                         0.532015
# 85                                         0.585384
# 86                                         0.521739
# 87                                         0.391219
# 88                                         0.446337
#
#     imaging.radiomics.Wavelet_HHL_stats_kurtosis  \
# 0                                      13.841520
# 1                                      11.145545
# 2                                       6.787543
# 3                                      12.166695
# 4                                      15.221481
# ..                                           ...
# 84                                     10.198610
# 85                                      9.085355
# 86                                      7.808384
# 87                                      4.499409
# 88                                      7.236369
#
#     imaging.radiomics.Wavelet_LHL_glcm_correl1  \
# 0                                     0.535814
# 1                                     0.307072
# 2                                     0.439001
# 3                                     0.246158
# 4                                     0.287495
# ..                                         ...
# 84                                    0.340337
# 85                                    0.398621
# 86                                    0.487421
# 87                                    0.262536
# 88                                    0.235044
#
#     imaging.radiomics.Shape_orig_compactness2  \
# 0                                    0.202877
# 1                                    0.391637
# 2                                    0.436937
# 3                                    0.308507
# 4                                    0.066577
# ..                                        ...
# 84                                   0.243021
# 85                                   0.133762
# 86                                   0.426456
# 87                                   0.583091
# 88                                   0.259984
#
#     imaging.radiomics.Shape_maxDiameter2Dy  \
# 0                                 6.453681
# 1                                 2.500000
# 2                                 5.590170
# 3                                 6.000833
# 4                                 4.925444
# ..                                     ...
# 84                                3.080584
# 85                                4.294182
# 86                                6.053924
# 87                                1.200925
# 88                                3.544009
#
#     imaging.radiomics.LoG_sigma_5_mm_2D_stats_skewness  \
# 0                                            1.051637
# 1                                           -0.171818
# 2                                            0.105952
# 3                                            0.597371
# 4                                            0.030679
# ..                                                ...
# 84                                          -0.316071
# 85                                           0.018411
# 86                                           0.170704
# 87                                          -0.270210
# 88                                          -0.026797
#
#     imaging.radiomics.Shape_orig_maxDiameter2Dz  \
# 0                                      6.299850
# 1                                      1.985615
# 2                                      5.561389
# 3                                      6.781966
# 4                                      5.459148
# ..                                          ...
# 84                                     3.648739
# 85                                     4.519825
# 86                                     4.944146
# 87                                     1.069129
# 88                                     3.367371
#
#     imaging.radiomics.Wavelet_LHH_glcm_correl1  \
# 0                                     0.222080
# 1                                     0.156891
# 2                                     0.112109
# 3                                    -0.006373
# 4                                     0.061200
# ..                                         ...
# 84                                    0.059526
# 85                                    0.106430
# 86                                    0.208256
# 87                                    0.128811
# 88                                   -0.013090
#
#     imaging.radiomics.Shape_orig_maxDiameter3D_pdist  \
# 0                                           7.842583
# 1                                           2.564109
# 2                                           6.075626
# 3                                           7.324626
# 4                                           5.648626
# ..                                               ...
# 84                                          4.513822
# 85                                          4.988984
# 86                                          5.895267
# 87                                          1.288968
# 88                                          3.580043
#
#     imaging.radiomics.LoG_sigma_3_mm_2D_stats_skewness  \
# 0                                            1.154539
# 1                                           -0.244770
# 2                                            1.048718
# 3                                            1.237680
# 4                                           -0.075405
# ..                                                ...
# 84                                          -0.190842
# 85                                           0.630210
# 86                                           0.307867
# 87                                          -0.360876
# 88                                           0.216279
#
#     imaging.radiomics.Wavelet_HLH_glcm_correl1  \
# 0                                     0.452857
# 1                                     0.263872
# 2                                     0.228140
# 3                                     0.022809
# 4                                     0.086584
# ..                                         ...
# 84                                    0.292658
# 85                                    0.224504
# 86                                    0.314192
# 87                                    0.428795
# 88                                    0.144497
#
#     imaging.radiomics.Wavelet_HHL_rlgl_shortRunLowGrayLevEmpha
# 0                                            0.001730
# 1                                            0.007321
# 2                                            0.002636
# 3                                            0.001473
# 4                                            0.005447
# ..                                                ...
# 84                                           0.003538
# 85                                           0.001592
# 86                                           0.002349
# 87                                           0.010121
# 88                                           0.002585
#
# [89 rows x 20 columns]

# %%
from sklearn.model_selection import train_test_split
X_train_20, X_test_20, y_train_20, y_test_20 = train_test_split(data_new_20features_X, data_y_trans, train_size = 0.8, random_state=26)

# %%
from sklearn.preprocessing import StandardScaler 
ss_20 = StandardScaler()
X_train_std_20 = ss_20.fit_transform(X_train_20)
X_test_std_20 = ss_20.fit_transform(X_test_20)

# %% [markdown]
# Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=56)

# %%
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
from sklearn.metrics import confusion_matrix

# %%
from sklearn.model_selection import cross_val_predict
y_pred = cross_val_predict(rf, data_new_20features_X, data_y_trans, cv=10)
conf_mat = confusion_matrix(data_y_trans, y_pred)

# %%
print(conf_mat)
# Out:
# [[34  0  8]
#  [ 6  2  4]
#  [12  1 22]]

# %%
print("Classification Report for Random Forest: \n", classification_report(data_y_trans,y_pred))
# Out:
# Classification Report for Random Forest:
#                precision    recall  f1-score   support
#
#            0       0.65      0.81      0.72        42
#            1       0.67      0.17      0.27        12
#            2       0.65      0.63      0.64        35
#
#     accuracy                           0.65        89
#    macro avg       0.66      0.53      0.54        89
# weighted avg       0.65      0.65      0.63        89

# %% [markdown]
# PSO

# %%
# !pip install optunity
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optunity in /usr/local/lib/python3.8/dist-packages (1.1.1)

# %%
data_new_20features_Xt = ss_20.fit_transform(data_new_20features_X)

# %%
import optunity
import optunity.metrics
from sklearn.model_selection import cross_val_score
data=data_new_20features_Xt
labels= data_y_trans.tolist()
# Define the hyperparameter configuration space
search = {
    'n_estimators': [10, 100],
    'max_features': [1, 64],
    'max_depth': [5,50],
    "min_samples_split":[2,11],
    "min_samples_leaf":[1,11],
    "criterion":[0,1]
         }
# Define the objective function
@optunity.cross_validated(x=data, y=labels, num_folds=3)
def performance(x_train, y_train, x_test, y_test,n_estimators=None, max_features=None,max_depth=None,min_samples_split=None,min_samples_leaf=None,criterion=None):
    # fit the model
    if criterion<0.5:
        cri='gini'
    else:
        cri='entropy'
    model = RandomForestClassifier(
                                   criterion=cri,
                                  )
    #predictions = model.predict(x_test)
    scores=np.mean(cross_val_score(model, data_new_20features_Xt,  data_y_trans, cv=10, n_jobs=-1,
                                    scoring="accuracy"))
    #return optunity.metrics.roc_auc(y_test, predictions, positive=True)
    return scores#optunity.metrics.accuracy(y_test, predictions)

optimal_configuration, info, _ = optunity.maximize(performance,
                                                  solver_name='particle swarm',
                                                  num_evals=20,
                                                   **search
                                                  )
print(optimal_configuration)
print("Accuracy:"+ str(info.optimum))
# Out:
# {'n_estimators': 55.9580078125, 'max_features': 22.82470591176616, 'max_depth': 35.1988706890031, 'min_samples_split': 5.77841796875, 'min_samples_leaf': 2.0458984375, 'criterion': 0.21254140609897798}
# Accuracy:0.6675925925925926

# %% [markdown]
# ROC Curve

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score

# %%
from sklearn.preprocessing import label_binarize
y_bin = label_binarize(data_y_trans, classes=[0, 1, 2,3])
from itertools import cycle
lw=2

# %%
import matplotlib.pyplot as plt

# %%
y_score = cross_val_predict(rf, data_new_20features_X, data_y_trans, cv=2 ,method='predict_proba')

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
colors = cycle(['blue', 'red', 'green','magenta'])
list_class = ['squamous','largecell','others','adeno']
for i, color in zip(range(3), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(list_class[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic for multi-class data')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# svm

# %%
from sklearn.svm import SVC

svm_rbf = SVC(gamma=4, C=1)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
y_pred = cross_val_predict(svm_rbf, data_new_20features_X, data_y_trans, cv=4)
conf_mat = confusion_matrix(data_y_trans, y_pred)

# %%
print("Classification Report for Random Forest: \n", classification_report(data_y_trans,y_pred))
# Out:
# Classification Report for Random Forest:
#                precision    recall  f1-score   support
#
#            0       0.47      1.00      0.64        42
#            1       0.00      0.00      0.00        12
#            2       0.00      0.00      0.00        35
#
#     accuracy                           0.47        89
#    macro avg       0.16      0.33      0.21        89
# weighted avg       0.22      0.47      0.30        89
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
data=data_new_20features_Xt
labels=data_y_trans.tolist()

search = {
    'C': (0,50),
    'kernel':[0,4]
         }
@optunity.cross_validated(x=data, y=labels, num_folds=3)
def performance(x_train, y_train, x_test, y_test,C=None,kernel=None):
    # fit the model
    if kernel<1:
        ke='linear'
    elif kernel<2:
        ke='poly'
    elif kernel<3:
        ke='rbf'
    else:
        ke='sigmoid'
    model = SVC(C=float(C),
                kernel=ke
                                  )
    #predictions = model.predict(x_test)
    scores=np.mean(cross_val_score(model, data_new_20features_Xt,data_y_trans, cv=10, n_jobs=-1,
                                    scoring="accuracy"))
    #return optunity.metrics.roc_auc(y_test, predictions, positive=True)
    return scores#optunity.metrics.accuracy(y_test, predictions)

optimal_configuration, info, _ = optunity.maximize(performance,
                                                  solver_name='particle swarm',
                                                  num_evals=20,
                                                   **search
                                                  )
print(optimal_configuration)
print("Accuracy:"+ str(info.optimum))
# Out:
# {'C': 3.3073403768179084, 'kernel': 0.19233335249841021}
# Accuracy:0.6388888888888888

# %% [markdown]
# knn

# %%
from sklearn.neighbors import KNeighborsClassifier,KNeighborsRegressor

# %%
clf2 = KNeighborsClassifier()
clf2.fit(data_new_20features_X, data_y_trans)
scores = cross_val_score(clf2, data_new_20features_X, data_y_trans, cv=10,scoring='accuracy')
print("Accuracy:"+ str(scores.mean()))
# Out:
# Accuracy:0.5458333333333334

# %% [markdown]
# knn PSO

# %%
import optunity
import optunity.metrics

data=data_new_20features_Xt
labels=data_y_trans.tolist()

search = {
    'n_neighbors': [1, 20],
         }
@optunity.cross_validated(x=data, y=labels, num_folds=3)
def performance(x_train, y_train, x_test, y_test,n_neighbors=None):
    # fit the model
    model = KNeighborsClassifier(n_neighbors=int(n_neighbors),
                                  )
    scores=np.mean(cross_val_score(model,data_new_20features_Xt,data_y_trans, cv=10, n_jobs=-1,
                                    scoring="accuracy"))
    return scores

optimal_configuration, info, _ = optunity.maximize(performance,
                                                  solver_name='particle swarm',
                                                  num_evals=10,
                                                   **search
                                                  )
print(optimal_configuration)
print("Accuracy:"+ str(info.optimum))
# Out:
# {'n_neighbors': 13.2646484375}
# Accuracy:0.6263888888888889

# %% [markdown]
# ROC Curve

# %%
y_score = cross_val_predict(clf2, data_new_20features_X, data_y_trans, cv=2 ,method='predict_proba')

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
colors = cycle(['blue', 'red', 'green','magenta'])
list_class = ['squamous','largecell','others','adeno']
for i, color in zip(range(3), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(list_class[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic for multi-class data')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# GradientBoosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gradient_boost = GradientBoostingClassifier(random_state=56)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
y_pred = cross_val_predict(gradient_boost, data_new_20features_X, data_y_trans, cv=10)
conf_mat = confusion_matrix(data_y_trans, y_pred)

# %%
print("Classification Report for GradientBoosting: \n", classification_report(data_y_trans,y_pred))
# Out:
# Classification Report for GradientBoosting:
#                precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71        42
#            1       0.36      0.33      0.35        12
#            2       0.69      0.71      0.70        35
#
#     accuracy                           0.66        89
#    macro avg       0.59      0.59      0.59        89
# weighted avg       0.66      0.66      0.66        89

# %% [markdown]
# GB PSO

# %%
data=data_new_20features_Xt
labels=data_y_trans.tolist()

search = {
    'C': (0,50),
    'kernel':[0,4]
         }
@optunity.cross_validated(x=data, y=labels, num_folds=3)
def performance(x_train, y_train, x_test, y_test,C=None,kernel=None):
    # fit the model
    
    model = GradientBoostingClassifier(random_state=56)
    #predictions = model.predict(x_test)
    scores=np.mean(cross_val_score(model, data_new_20features_Xt,data_y_trans, cv=10, n_jobs=-1,
                                    scoring="accuracy"))
    #return optunity.metrics.roc_auc(y_test, predictions, positive=True)
    return scores#optunity.metrics.accuracy(y_test, predictions)

optimal_configuration, info, _ = optunity.maximize(performance,
                                                  solver_name='particle swarm',
                                                  num_evals=20,
                                                   **search
                                                  )
print(optimal_configuration)
print("Accuracy:"+ str(info.optimum))
# Out:
# {'C': 11.181640625, 'kernel': 3.62109375}
# Accuracy:0.6625

# %% [markdown]
# ROC

# %%
y_score = cross_val_predict(gradient_boost, data_new_20features_X, data_y_trans, cv=2 ,method='predict_proba')

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
colors = cycle(['blue', 'red', 'green','magenta'])
list_class = ['squamous','largecell','others','adeno']
for i, color in zip(range(3), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(list_class[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic for multi-class data')
plt.legend(loc="lower right")
plt.show()
