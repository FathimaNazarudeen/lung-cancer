# %% [markdown]
# <a href="https://colab.research.google.com/github/FathimaNazarudeen/lung-cancer/blob/main/1st%20dataset%20old.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_csv("/content/thirddatasetdata1edited.csv")

# %%
data['Label'].value_counts()
# Out:
# adeno       128
# squamous     61
# other        34
# Name: Label, dtype: int64

# %%
data.columns
# Out:
# Index(['imaging.radiomics.GLCM_autocorr', 'imaging.radiomics.GLCM_clusProm',
#        'imaging.radiomics.GLCM_clusShade', 'imaging.radiomics.GLCM_clusTend',
#        'imaging.radiomics.GLCM_contrast', 'imaging.radiomics.GLCM_correl1',
#        'imaging.radiomics.GLCM_diffEntro', 'imaging.radiomics.GLCM_dissimilar',
#        'imaging.radiomics.GLCM_energy', 'imaging.radiomics.GLCM_entrop2',
#        ...
#        'imaging.radiomics.Wavelet_LLL_stats_median',
#        'imaging.radiomics.Wavelet_LLL_stats_min',
#        'imaging.radiomics.Wavelet_LLL_stats_range',
#        'imaging.radiomics.Wavelet_LLL_stats_rms',
#        'imaging.radiomics.Wavelet_LLL_stats_skewness',
#        'imaging.radiomics.Wavelet_LLL_stats_std',
#        'imaging.radiomics.Wavelet_LLL_stats_totalenergy',
#        'imaging.radiomics.Wavelet_LLL_stats_uniformity',
#        'imaging.radiomics.Wavelet_LLL_stats_var', 'Label'],
#       dtype='object', length=637)

# %%
data_real = data.replace(np.inf, np.nan)

# %%
data_real.isnull().sum().sum()
# Out:
# 0

# %%
data_df = data_real.dropna(axis=0)

# %%
data_df.isnull().sum().sum()
# Out:
# 0

# %%
data_df
# Out:
#      imaging.radiomics.GLCM_autocorr  imaging.radiomics.GLCM_clusProm  \
# 0                         715.183492                      53618.03971
# 1                         956.436544                      95580.27813
# 2                         963.057792                      96330.46530
# 3                         963.057792                      96330.46530
# 4                         570.535556                      42026.85712
# ..                               ...                              ...
# 218                      1044.774426                      79499.77631
# 219                      1685.794323                     139242.15520
# 220                      1574.455037                     992379.18660
# 221                       928.282770                     122621.87940
# 222                      1059.032655                     135188.72910
#
#      imaging.radiomics.GLCM_clusShade  imaging.radiomics.GLCM_clusTend  \
# 0                        -1475.142740                       118.475813
# 1                        -2508.858114                       131.204922
# 2                        -2186.802767                       163.193200
# 3                        -2186.802767                       163.193200
# 4                        -1161.186895                       116.475148
# ..                                ...                              ...
# 218                      -2163.336685                        99.634124
# 219                      -2916.035450                       165.486791
# 220                     -17255.002550                       450.822406
# 221                      -3187.952067                       126.827405
# 222                      -3091.943935                       183.780705
#
#      imaging.radiomics.GLCM_contrast  imaging.radiomics.GLCM_correl1  \
# 0                          23.536831                        0.663697
# 1                          13.575296                        0.821103
# 2                          21.049552                        0.770236
# 3                          21.049552                        0.770236
# 4                           9.569859                        0.847589
# ..                               ...                             ...
# 218                        11.320732                        0.793514
# 219                        53.945927                        0.505402
# 220                        14.130566                        0.946498
# 221                         8.814964                        0.878375
# 222                        19.546750                        0.806077
#
#      imaging.radiomics.GLCM_diffEntro  imaging.radiomics.GLCM_dissimilar  \
# 0                            2.303956                           3.404106
# 1                            1.945360                           2.235645
# 2                            2.250995                           3.157283
# 3                            2.250995                           3.157283
# 4                            1.914548                           2.124945
# ..                                ...                                ...
# 218                          1.803409                           1.907051
# 219                          2.610250                           4.840263
# 220                          1.784805                           1.964283
# 221                          1.765431                           1.761873
# 222                          2.135251                           2.783181
#
#      imaging.radiomics.GLCM_energy  imaging.radiomics.GLCM_entrop2  ...  \
# 0                         0.011698                        5.253413  ...
# 1                         0.022005                        4.892834  ...
# 2                         0.010573                        5.550620  ...
# 3                         0.010573                        5.550620  ...
# 4                         0.021076                        4.927171  ...
# ..                             ...                             ...  ...
# 218                       0.040823                        4.387260  ...
# 219                       0.006240                        6.038553  ...
# 220                       0.076426                        4.220708  ...
# 221                       0.071576                        4.043600  ...
# 222                       0.011187                        5.475804  ...
#
#      imaging.radiomics.Wavelet_LLL_stats_median  \
# 0                                   2832.543927
# 1                                   2963.576661
# 2                                   2748.221725
# 3                                   2748.221725
# 4                                   2661.029808
# ..                                          ...
# 218                                 3054.296105
# 219                                 2982.108699
# 220                                 3035.723007
# 221                                 3102.222268
# 222                                 2999.751947
#
#      imaging.radiomics.Wavelet_LLL_stats_min  \
# 0                                1020.111155
# 1                                 711.796395
# 2                                 650.596834
# 3                                 650.596834
# 4                                1009.412132
# ..                                       ...
# 218                               766.661346
# 219                              -296.808335
# 220                                57.026827
# 221                               839.503760
# 222                               702.896216
#
#      imaging.radiomics.Wavelet_LLL_stats_range  \
# 0                                  2409.764875
# 1                                  2779.237448
# 2                                  2834.709123
# 3                                  2834.709123
# 4                                  2581.862196
# ..                                         ...
# 218                                2870.223030
# 219                                4465.246325
# 220                                3528.675622
# 221                                2505.621278
# 222                                2934.028068
#
#      imaging.radiomics.Wavelet_LLL_stats_rms  \
# 0                                2738.254593
# 1                                2812.484806
# 2                                2661.153097
# 3                                2661.153097
# 4                                2578.745604
# ..                                       ...
# 218                              2909.783049
# 219                              2815.259028
# 220                              2741.645706
# 221                              2912.716745
# 222                              2835.686896
#
#      imaging.radiomics.Wavelet_LLL_stats_skewness  \
# 0                                       -0.899672
# 1                                       -1.485601
# 2                                       -0.933133
# 3                                       -0.933133
# 4                                       -0.808529
# ..                                            ...
# 218                                     -1.872298
# 219                                     -1.228746
# 220                                     -1.643321
# 221                                     -1.915246
# 222                                     -1.095398
#
#      imaging.radiomics.Wavelet_LLL_stats_std  \
# 0                                 485.593853
# 1                                 458.859064
# 2                                 519.346381
# 3                                 519.346381
# 4                                 431.885733
# ..                                       ...
# 218                               432.828235
# 219                               512.237142
# 220                               805.981985
# 221                               459.434538
# 222                               557.034218
#
#      imaging.radiomics.Wavelet_LLL_stats_totalenergy  \
# 0                                        15101048968
# 1                                        86733926143
# 2                                       175000000000
# 3                                       175000000000
# 4                                        58725522043
# ..                                               ...
# 218                                     113000000000
# 219                                     252000000000
# 220                                     359000000000
# 221                                      53830465004
# 222                                     185000000000
#
#      imaging.radiomics.Wavelet_LLL_stats_uniformity  \
# 0                                          0.057933
# 1                                          0.080207
# 2                                          0.050023
# 3                                          0.050023
# 4                                          0.066736
# ..                                              ...
# 218                                        0.113193
# 219                                        0.066760
# 220                                        0.192396
# 221                                        0.155007
# 222                                        0.052281
#
#      imaging.radiomics.Wavelet_LLL_stats_var  Label
# 0                                235801.3901  adeno
# 1                                210551.6408  adeno
# 2                                269720.6632  adeno
# 3                                269720.6632  adeno
# 4                                186525.2862  adeno
# ..                                       ...    ...
# 218                              187340.2806  other
# 219                              262386.8899  other
# 220                              649606.9605  other
# 221                              211080.0949  other
# 222                              310287.1205  other
#
# [223 rows x 637 columns]

# %%
data_X = data_df.drop(['Label'], axis = 1)

# %%
data_X.columns
# Out:
# Index(['imaging.radiomics.GLCM_autocorr', 'imaging.radiomics.GLCM_clusProm',
#        'imaging.radiomics.GLCM_clusShade', 'imaging.radiomics.GLCM_clusTend',
#        'imaging.radiomics.GLCM_contrast', 'imaging.radiomics.GLCM_correl1',
#        'imaging.radiomics.GLCM_diffEntro', 'imaging.radiomics.GLCM_dissimilar',
#        'imaging.radiomics.GLCM_energy', 'imaging.radiomics.GLCM_entrop2',
#        ...
#        'imaging.radiomics.Wavelet_LLL_stats_mean',
#        'imaging.radiomics.Wavelet_LLL_stats_median',
#        'imaging.radiomics.Wavelet_LLL_stats_min',
#        'imaging.radiomics.Wavelet_LLL_stats_range',
#        'imaging.radiomics.Wavelet_LLL_stats_rms',
#        'imaging.radiomics.Wavelet_LLL_stats_skewness',
#        'imaging.radiomics.Wavelet_LLL_stats_std',
#        'imaging.radiomics.Wavelet_LLL_stats_totalenergy',
#        'imaging.radiomics.Wavelet_LLL_stats_uniformity',
#        'imaging.radiomics.Wavelet_LLL_stats_var'],
#       dtype='object', length=636)

# %%
data_X.shape
# Out:
# (223, 636)

# %%
data_y = data_df['Label']

# %%
data_y.shape
# Out:
# (223,)

# %%
data_df.isnull().sum().sum()
# Out:
# 0

# %%
data_y.unique()
# Out:
# array(['adeno', 'squamous', 'other'], dtype=object)

# %%
data_X
# Out:
#      imaging.radiomics.GLCM_autocorr  imaging.radiomics.GLCM_clusProm  \
# 0                         715.183492                      53618.03971
# 1                         956.436544                      95580.27813
# 2                         963.057792                      96330.46530
# 3                         963.057792                      96330.46530
# 4                         570.535556                      42026.85712
# ..                               ...                              ...
# 218                      1044.774426                      79499.77631
# 219                      1685.794323                     139242.15520
# 220                      1574.455037                     992379.18660
# 221                       928.282770                     122621.87940
# 222                      1059.032655                     135188.72910
#
#      imaging.radiomics.GLCM_clusShade  imaging.radiomics.GLCM_clusTend  \
# 0                        -1475.142740                       118.475813
# 1                        -2508.858114                       131.204922
# 2                        -2186.802767                       163.193200
# 3                        -2186.802767                       163.193200
# 4                        -1161.186895                       116.475148
# ..                                ...                              ...
# 218                      -2163.336685                        99.634124
# 219                      -2916.035450                       165.486791
# 220                     -17255.002550                       450.822406
# 221                      -3187.952067                       126.827405
# 222                      -3091.943935                       183.780705
#
#      imaging.radiomics.GLCM_contrast  imaging.radiomics.GLCM_correl1  \
# 0                          23.536831                        0.663697
# 1                          13.575296                        0.821103
# 2                          21.049552                        0.770236
# 3                          21.049552                        0.770236
# 4                           9.569859                        0.847589
# ..                               ...                             ...
# 218                        11.320732                        0.793514
# 219                        53.945927                        0.505402
# 220                        14.130566                        0.946498
# 221                         8.814964                        0.878375
# 222                        19.546750                        0.806077
#
#      imaging.radiomics.GLCM_diffEntro  imaging.radiomics.GLCM_dissimilar  \
# 0                            2.303956                           3.404106
# 1                            1.945360                           2.235645
# 2                            2.250995                           3.157283
# 3                            2.250995                           3.157283
# 4                            1.914548                           2.124945
# ..                                ...                                ...
# 218                          1.803409                           1.907051
# 219                          2.610250                           4.840263
# 220                          1.784805                           1.964283
# 221                          1.765431                           1.761873
# 222                          2.135251                           2.783181
#
#      imaging.radiomics.GLCM_energy  imaging.radiomics.GLCM_entrop2  ...  \
# 0                         0.011698                        5.253413  ...
# 1                         0.022005                        4.892834  ...
# 2                         0.010573                        5.550620  ...
# 3                         0.010573                        5.550620  ...
# 4                         0.021076                        4.927171  ...
# ..                             ...                             ...  ...
# 218                       0.040823                        4.387260  ...
# 219                       0.006240                        6.038553  ...
# 220                       0.076426                        4.220708  ...
# 221                       0.071576                        4.043600  ...
# 222                       0.011187                        5.475804  ...
#
#      imaging.radiomics.Wavelet_LLL_stats_mean  \
# 0                                 2694.875490
# 1                                 2774.804199
# 2                                 2609.985831
# 3                                 2609.985831
# 4                                 2542.326637
# ..                                        ...
# 218                               2877.413963
# 219                               2768.267464
# 220                               2620.501447
# 221                               2876.260073
# 222                               2780.439985
#
#      imaging.radiomics.Wavelet_LLL_stats_median  \
# 0                                   2832.543927
# 1                                   2963.576661
# 2                                   2748.221725
# 3                                   2748.221725
# 4                                   2661.029808
# ..                                          ...
# 218                                 3054.296105
# 219                                 2982.108699
# 220                                 3035.723007
# 221                                 3102.222268
# 222                                 2999.751947
#
#      imaging.radiomics.Wavelet_LLL_stats_min  \
# 0
# imaging.radiomics.Wavelet_LLH_stats_entropy                    0.003694
# imaging.radiomics.Wavelet_LLL_glcm_infoCorr2                   0.003688
# imaging.radiomics.Wavelet_HLL_rlgl_runLengthNonuniformity      0.003531
# imaging.radiomics.Wavelet_HLH_rlgl_shortRunEmphasis            0.003520
# imaging.radiomics.Wavelet_LLL_glcm_sumEntro                    0.003488
# dtype: float64

# %%
data_new_20features_X = data_X[['imaging.radiomics.Wavelet_LLH_glcm_entrop2',
'imaging.radiomics.Wavelet_LLL_glcm_correl1',
'imaging.radiomics.Wavelet_LLL_stats_median',
'imaging.radiomics.Wavelet_HLH_glcm_inverseVar',
'imaging.radiomics.Wavelet_LLL_glcm_clusShade',
'imaging.radiomics.Wavelet_LLL_glcm_clusProm',
'imaging.radiomics.Wavelet_LLH_glcm_homogeneity1',
'imaging.radiomics.Wavelet_LLL_stats_min',
'imaging.radiomics.Wavelet_LLL_stats_md',
'imaging.radiomics.Wavelet_HLH_stats_kurtosis',
'imaging.radiomics.Wavelet_LLL_rlgl_shortRunHighGrayLevEmpha',
'imaging.radiomics.Stats_std',
'imaging.radiomics.Wavelet_LLH_stats_skewness',
'imaging.radiomics.Wavelet_LHL_rlgl_shortRunEmphasis',
'imaging.radiomics.Wavelet_HLH_glcm_entrop2',
'imaging.radiomics.Wavelet_LLH_stats_entropy',
'imaging.radiomics.Wavelet_LLL_glcm_infoCorr2',
'imaging.radiomics.Wavelet_HLL_rlgl_runLengthNonuniformity',
'imaging.radiomics.Wavelet_HLH_rlgl_shortRunEmphasis',
'imaging.radiomics.Wavelet_LLL_glcm_sumEntro']]

# %%
data_new_20features_X
# Out:
#      imaging.radiomics.Wavelet_LLH_glcm_entrop2  \
# 0                                      5.156136
# 1                                      3.499411
# 2                                      5.080891
# 3                                      5.080891
# 4                                      4.282313
# ..                                          ...
# 218                                    3.180711
# 219                                    4.910645
# 220                                    3.608921
# 221                                    3.676194
# 222                                    4.415225
#
#      imaging.radiomics.Wavelet_LLL_glcm_correl1  \
# 0                                      0.692125
# 1                                      0.843714
# 2                                      0.783959
# 3                                      0.783959
# 4                                      0.854516
# ..                                          ...
# 218                                    0.800205
# 219                                    0.667436
# 220                                    0.952064
# 221                                    0.892998
# 222                                    0.820424
#
#      imaging.radiomics.Wavelet_LLL_stats_median  \
# 0                                   2832.543927
# 1                                   2963.576661
# 2                                   2748.221725
# 3                                   2748.221725
# 4                                   2661.029808
# ..                                          ...
# 218                                 3054.296105
# 219                                 2982.108699
# 220                                 3035.723007
# 221                                 3102.222268
# 222                                 2999.751947
#
#      imaging.radiomics.Wavelet_HLH_glcm_inverseVar  \
# 0                                         0.303650
# 1                                         0.398843
# 2                                         0.373929
# 3                                         0.373929
# 4                                         0.403274
# ..                                             ...
# 218                                       0.393424
# 219                                       0.297021
# 220                                       0.396047
# 221                                       0.405176
# 222                                       0.400018
#
#      imaging.radiomics.Wavelet_LLL_glcm_clusShade  \
# 0                                    -1439.069804
# 1                                    -2546.245751
# 2                                    -2411.928366
# 3                                    -2411.928366
# 4                                    -1201.566886
# ..                                            ...
# 218                                  -2404.358516
# 219                                  -2737.218790
# 220                                 -17096.689470
# 221                                  -2992.325003
# 222                                  -3121.393107
#
#      imaging.radiomics.Wavelet_LLL_glcm_clusProm  \
# 0                                    53008.86929
# 1                                    97855.98905
# 2                                   112973.26220
# 3                                   112973.26220
# 4                                    44072.20606
# ..                                           ...
# 218                                  91071.67948
# 219                                 127524.89110
# 220                                 981933.95560
# 221                                 112489.21350
# 222                                 138753.11600
#
#      imaging.radiomics.Wavelet_LLH_glcm_homogeneity1  \
# 0                                           0.406834
# 1                                           0.624795
# 2                                           0.446747
# 3                                           0.446747
# 4                                           0.546774
# ..                                               ...
# 218                                         0.659998
# 219                                         0.444149
# 220                                         0.613994
# 221                                         0.590794
# 222                                         0.519640
#
#      imaging.radiomics.Wavelet_LLL_stats_min  \
# 0                                1020.111155
# 1                                 711.796395
# 2                                 650.596834
# 3                                 650.596834
# 4                                1009.412132
# ..                                       ...
# 218                               766.661346
# 219                              -296.808335
# 220                                57.026827
# 221                               839.503760
# 222                               702.896216
#
#      imaging.radiomics.Wavelet_LLL_stats_md  \
# 0                                402.926385
# 1                                355.510671
# 2                                426.233389
# 3                                426.233389
# 4                                361.275482
# ..                                      ...
# 218                              319.814895
# 219                              410.004547
# 220                              627.212117
# 221                              340.000621
# 222                              453.432597
#
#      imaging.radiomics.Wavelet_HLH_stats_kurtosis  \
# 0                                        4.818309
# 1                                       11.756401
# 2                                        6.723613
# 3                                        6.723613
# 4                                        8.016434
# ..                                            ...
# 218                                     14.234078
# 219                                      8.596799
# 220                                     12.117013
# 221                                     10.038556
# 222                                     10.492131
#
#      imaging.radiomics.Wavelet_LLL_rlgl_shortRunHighGrayLevEmpha  \
# 0                                            21.679970
# 1                                            25.050739
# 2                                            25.997901
# 3                                            25.997901
# 4                                            18.884856
# ..                                                 ...
# 218                                          24.997983
# 219                                          39.964554
# 220                                          25.917456
# 221                                          22.832332
# 222                                          25.652245
#
#      imaging.radiomics.Stats_std  \
# 0                     171.063599
# 1                     163.949737
# 2                     184.232208
# 3                     184.232208
# 4                     152.725372
# ..                           ...
# 218                   151.574005
# 219                   202.382126
# 220                   286.336121
# 221                   162.926880
# 222                   197.164810
#
#      imaging.radiomics.Wavelet_LLH_stats_skewness  \
# 0                                        0.037816
# 1                                       -1.618959
# 2                                       -0.069276
# 3                                       -0.069276
# 4                                        0.263160
# ..                                            ...
# 218                                     -0.523855
# 219                                      0.219204
# 220                                     -0.264268
# 221                                     -0.638601
# 222                                     -0.464038
#
#      imaging.radiomics.Wavelet_LHL_rlgl_shortRunEmphasis  \
# 0                                             0.921103
# 1                                             0.812233
# 2                                             0.885325
# 3                                             0.885325
# 4                                             0.816178
# ..                                                 ...
# 218                                           0.790135
# 219                                           0.927176
# 220                                           0.795892
# 221                                           0.781601
# 222                                           0.815093
#
#      imaging.radiomics.Wavelet_HLH_glcm_entrop2  \
# 0                                      4.993000
# 1                                      3.899077
# 2                                      4.544845
# 3                                      4.544845
# 4                                      4.302233
# ..                                          ...
# 218                                    3.596568
# 219                                    5.183919
# 220                                    3.918171
# 221                                    3.779192
# 222                                    3.848078
#
#      imaging.radiomics.Wavelet_LLH_stats_entropy  \
# 0                                       4.184240
# 1                                       2.882889
# 2                                       3.971293
# 3                                       3.971293
# 4                                       3.478659
# ..                                           ...
# 218                                     2.695000
# 219                                     3.847398
# 220                                     2.916907
# 221                                     3.071021
# 222                                     3.557336
#
#      imaging.radiomics.Wavelet_LLL_glcm_infoCorr2  \
# 0                                        0.828468
# 1                                        0.877564
# 2                                        0.835851
# 3                                        0.835851
# 4                                        0.890055
# ..                                            ...
# 218                                      0.859020
# 219                                      0.750196
# 220                                      0.903106
# 221                                      0.852839
# 222                                      0.874710
#
#      imaging.radiomics.Wavelet_HLL_rlgl_runLengthNonuniformity  \
# 0                                          1380.764995
# 1                                          6271.123831
# 2                                         13642.848480
# 3                                         13642.848480
# 4                                          4651.243483
# ..                                                 ...
# 218                                        6518.220627
# 219                                       19922.319240
# 220                                       18070.930230
# 221                                        3476.967114
# 222                                       12847.466730
#
#      imaging.radiomics.Wavelet_HLH_rlgl_shortRunEmphasis  \
# 0                                             0.923177
# 1                                             0.829368
# 2                                             0.870700
# 3                                             0.870700
# 4                                             0.849219
# ..                                                 ...
# 218                                           0.797226
# 219                                           0.910275
# 220                                           0.818959
# 221                                           0.827047
# 222                                           0.814983
#
#      imaging.radiomics.Wavelet_LLL_glcm_sumEntro
# 0                                       3.551309
# 1                                       3.470230
# 2                                       3.792505
# 3                                       3.792505
# 4                                       3.506673
# ..                                           ...
# 218                                     3.188845
# 219                                     3.623390
# 220                                     3.044352
# 221                                     2.940355
# 222                                     3.780798
#
# [223 rows x 20 columns]

# %%
from sklearn.model_selection import train_test_split
X_train_20, X_test_20, y_train_20, y_test_20 = train_test_split(data_new_20features_X, data_y_trans, train_size = 0.8, random_state=26)

# %%
from sklearn.preprocessing import StandardScaler 
ss_20 = StandardScaler()
X_train_std_20 = ss_20.fit_transform(X_train_20)
X_test_std_20 = ss_20.fit_transform(X_test_20)

# %% [markdown]
# Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=56)

# %%
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
from sklearn.metrics import confusion_matrix

# %%
from sklearn.model_selection import cross_val_predict
y_pred = cross_val_predict(rf, data_new_20features_X, data_y_trans, cv=10)
conf_mat = confusion_matrix(data_y_trans, y_pred)

# %%
print(conf_mat)
# Out:
# [[121   3   4]
#  [ 10  22   2]
#  [ 17   0  44]]

# %%
print("Classification Report for Random Forest: \n", classification_report(data_y_trans,y_pred))
# Out:
# Classification Report for Random Forest:
#                precision    recall  f1-score   support
#
#            0       0.82      0.95      0.88       128
#            1       0.88      0.65      0.75        34
#            2       0.88      0.72      0.79        61
#
#     accuracy                           0.84       223
#    macro avg       0.86      0.77      0.81       223
# weighted avg       0.84      0.84      0.83       223

# %% [markdown]
# PSO

# %%
# !pip install optunity
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optunity
#   Downloading Optunity-1.1.1.tar.gz (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 62.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: optunity
#   Building wheel for optunity (setup.py) ... done
#   Created wheel for optunity: filename=Optunity-1.1.1-py3-none-any.whl size=72031 sha256=489a379a5c6a51f6818c7bd2e434c33c895d123412e483b336c4f63611e73951
#   Stored in directory: /root/.cache/pip/wheels/d1/03/a8/c725421da03e2bb8b33fb20b7159727fb1d47806f0ae844a91
# Successfully built optunity
# Installing collected packages: optunity
# Successfully installed optunity-1.1.1

# %%
data_new_20features_Xt = ss_20.fit_transform(data_new_20features_X)

# %%
import optunity
import optunity.metrics
from sklearn.model_selection import cross_val_score
data=data_new_20features_Xt
labels= data_y_trans.tolist()
# Define the hyperparameter configuration space
search = {
    'n_estimators': [10, 100],
    'max_features': [1, 64],
    'max_depth': [5,50],
    "min_samples_split":[2,11],
    "min_samples_leaf":[1,11],
    "criterion":[0,1]
         }
# Define the objective function
@optunity.cross_validated(x=data, y=labels, num_folds=3)
def performance(x_train, y_train, x_test, y_test,n_estimators=None, max_features=None,max_depth=None,min_samples_split=None,min_samples_leaf=None,criterion=None):
    # fit the model
    if criterion<0.5:
        cri='gini'
    else:
        cri='entropy'
    model = RandomForestClassifier(
                                   criterion=cri,
                                  )
    #predictions = model.predict(x_test)
    scores=np.mean(cross_val_score(model, data_new_20features_Xt,  data_y_trans, cv=10, n_jobs=-1,
                                    scoring="accuracy"))
    #return optunity.metrics.roc_auc(y_test, predictions, positive=True)
    return scores#optunity.metrics.accuracy(y_test, predictions)

optimal_configuration, info, _ = optunity.maximize(performance,
                                                  solver_name='particle swarm',
                                                  num_evals=20,
                                                   **search
                                                  )
print(optimal_configuration)
print("Accuracy:"+ str(info.optimum))
# Out:
# {'n_estimators': 81.806640625, 'max_features': 49.4189453125, 'max_depth': 45.8251953125, 'min_samples_split': 3.4501953125, 'min_samples_leaf': 8.880859375, 'criterion': 0.2060546875}
# Accuracy:0.8465744400527009

# %% [markdown]
# ROC Curve

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score

# %%
from sklearn.preprocessing import label_binarize
y_bin = label_binarize(data_y_trans, classes=[0, 1, 2,3])
from itertools import cycle
lw=2

# %%
import matplotlib.pyplot as plt

# %%
y_score = cross_val_predict(rf, data_new_20features_X, data_y_trans, cv=2 ,method='predict_proba')

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
colors = cycle(['blue', 'red', 'green','magenta'])
list_class = ['squamous','largecell','others','adeno']
for i, color in zip(range(3), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(list_class[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic for multi-class data')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# svm

# %%
from sklearn.svm import SVC

svm_rbf = SVC(gamma=4, C=1)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
y_pred = cross_val_predict(svm_rbf, data_new_20features_X, data_y_trans, cv=4)
conf_mat = confusion_matrix(data_y_trans, y_pred)

# %%
print("Classification Report for Random Forest: \n", classification_report(data_y_trans,y_pred))
# Out:
# Classification Report for Random Forest:
#                precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85       128
#            1       1.00      0.53      0.69        34
#            2       1.00      0.52      0.69        61
#
#     accuracy                           0.80       223
#    macro avg       0.91      0.68      0.74       223
# weighted avg       0.85      0.80      0.78       223

# %%
data=data_new_20features_Xt
labels=data_y_trans.tolist()

search = {
    'C': (0,50),
    'kernel':[0,4]
         }
@optunity.cross_validated(x=data, y=labels, num_folds=3)
def performance(x_train, y_train, x_test, y_test,C=None,kernel=None):
    # fit the model
    if kernel<1:
        ke='linear'
    elif kernel<2:
        ke='poly'
    elif kernel<3:
        ke='rbf'
    else:
        ke='sigmoid'
    model = SVC(C=float(C),
                kernel=ke
                                  )
    #predictions = model.predict(x_test)
    scores=np.mean(cross_val_score(model, data_new_20features_Xt,data_y_trans, cv=10, n_jobs=-1,
                                    scoring="accuracy"))
    #return optunity.metrics.roc_auc(y_test, predictions, positive=True)
    return scores#optunity.metrics.accuracy(y_test, predictions)

optimal_configuration, info, _ = optunity.maximize(performance,
                                                  solver_name='particle swarm',
                                                  num_evals=20,
                                                   **search
                                                  )
print(optimal_configuration)
print("Accuracy:"+ str(info.optimum))
# Out:
# {'C': 17.6025390625, 'kernel': 2.791015625}
# Accuracy:0.8339920948616601

# %% [markdown]
# knn

# %%
from sklearn.neighbors import KNeighborsClassifier,KNeighborsRegressor

# %%
clf2 = KNeighborsClassifier()
clf2.fit(data_new_20features_X, data_y_trans)
scores = cross_val_score(clf2, data_new_20features_X, data_y_trans, cv=10,scoring='accuracy')
print("Accuracy:"+ str(scores.mean()))
# Out:
# Accuracy:0.5784584980237154

# %% [markdown]
# knn PSO

# %%
import optunity
import optunity.metrics

data=data_new_20features_Xt
labels=data_y_trans.tolist()

search = {
    'n_neighbors': [1, 20],
         }
@optunity.cross_validated(x=data, y=labels, num_folds=3)
def performance(x_train, y_train, x_test, y_test,n_neighbors=None):
    # fit the model
    model = KNeighborsClassifier(n_neighbors=int(n_neighbors),
                                  )
    scores=np.mean(cross_val_score(model,data_new_20features_Xt,data_y_trans, cv=10, n_jobs=-1,
                                    scoring="accuracy"))
    return scores

optimal_configuration, info, _ = optunity.maximize(performance,
                                                  solver_name='particle swarm',
                                                  num_evals=10,
                                                   **search
                                                  )
print(optimal_configuration)
print("Accuracy:"+ str(info.optimum))
# Out:
# {'n_neighbors': 3.3564453125}
# Accuracy:0.691501976284585

# %% [markdown]
# ROC Curve

# %%
y_score = cross_val_predict(clf2, data_new_20features_X, data_y_trans, cv=2 ,method='predict_proba')

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
colors = cycle(['blue', 'red', 'green','magenta'])
list_class = ['squamous','largecell','others','adeno']
for i, color in zip(range(3), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(list_class[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic for multi-class data')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# GradientBoosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gradient_boost = GradientBoostingClassifier(random_state=56)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
y_pred = cross_val_predict(gradient_boost, data_new_20features_X, data_y_trans, cv=10)
conf_mat = confusion_matrix(data_y_trans, y_pred)

# %%
print("Classification Report for GradientBoosting: \n", classification_report(data_y_trans,y_pred))
# Out:
# Classification Report for GradientBoosting:
#                precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88       128
#            1       0.73      0.65      0.69        34
#            2       0.84      0.75      0.79        61
#
#     accuracy                           0.83       223
#    macro avg       0.81      0.77      0.79       223
# weighted avg       0.83      0.83      0.83       223

# %% [markdown]
# GB PSO

# %%
data=data_new_20features_Xt
labels=data_y_trans.tolist()

search = {
    'C': (0,50),
    'kernel':[0,4]
         }
@optunity.cross_validated(x=data, y=labels, num_folds=3)
def performance(x_train, y_train, x_test, y_test,C=None,kernel=None):
    # fit the model
    
    model = GradientBoostingClassifier(random_state=56)
    #predictions = model.predict(x_test)
    scores=np.mean(cross_val_score(model, data_new_20features_Xt,data_y_trans, cv=10, n_jobs=-1,
                                    scoring="accuracy"))
    #return optunity.metrics.roc_auc(y_test, predictions, positive=True)
    return scores#optunity.metrics.accuracy(y_test, predictions)

optimal_configuration, info, _ = optunity.maximize(performance,
                                                  solver_name='particle swarm',
                                                  num_evals=20,
                                                   **search
                                                  )
print(optimal_configuration)
print("Accuracy:"+ str(info.optimum))
# Out:
# {'C': 37.353515625, 'kernel': 0.02734375}
# Accuracy:0.8300395256916996

# %% [markdown]
# ROC

# %%
y_score = cross_val_predict(gradient_boost, data_new_20features_X, data_y_trans, cv=2 ,method='predict_proba')

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
colors = cycle(['blue', 'red', 'green','magenta'])
list_class = ['squamous','largecell','others','adeno']
for i, color in zip(range(3), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(list_class[i], roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic for multi-class data')
plt.legend(loc="lower right")
plt.show()
